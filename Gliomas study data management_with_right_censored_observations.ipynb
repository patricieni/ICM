# %% [markdown]
# # Preprocessing and storing DF in pickle
# Perhaps we might Dwh Pat Dn Date later on.

# %%
import pandas as pd
import numpy as np
from pathlib import Path
import os 
from datetime import timedelta
pd.set_option('display.max_columns', None)

#data_path = str(Path(os.getcwd())) + "/data/"

#def write_to_pickle(dataframe, name):
#    dataframe.to_pickle(data_path + name + ".pickle")
#def read_from_pickle(name): 
#    return pd.read_pickle(data_path + name + ".pickle")

# %%
bio = pd.read_excel('Dropbox/Healthcare work Patric/20170713_Marc Gliomes_Bio.xlsx', index_col = None)
clin = pd.read_excel('Dropbox/Healthcare work Patric/20170713_Marc Gliomes_Clin.xlsx', index_col = None)

# %%
b = bio.loc[bio['Pat Nip']==4406078178,'Dwh Prv Date Chir']
c = clin.loc[clin['Pat Nip']==4406078178,'Clin Chir Date']

#c.iloc[:len(c)]=1
#clin.loc[clin['Pat Nip']==4406078178,'Clin Chir Date'] = c
#clin.loc[clin['Pat Nip']==4406078178,'Clin Chir Date'] 
#print(clin.loc[clin['Pat Nip']==4406078178,'Clin Chir Date'].iloc[i])
#clin.loc[clin['Pat Nip']==4406078178,'Clin Chir Date']    
#bio['Dwh Prv Date Chir'] = bio['Dwh Prv Date Chir'].apply(lambda x: x.to_pydatetime())
#bio.loc[2,'Dwh Prv Date Chir'].to_pydatetime()-timedelta(days=1)
#clin['Clin Chir Date'] = clin['Clin Chir Date'].apply(lambda x: x.to_pydatetime() + timedelta(days=1))
#bio['Dwh Prv Date Chir'] = bio['Dwh Prv Date Chir'].apply(lambda x: x.to_pydatetime())

# %% [markdown]
# Fix the surgery and clinical date so that they match

# %%
# Make the two surgery dates match 
# You are taking copies of the dataframe with loc and iloc, so you need to pay attention when you do assignment
# Can definitely remove one or both 'for' loops
for val in np.unique(clin['Pat Nip']): 
    bio_data = bio.loc[bio['Pat Nip']==val,'Dwh Prv Date Chir']
    clin_data = clin.loc[clin['Pat Nip']==val,'Clin Chir Date']
    lc = len(clin_data)
    lb = len(bio_data)
    if lc <=lb:
        for i in range(0,lc):
            clin_data.iloc[i] = bio_data.iloc[i]        
    else: 
        for i in range(0,lb):
            clin_data.iloc[i] = bio_data.iloc[i]
    clin.loc[clin['Pat Nip']==val,'Clin Chir Date'] = clin_data

# %%
df = pd.merge(bio, clin, left_on = ['Pat Nip','Dwh Prv Date Chir'], right_on = ['Pat Nip','Clin Chir Date'],how='outer')
df.columns
# Out:
# Index(['Dwh Prv Nip', 'Dwh Pat Consentement', 'Pat Nip', 'Pat Sexe_x',
#        'Pat Date Naissance_x', 'Dwh Pat Dn Date_x', 'Dwh Pat Date Deces_x',
#        'Dwh Prv Date Chir', 'Dwh Prv Diag Histologie', 'Grade', 'Dwh Gen Idh1',
#        'Dwh Gen Idh2', 'Dwh Gen Htert C228T', 'Dwh Gen Htert C250T',
#        'Dwh Gen P53', 'Dwh Gen Mgmt', 'Dwh Gen Egfr', 'Dwh Gen Mdm2',
#        'Dwh Gen Cdk4', 'Dwh Gen P16', 'Dwh Ihc Atrx', 'Dwh Chr Ch1P',
#        'Dwh Chr Ch19Q', 'Dwh Chr Ch10P', 'Dwh Chr Ch10Q', 'Dwh Chr Ch9P',
#        'Dwh Chr Ch9Q', 'Dwh Pat Tumeur Siege', 'Dwh Pat Tumeur Position',
#        'Pat Sexe_y', 'Pat Date Naissance_y', 'Dwh Pat Dn Date_y',
#        'Dwh Pat Date Deces_y', 'Clin Diag Histologie', 'Grade histo',
#        'Clin Chir Date', 'Clin Evolution', 'Clin Type Chirurgie',
#        'Clin Rx Date', 'Dwh Chm Date Debut'],
#       dtype='object')

# %% [markdown]
# Before merging sexes, birthdays and deaths

# %%
# Can check before merging the whole thing as well. 
#bio['Pat Sexe'].isnull().value_counts()
print(df['Pat Sexe_x'].isnull().value_counts())
print(df['Pat Date Naissance_x'].isnull().value_counts())
print(df['Dwh Pat Date Deces_x'].isnull().value_counts())
# Out:
# False    7456
# True      369
# Name: Pat Sexe_x, dtype: int64
# False    7725
# True      100
# Name: Pat Date Naissance_x, dtype: int64
# True     4921
# False    2904
# Name: Dwh Pat Date Deces_x, dtype: int64

# %% [markdown]
# # Copy all _y columns into _x: sex, birthday and death, clinical histology, grade histology

# %%
for val in np.unique(df['Pat Nip']): 
    x_data = df.loc[df['Pat Nip']==val,'Pat Sexe_x']
    y_data = df.loc[df['Pat Nip']==val,'Pat Sexe_y']
    lc = len(x_data)
    for i in range(0,lc):
        check = x_data.iloc[i]
        if pd.isnull(check):
             x_data.iloc[i] = y_data.iloc[i]        
    df.loc[df['Pat Nip']==val,'Pat Sexe_x'] = x_data

for val in np.unique(df['Pat Nip']): 
    x_data = df.loc[df['Pat Nip']==val,'Pat Date Naissance_x']
    y_data = df.loc[df['Pat Nip']==val,'Pat Date Naissance_y']
    lc = len(x_data)
    for i in range(0,lc):
        check = x_data.iloc[i]
        if pd.isnull(check):
             x_data.iloc[i] = y_data.iloc[i]        
    df.loc[df['Pat Nip']==val,'Pat Date Naissance_x'] = x_data    

for val in np.unique(df['Pat Nip']): 
    x_data = df.loc[df['Pat Nip']==val,'Dwh Pat Date Deces_x']
    y_data = df.loc[df['Pat Nip']==val,'Dwh Pat Date Deces_y']
    lc = len(x_data)
    for i in range(0,lc):
        check = x_data.iloc[i]
        if pd.isnull(check):
             x_data.iloc[i] = y_data.iloc[i]        
    df.loc[df['Pat Nip']==val,'Dwh Pat Date Deces_x'] = x_data   
    
for val in np.unique(df['Pat Nip']): 
    x_data = df.loc[df['Pat Nip']==val,'Dwh Prv Diag Histologie']
    y_data = df.loc[df['Pat Nip']==val,'Clin Diag Histologie']
    lc = len(x_data)
    for i in range(0,lc):
        check = x_data.iloc[i]
        if pd.isnull(check):
             x_data.iloc[i] = y_data.iloc[i]        
    df.loc[df['Pat Nip']==val,'Dwh Prv Diag Histologie'] = x_data   

for val in np.unique(df['Pat Nip']): 
    x_data = df.loc[df['Pat Nip']==val,'Grade']
    y_data = df.loc[df['Pat Nip']==val,'Grade histo']
    lc = len(x_data)
    for i in range(0,lc):
        check = x_data.iloc[i]
        if pd.isnull(check):
             x_data.iloc[i] = y_data.iloc[i]        
    df.loc[df['Pat Nip']==val,'Grade'] = x_data   

for val in np.unique(df['Pat Nip']): 
    x_data = df.loc[df['Pat Nip']==val,'Dwh Pat Dn Date_x']
    y_data = df.loc[df['Pat Nip']==val,'Dwh Pat Dn Date_y']
    lc = len(x_data)
    for i in range(0,lc):
        check = x_data.iloc[i]
        if pd.isnull(check):
             x_data.iloc[i] = y_data.iloc[i]        
    df.loc[df['Pat Nip']==val,'Dwh Pat Dn Date_x'] = x_data

# %%
# A small improvement
print(df['Pat Sexe_x'].isnull().value_counts())
print(df['Pat Date Naissance_x'].isnull().value_counts())
print(df['Dwh Pat Date Deces_x'].isnull().value_counts())
print(df['Dwh Prv Diag Histologie'].isnull().value_counts())
# Out:
# False    7493
# True      332
# Name: Pat Sexe_x, dtype: int64
# False    7762
# True       63
# Name: Pat Date Naissance_x, dtype: int64
# True     4908
# False    2917
# Name: Dwh Pat Date Deces_x, dtype: int64
# False    7825
# Name: Dwh Prv Diag Histologie, dtype: int64

# %%
df.columns
# Out:
# Index(['Dwh Prv Nip', 'Dwh Pat Consentement', 'Pat Nip', 'Pat Sexe_x',
#        'Pat Date Naissance_x', 'Dwh Pat Dn Date_x', 'Dwh Pat Date Deces_x',
#        'Dwh Prv Date Chir', 'Dwh Prv Diag Histologie', 'Grade', 'Dwh Gen Idh1',
#        'Dwh Gen Idh2', 'Dwh Gen Htert C228T', 'Dwh Gen Htert C250T',
#        'Dwh Gen P53', 'Dwh Gen Mgmt', 'Dwh Gen Egfr', 'Dwh Gen Mdm2',
#        'Dwh Gen Cdk4', 'Dwh Gen P16', 'Dwh Ihc Atrx', 'Dwh Chr Ch1P',
#        'Dwh Chr Ch19Q', 'Dwh Chr Ch10P', 'Dwh Chr Ch10Q', 'Dwh Chr Ch9P',
#        'Dwh Chr Ch9Q', 'Dwh Pat Tumeur Siege', 'Dwh Pat Tumeur Position',
#        'Pat Sexe_y', 'Pat Date Naissance_y', 'Dwh Pat Dn Date_y',
#        'Dwh Pat Date Deces_y', 'Clin Diag Histologie', 'Grade histo',
#        'Clin Chir Date', 'Clin Evolution', 'Clin Type Chirurgie',
#        'Clin Rx Date', 'Dwh Chm Date Debut'],
#       dtype='object')

# %%
df.rename(columns = {'Pat Nip':'ID','Pat Sexe_x':'Sex','Dwh Pat Dn Date_x':'Dernieres_nouvelles','Pat Date Naissance_x':'DoB','Dwh Pat Date Deces_x':'Death_date',
                      'Dwh Prv Date Chir':'Surgery_date', 'Dwh Prv Diag Histologie':'Tumor_type','Grade':'Tumor_grade',
                      'Dwh Gen Idh1':'Gene_Idh1', 'Dwh Gen Idh2':'Gene_Idh2','Dwh Gen Htert C228T':'Gene_Htert_C228T', 
                      'Dwh Gen Htert C250T':'Gene_Htert_C250T', "Dwh Gen P53":'Gene_P53', 'Dwh Gen Mgmt':'Gene_Mgmt', 
                      'Dwh Gen Egfr':'Gene_Egfr', 'Dwh Gen Mdm2':'Gene_Mdm2','Dwh Gen Cdk4':'Gene_Cdk4',
                      'Dwh Gen P16':'Gene_P16', 'Dwh Ihc Atrx':'Gene_Ihc_Atrx', 'Dwh Chr Ch1P':'Gene_Ch1P',
                      'Dwh Chr Ch19Q':'Gene_Ch19Q', 'Dwh Chr Ch10P':'Gene_Ch10P', 'Dwh Chr Ch10Q':'Gene_Ch10Q', 'Dwh Chr Ch9P':'Gene_Ch9P',
                      'Dwh Chr Ch9Q':'Gene_Ch9Q', 'Dwh Pat Tumeur Siege':'Tumor_Location', 'Dwh Pat Tumeur Position':'Tumor_Position',
                      'Clin Evolution':'Clinical_evolution', 'Clin Type Chirurgie':'Surgery_type',
                      'Clin Rx Date':'Rx_date', 'Dwh Chm Date Debut':'Chemo_start_date'}, inplace = True)
df.drop(['Dwh Pat Dn Date_y','Pat Sexe_y','Dwh Pat Date Deces_y','Pat Date Naissance_y'], axis=1,inplace=True)
df.drop('Dwh Pat Consentement', axis=1, inplace=True)
df.drop('Dwh Prv Nip', axis=1, inplace=True)
df.drop(['Clin Diag Histologie', 'Grade histo','Clin Chir Date',],axis=1,inplace=True)

# %%
df.rename(columns = {'Sex':'Gender'},inplace = True) 
#write_to_pickle(df,'post_merge_data')
df.columns
# Out:
# Index(['ID', 'Gender', 'DoB', 'Dernieres_nouvelles', 'Death_date',
#        'Surgery_date', 'Tumor_type', 'Tumor_grade', 'Gene_Idh1', 'Gene_Idh2',
#        'Gene_Htert_C228T', 'Gene_Htert_C250T', 'Gene_P53', 'Gene_Mgmt',
#        'Gene_Egfr', 'Gene_Mdm2', 'Gene_Cdk4', 'Gene_P16', 'Gene_Ihc_Atrx',
#        'Gene_Ch1P', 'Gene_Ch19Q', 'Gene_Ch10P', 'Gene_Ch10Q', 'Gene_Ch9P',
#        'Gene_Ch9Q', 'Tumor_Location', 'Tumor_Position', 'Clinical_evolution',
#        'Surgery_type', 'Rx_date', 'Chemo_start_date'],
#       dtype='object')

# %%
#df = read_from_pickle('post_merge_data')

# %%
df.head(2)
# Out:
#    ID Gender        DoB Dernieres_nouvelles Death_date Surgery_date  \
# 0   4      M 1940-05-22                 NaN 2001-02-22   2000-05-30
# 1   5      M 1947-10-15                 NaN 1999-12-15   1999-05-29
#
#         Tumor_type  Tumor_grade Gene_Idh1 Gene_Idh2 Gene_Htert_C228T  \
# 0  glioblastome IV          4.0        NC        NC              NaN
# 1  glioblastome IV          4.0       NaN       NaN              NaN
#
#   Gene_Htert_C250T Gene_P53 Gene_Mgmt Gene_Egfr Gene_Mdm2 Gene_Cdk4 Gene_P16  \
# 0              NaN       NC       NaN       NaN       NaN       NaN      NaN
# 1              NaN      NaN       NaN       NaN       NaN       NaN      NaN
#
#   Gene_Ihc_Atrx Gene_Ch1P Gene_Ch19Q Gene_Ch10P Gene_Ch10Q Gene_Ch9P  \
# 0           NaN       NaN        NaN        NaN        NaN       NaN
# 1           NaN       NaN        NaN        NaN        NaN       NaN
#
#   Gene_Ch9Q Tumor_Location Tumor_Position Clinical_evolution Surgery_type  \
# 0       NaN          autre              G                 P1      exérèse
# 1       NaN   sus-T hémisp              G             TT ini      biopsie
#
#      Rx_date Chemo_start_date
# 0 2000-07-07              NaT
# 1 1999-07-12       1999-06-29

# %% [markdown]
# # End of merging. Next we deal with nan/empty values

# %%
df_clean = df.copy(deep=True)

# %%
df_clean = df.copy(deep=True)

#Marc comment: if a patient misses data for both IDH1 and IDH2, poor quality record = delete 
#Retain observations for which either Idh1 or Idh2 are null but not both
df_clean = df_clean.loc[(df_clean.Gene_Idh2.notnull()) | (df_clean.Gene_Idh1.notnull())]

df_clean= df_clean[df_clean.DoB.notnull()]
df_clean = df_clean[df_clean.Gender.notnull()]

#The below only applies in the dataset without right censored data
#Remove dernieres nouvelles as in this notebook we focus only on patients with a confirmed survival time since surgery
#df_clean.drop('Dernieres_nouvelles', axis=1, inplace=True)

# %%
# Sanity check
(df_clean.Gene_Idh1.isnull() & df_clean.Gene_Idh2.isnull()).value_counts()
# Out:
# False    7057
# dtype: int64

# %%
# We therefore cannot work with missing values here (beyond specific left censoring methods of analysis)
# Remove NaN for surgery dates before creating new variable
df_clean = df_clean[df_clean.Surgery_date.notnull()]
df_clean.Surgery_date.isnull().value_counts()
# Out:
# False    6794
# Name: Surgery_date, dtype: int64

# %%
# Add age at surgery variable
df_clean['Age_surgery'] = df_clean['Surgery_date'] - df_clean['DoB']

# %%
len(df_clean)
# Out:
# 6794

# %%
# Marc comment: keep only observations where Clinical evolution was "TT ini" (initial evaluation)
df_clean = df_clean.loc[df_clean['Clinical_evolution'] == "TT ini"]

# %%
len(df_clean)
# Out:
# 3758

# %% [markdown]
# # Time manipulations

# %%
df_clean.Death_date.isnull().value_counts()
# Out:
# False    2152
# True     1606
# Name: Death_date, dtype: int64

# %%
# Convert Age at surgery to years
df_clean['Age_surgery'] = df_clean['Age_surgery'] / np.timedelta64(1, 'Y')
df_clean['Age_surgery'] = df_clean['Age_surgery'].round()

# %%
df_clean["Dernieres_nouvelles"] = pd.to_datetime(df_clean["Dernieres_nouvelles"])
df_clean.loc[:,'Dernieres_nouvelles'] = df_clean['Dernieres_nouvelles'].dt.year

# %%
(df_clean['Dernieres_nouvelles'] == 2017).value_counts()
# Out:
# False    3480
# True      278
# Name: Dernieres_nouvelles, dtype: int64

# %%
#should we expand this to include last dernieres nouvelles in 2016? It would add 387 records.
(df_clean['Dernieres_nouvelles'] == 2016).value_counts()
# Out:
# False    3474
# True      284
# Name: Dernieres_nouvelles, dtype: int64

# %% [markdown]
# Two approaches:
# - we remove null values for death dates
# - we deal with null values for life_expectancy later on

# %%
# Comment the first line to have the second approach
df_clean = df_clean[(df_clean.Death_date.notnull()) | (df_clean['Dernieres_nouvelles'] == 2017)]
df_clean['life_expectancy'] = df_clean.Death_date - df_clean.Surgery_date
df_clean['life_expectancy'] = df_clean['life_expectancy'] / np.timedelta64(1, 'D')

# %%
len(df_clean)
# Out:
# 2430

# %%
df_clean_test = df_clean.copy(deep=True)

# %%
#Marc rule: aggregate "glioblastoma avec oligo IV" into "GBM"; "astrocytome gémistocytique (=A2)" into "astrocytoma grade II"
#we also remove grades from tumor types, since they are contained in "Tumor_grade" variable
df_clean_test['Tumor_type'].replace({"glioblastome IV": "GBM", "oligo.haut grade III":"oligo",
                                "gliome mixte ana III":"gliome", "oligo. bas grade II": "oligo",
                                "glioblastome avec oligo. IV": "GBM", "gliome mixte II": "gliome",
                                "astrocytome anaplasique III": "astrocytome", "astrocytome bas grade II":"astrocytome",
                                "astrocytome gémistocytique (=A2":"astrocytome", "gangliogliome anaplasique III":"gangliogliome anaplasique"}, inplace=True)
df_clean_test
# Out:
#               ID Gender        DoB  Dernieres_nouvelles Death_date  \
# 2             10      M 1949-11-05                  NaN 1992-05-15
# 3             11      M 1958-07-29                  NaN 1991-11-15
# 5             12      F 1930-12-07                  NaN 1991-03-13
# 7             13      M 1928-11-17                  NaN 1990-12-20
# 8             14      F 1934-07-17                  NaN 1993-03-30
# 9             15      M 1936-03-22                  NaN 1992-03-14
# 10            16      M 1922-04-18                  NaN 1991-12-22
# 11            17      M 1924-04-12                  NaN 1990-04-04
# 12            18      F 1931-06-05                  NaN 1992-12-18
# 14            22      M 1950-05-10                  NaN 1995-01-29
# 15            23      F 1932-10-09                  NaN 1993-09-10
# 16            23      F 1932-10-09                  NaN 1993-09-10
# 17            24      M 1943-03-04                  NaN 1993-12-15
# 18            25      M 1957-06-16                  NaN 1991-04-13
# 19            25      M 1957-06-16                  NaN 1991-04-13
# 20            26      M 1930-07-07                  NaN 1991-05-15
# 24            30      M 1952-02-01                  NaN 1994-03-03
# 25            31      M 1957-11-25                  NaN 1992-10-20
# 27            34      F 1939-06-30                  NaN 1990-09-15
# 28            35      F 1917-06-04                  NaN 1990-04-15
# 30            36      F 1972-12-01                  NaN 1996-10-19
# 31            37      M 1945-01-01                  NaN 1989-12-31
# 34            39      F 1974-06-21                  NaN 1990-10-30
# 35            40      M 1927-04-16                  NaN 1990-07-09
# 36            41      M 1970-04-07                  NaN 1992-09-01
# 37            42      F 1942-08-14                  NaN 1993-11-08
# 40            44      M 1951-03-28                  NaN 1992-08-06
# 45            47      F 1932-05-26                  NaN 1994-03-10
# 50            49      M 1927-04-07                  NaN 1993-10-01
# 51            49      M 1927-04-07                  NaN 1993-10-01
# ...          ...    ...        ...                  ...        ...
# 7685  8009475251      F 1956-12-25               2017.0        NaT
# 7689  8009496494      F 1953-07-01               2017.0        NaT
# 7690  8009502080      M 1967-02-03               2017.0        NaT
# 7691  8009502097      F 1959-04-19               2017.0        NaT
# 7692  8009504238      M 1996-12-28               2017.0        NaT
# 7693  8009508609      M 1944-02-26               2017.0        NaT
# 7694  8009509396      M 1963-12-08               2017.0        NaT
# 7695  8009510265      F 1962-06-07               2017.0        NaT
# 7696  8009536357      M 1968-04-16                  NaN 2017-05-13
# 7697  8009538232      M 1945-01-01               2017.0        NaT
# 7698  8009545405      F 1975-09-30               2017.0        NaT
# 7700  8009547563      F 1974-09-11               2017.0        NaT
# 7701  8009558455      F 1962-08-12               2017.0        NaT
# 7704  8009583738      F 1947-03-30               2017.0        NaT
# 7707  8009588647      F 1958-06-26               2017.0        NaT
# 7709  8009606625      F 1947-03-27               2017.0        NaT
# 7711  8009619135      F 1993-02-08               2017.0        NaT
# 7713  8009630406      F 1968-12-22               2017.0        NaT
# 7714  8009631994      M 1970-07-28               2017.0        NaT
# 7715  8009633302      M 1965-11-07               2017.0        NaT
# 7716  8009635074      M 1957-01-07               2017.0        NaT
# 7719  8009636704      M 1974-04-12               2017.0        NaT
# 7720  8009636704      M 1974-04-12               2017.0        NaT
# 7727  8009657835      F 1985-08-30               2017.0        NaT
# 7729  8009669708      F 1971-08-19               2017.0        NaT
# 7732  8009694199      M 1948-10-14               2017.0        NaT
# 7735  8009712826      M 1956-01-01               2017.0        NaT
# 7738  8009724274      F 1942-07-30               2017.0        NaT
# 7740  8009728167      F 1957-02-22               2017.0        NaT
# 7755  8009823797      F 1968-01-16               2017.0        NaT
#
#      Surgery_date                        Tumor_type  Tumor_grade Gene_Idh1  \
# 2      1992-04-15                            gliome          3.0    ALTERE
# 3      1986-03-17                       astrocytome          2.0        NC
# 5      1990-02-13                               GBM          4.0    NORMAL
# 7      1989-11-17                               GBM          4.0    NORMAL
# 8      1992-01-22                               GBM          4.0    NORMAL
# 9      1991-10-23                               GBM          4.0    NORMAL
# 10     1990-11-09                               GBM          4.0    NORMAL
# 11     1990-03-28                               GBM          4.0    NORMAL
# 12     1992-02-06                       astrocytome          3.0    NORMAL
# 14     1993-07-07                               GBM          4.0    NORMAL
# 15     1990-06-26                       astrocytome          3.0        NC
# 16     1990-06-26                       astrocytome          3.0        NC
# 17     1992-01-14                            gliome          3.0    NORMAL
# 18     1989-11-08                       astrocytome          2.0    NORMAL
# 19     1989-11-08                       astrocytome          2.0    NORMAL
# 20     1990-11-02                             oligo          3.0    ALTERE
# 24     1990-09-25                       astrocytome          3.0    NORMAL
# 25     1992-05-04                             oligo          2.0    NORMAL
# 27     1988-11-18                               GBM          4.0    NORMAL
# 28     1989-04-25                               GBM          4.0    NORMAL
# 30     1996-08-20                            gliome          3.0    ALTERE
# 31     1989-09-26                               GBM          4.0    NORMAL
# 34     1989-04-12                       astrocytome          2.0        NC
# 35     1989-08-23                               GBM          4.0    NORMAL
# 36     1992-03-10                               GBM          4.0    NORMAL
# 37     1991-02-15                               GBM          4.0    NORMAL
# 40     1991-12-30                               GBM          4.0        NC
# 45     1992-11-17                               GBM          4.0    NORMAL
# 50     1990-04-11                             oligo          3.0    NORMAL
# 51     1990-04-11                             oligo          3.0    NORMAL
# ...           ...                               ...          ...       ...
# 7685   2008-08-27                             oligo          2.0    ALTERE
# 7689   2016-08-31                               GBM          4.0    NORMAL
# 7690   2016-05-03                            gliome          3.0    ALTERE
# 7691   2016-08-23                             oligo          3.0    ALTERE
# 7692   2017-02-06                       astrocytome          3.0    ALTERE
# 7693   2015-10-28                               GBM          4.0    NORMAL
# 7694   2016-06-08                               GBM          4.0        NC
# 7695   2015-09-29                               GBM          4.0    NORMAL
# 7696   2016-07-07                       astrocytome          3.0    NORMAL
# 7697   2016-12-29                               GBM          4.0    ALTERE
# 7698   2005-11-25                             oligo          3.0    ALTERE
# 7700   2013-01-22                               GBM          4.0    ALTERE
# 7701   2006-07-19  astrocytome gémistocytique (=A2)          2.0    ALTERE
# 7704   2016-09-20                               GBM          4.0        NC
# 7707   2016-05-20                       astrocytome          2.0    NORMAL
# 7709   2016-04-06                               GBM          4.0        NC
# 7711   2016-08-30                               GBM          4.0    NORMAL
# 7713   2016-04-28                               GBM          4.0        NC
# 7714   2016-02-18                               GBM          4.0    NORMAL
# 7715   2016-03-17                             oligo          3.0    ALTERE
# 7716   2016-06-27                               GBM          4.0        NC
# 7719   2004-08-17                             oligo          2.0        NC
# 7720   2004-08-17                             oligo          2.0        NC
# 7727   2007-10-08                             oligo          2.0        NC
# 7729   2017-01-26                               GBM          4.0    NORMAL
# 7732   2017-03-08                       astrocytome          3.0    NORMAL
# 7735   2017-03-09                             oligo          3.0    ALTERE
# 7738   2017-03-10                       astrocytome          3.0    NORMAL
# 7740   2017-01-24                               GBM          4.0    NORMAL
# 7755   2017-03-20                               GBM          4.0    NORMAL
#
#      Gene_Idh2 Gene_Htert_C228T Gene_Htert_C250T Gene_P53    Gene_Mgmt  \
# 2       NORMAL           NORMAL           NORMAL       NC          NaN
# 3           NC              NaN              NaN       NC          NaN
# 5          NaN           NORMAL           ALTERE   NORMAL  NON METHYLE
# 7          NaN           NORMAL           NORMAL   NORMAL  NON METHYLE
# 8       NORMAL           NORMAL           ALTERE   NORMAL          NaN
# 9       NORMAL           ALTERE           NORMAL   ALTERE  NON METHYLE
# 10      NORMAL           NORMAL           NORMAL   NORMAL          NaN
# 11         NaN           NORMAL           ALTERE       NC      METHYLE
# 12      NORMAL           ALTERE           NORMAL   NORMAL          NaN
# 14      NORMAL           ALTERE           NORMAL   NORMAL      METHYLE
# 15          NC              NaN              NaN       NC          NaN
# 16          NC              NaN              NaN       NC          NaN
# 17      NORMAL           ALTERE           NORMAL   NORMAL      METHYLE
# 18      NORMAL           NORMAL           NORMAL       NC      METHYLE
# 19      NORMAL           NORMAL           NORMAL       NC      METHYLE
# 20      NORMAL              NaN              NaN   NORMAL          NaN
# 24         NaN           NORMAL           NORMAL   NORMAL          NaN
# 25      NORMAL           NORMAL           NORMAL       NC          NaN
# 27         NaN           NORMAL           ALTERE   NORMAL          NaN
# 28         NaN           ALTERE           NORMAL   NORMAL      METHYLE
# 30      NORMAL              NaN              NaN       NC          NaN
# 31         NaN           NORMAL           NORMAL       NC          NaN
# 34          NC              NaN              NaN       NC          NaN
# 35         NaN           NORMAL           NORMAL   NORMAL      METHYLE
# 36         NaN           ALTERE           NORMAL   NORMAL  NON METHYLE
# 37      NORMAL           ALTERE           NORMAL      NaN  NON METHYLE
# 40          NC              NaN              NaN       NC          NaN
# 45         NaN           NORMAL           NORMAL      NaN      METHYLE
# 50      NORMAL           NORMAL           NORMAL       NC          NaN
# 51      NORMAL           NORMAL           NORMAL       NC          NaN
# ...        ...              ...              ...      ...          ...
# 7685    NORMAL           NORMAL           NORMAL   NORMAL          NaN
# 7689    NORMAL               NC               NC       NC          NaN
# 7690    NORMAL           NORMAL           ALTERE   NORMAL          NaN
# 7691    NORMAL           NORMAL           ALTERE   NORMAL          NaN
# 7692    NORMAL           NORMAL           NORMAL   ALTERE          NaN
# 7693    NORMAL               NC               NC       NC      METHYLE
# 7694        NC               NC               NC       NC          NaN
# 7695    NORMAL           ALTERE           NORMAL       NC          NaN
# 7696    NORMAL           ALTERE           NORMAL   NORMAL          NaN
# 7697        NC               NC               NC       NC          NaN
# 7698    NORMAL           NORMAL           ALTERE      NaN          NaN
# 7700    NORMAL           NORMAL           NORMAL       NC          NaN
# 7701    NORMAL           NORMAL           NORMAL      NaN          NaN
# 7704        NC               NC               NC       NC          NaN
# 7707    NORMAL           NORMAL           NORMAL   NORMAL          NaN
# 7709        NC               NC               NC       NC          NaN
# 7711    NORMAL           NORMAL           NORMAL   ALTERE          NaN
# 7713        NC               NC               NC       NC          NaN
# 7714    NORMAL           ALTERE           NORMAL   NORMAL          NaN
# 7715    NORMAL           NORMAL           ALTERE   NORMAL          NaN
# 7716        NC               NC               NC       NC          NaN
# 7719        NC              NaN              NaN       NC          NaN
# 7720        NC              NaN              NaN       NC          NaN
# 7727        NC              NaN              NaN       NC          NaN
# 7729    NORMAL               NC               NC       NC          NaN
# 7732    NORMAL           ALTERE           NORMAL       NC          NaN
# 7735    NORMAL           NORMAL           ALTERE   NORMAL          NaN
# 7738    NORMAL           NORMAL           NORMAL       NC          NaN
# 7740    NORMAL           ALTERE           NORMAL       NC          NaN
# 7755    NORMAL           NORMAL           ALTERE   ALTERE          NaN
#
#      Gene_Egfr Gene_Mdm2 Gene_Cdk4 Gene_P16       Gene_Ihc_Atrx  Gene_Ch1P  \
# 2       NORMAL       NaN       NaN      NaN                 NaN  NON PERTE
# 3          NaN       NaN       NaN      NaN                 NaN        NaN
# 5       NORMAL    NORMAL    NORMAL   DELETE                 NaN    PARTIEL
# 7       NORMAL    NORMAL    NORMAL   NORMAL                 NaN  NON PERTE
# 8     AMPLIFIE    NORMAL    NORMAL   NORMAL                 NaN       GAIN
# 9     AMPLIFIE    NORMAL    NORMAL   DELETE                 NaN    PARTIEL
# 10      NORMAL    NORMAL    NORMAL   DELETE                 NaN    PARTIEL
# 11      NORMAL    NORMAL    NORMAL   NORMAL                 NaN  NON PERTE
# 12      NORMAL       NaN       NaN      NaN                 NaN  NON PERTE
# 14    AMPLIFIE    NORMAL    NORMAL   DELETE                 NaN    PARTIEL
# 15         NaN       NaN       NaN      NaN                 NaN        NaN
# 16         NaN       NaN       NaN      NaN                 NaN        NaN
# 17    AMPLIFIE    NORMAL    NORMAL   DELETE                 NaN  NON PERTE
# 18         NaN       NaN       NaN      NaN                 NaN  NON PERTE
# 19         NaN       NaN       NaN      NaN                 NaN  NON PERTE
# 20      NORMAL    NORMAL    NORMAL   NORMAL                 NaN      PERDU
# 24         NaN       NaN       NaN      NaN                 NaN  NON PERTE
# 25         NaN       NaN       NaN      NaN                 NaN        NaN
# 27      NORMAL    NORMAL    NORMAL   NORMAL                 NaN    PARTIEL
# 28      NORMAL    NORMAL    NORMAL   DELETE                 NaN  NON PERTE
# 30         NaN       NaN       NaN      NaN                 NaN        NaN
# 31      NORMAL    NORMAL    NORMAL   NORMAL                 NaN  NON PERTE
# 34         NaN       NaN       NaN      NaN                 NaN        NaN
# 35      NORMAL    NORMAL    NORMAL   DELETE                 NaN  NON PERTE
# 36      NORMAL    NORMAL    NORMAL   DELETE                 NaN  NON PERTE
# 37      NORMAL    NORMAL    NORMAL   NORMAL                 NaN  NON PERTE
# 40         NaN       NaN       NaN      NaN                 NaN        NaN
# 45      NORMAL    NORMAL  AMPLIFIE   NORMAL                 NaN  NON PERTE
# 50      NORMAL    NORMAL    NORMAL   NORMAL                 NaN  NON PERTE
# 51      NORMAL    NORMAL    NORMAL   NORMAL                 NaN  NON PERTE
# ...        ...       ...       ...      ...                 ...        ...
# 7685    NORMAL    NORMAL    NORMAL   NORMAL                 NaN      PERDU
# 7689       NaN       NaN       NaN      NaN            Maintien        NaN
# 7690    NORMAL    NORMAL    NORMAL   NORMAL            Maintien      PERDU
# 7691    NORMAL    NORMAL    NORMAL   NORMAL            Maintien      PERDU
# 7692    NORMAL    NORMAL    NORMAL   NORMAL  Extinction diffuse  NON PERTE
# 7693       NaN    NORMAL       NaN      NaN            Maintien        NaN
# 7694       NaN       NaN       NaN      NaN            Maintien        NaN
# 7695       NaN       NaN       NaN      NaN            Maintien        NaN
# 7696  AMPLIFIE    NORMAL    NORMAL   NORMAL            Maintien  NON PERTE
# 7697       NaN       NaN       NaN      NaN            Maintien        NaN
# 7698    NORMAL    NORMAL    NORMAL   NORMAL                 NaN      PERDU
# 7700    NORMAL    NORMAL    NORMAL   NORMAL                 NaN       GAIN
# 7701    NORMAL    NORMAL    NORMAL   NORMAL                 NaN    PARTIEL
# 7704       NaN       NaN       NaN      NaN            Maintien        NaN
# 7707    NORMAL    NORMAL    NORMAL   NORMAL            Maintien       GAIN
# 7709       NaN       NaN       NaN      NaN            Maintien        NaN
# 7711    NORMAL    NORMAL    NORMAL   NORMAL                 NaN  NON PERTE
# 7713       NaN       NaN       NaN      NaN                 NaN        NaN
# 7714    NORMAL    NORMAL    NORMAL   NORMAL            Maintien    PARTIEL
# 7715    NORMAL    NORMAL    NORMAL   NORMAL            Maintien      PERDU
# 7716       NaN       NaN       NaN      NaN            Maintien        NaN
# 7719       NaN       NaN       NaN      NaN                 NaN        NaN
# 7720       NaN       NaN       NaN      NaN                 NaN        NaN
# 7727       NaN       NaN       NaN      NaN                 NaN        NaN
# 7729       NaN       NaN       NaN      NaN            Maintien        NaN
# 7732       NaN       NaN       NaN      NaN                 NaN        NaN
# 7735    NORMAL    NORMAL    NORMAL   NORMAL            Maintien      PERDU
# 7738       NaN       NaN       NaN      NaN  Extinction diffuse        NaN
# 7740       NaN       NaN       NaN      NaN            Maintien        NaN
# 7755    NORMAL    NORMAL    NORMAL   NORMAL            Maintien  NON PERTE
#
#      Gene_Ch19Q Gene_Ch10P Gene_Ch10Q  Gene_Ch9P  Gene_Ch9Q  \
# 2     NON PERTE  NON PERTE      PERDU  NON PERTE        NaN
# 3           NaN        NaN        NaN        NaN        NaN
# 5       PARTIEL      PERDU      PERDU      PERDU        NaN
# 7     NON PERTE  NON PERTE      PERDU        NaN        NaN
# 8     NON PERTE  NON PERTE      PERDU  NON PERTE  NON PERTE
# 9     NON PERTE  NON PERTE      PERDU  NON PERTE  NON PERTE
# 10      PARTIEL        NaN      PERDU  NON PERTE        NaN
# 11    NON PERTE  NON PERTE      PERDU  NON PERTE        NaN
# 12          NaN  NON PERTE  NON PERTE  NON PERTE        NaN
# 14    NON PERTE      PERDU      PERDU    PARTIEL  NON PERTE
# 15          NaN        NaN        NaN        NaN        NaN
# 16          NaN        NaN        NaN        NaN        NaN
# 17        PERDU      PERDU      PERDU      PERDU        NaN
# 18          NaN        NaN  NON PERTE      PERDU        NaN
# 19          NaN        NaN  NON PERTE      PERDU        NaN
# 20        PERDU  NON PERTE  NON PERTE    PARTIEL        NaN
# 24    NON PERTE  NON PERTE  NON PERTE  NON PERTE        NaN
# 25          NaN        NaN        NaN        NaN        NaN
# 27      PARTIEL      PERDU      PERDU  NON PERTE        NaN
# 28    NON PERTE      PERDU      PERDU      PERDU  NON PERTE
# 30          NaN        NaN        NaN        NaN        NaN
# 31    NON PERTE      PERDU      PERDU      PERDU        NaN
# 34          NaN        NaN        NaN        NaN        NaN
# 35        PERDU        NaN  NON PERTE  NON PERTE        NaN
# 36        PERDU  NON PERTE  NON PERTE      PERDU        NaN
# 37      PARTIEL        NaN  NON PERTE  NON PERTE        NaN
# 40          NaN        NaN        NaN        NaN        NaN
# 45    NON PERTE  NON PERTE  NON PERTE  NON PERTE        NaN
# 50          NaN        NaN        NaN      PERDU        NaN
# 51          NaN        NaN        NaN      PERDU        NaN
# ...         ...        ...        ...        ...        ...
# 7685      PERDU  NON PERTE  NON PERTE    PARTIEL  NON PERTE
# 7689        NaN        NaN        NaN        NaN        NaN
# 7690      PERDU  NON PERTE  NON PERTE      PERDU  NON PERTE
# 7691      PERDU  NON PERTE  NON PERTE  NON PERTE  NON PERTE
# 7692  NON PERTE  NON PERTE  NON PERTE  NON PERTE        NaN
# 7693        NaN        NaN        NaN        NaN        NaN
# 7694        NaN        NaN        NaN        NaN        NaN
# 7695        NaN        NaN        NaN        NaN        NaN
# 7696  NON PERTE  NON PERTE  NON PERTE  NON PERTE        NaN
# 7697        NaN        NaN        NaN        NaN        NaN
# 7698      PERDU        NaN  NON PERTE        NaN        NaN
# 7700      PERDU  NON PERTE  NON PERTE  NON PERTE  NON PERTE
# 7701  NON PERTE    PARTIEL      PERDU  NON PERTE  NON PERTE
# 7704        NaN        NaN        NaN        NaN        NaN
# 7707       GAIN  NON PERTE  NON PERTE  NON PERTE        NaN
# 7709        NaN        NaN        NaN        NaN        NaN
# 7711  NON PERTE    PARTIEL    PARTIEL      PERDU        NaN
# 7713        NaN        NaN        NaN        NaN        NaN
# 7714    PARTIEL      PERDU      PERDU       GAIN        NaN
# 7715      PERDU  NON PERTE  NON PERTE  NON PERTE  NON PERTE
# 7716        NaN        NaN        NaN        NaN        NaN
# 7719        NaN        NaN        NaN        NaN        NaN
# 7720        NaN        NaN        NaN        NaN        NaN
# 7727        NaN        NaN        NaN        NaN        NaN
# 7729        NaN        NaN        NaN        NaN        NaN
# 7732        NaN        NaN        NaN        NaN        NaN
# 7735      PERDU  NON PERTE  NON PERTE      PERDU        NaN
# 7738        NaN        NaN        NaN        NaN        NaN
# 7740        NaN        NaN        NaN        NaN        NaN
# 7755  NON PERTE       GAIN       GAIN  NON PERTE        NaN
#
#             Tumor_Location Tumor_Position Clinical_evolution Surgery_type  \
# 2             sus-T hémisp              G             TT ini    partielle
# 3              non précisé    non précisé             TT ini      exérèse
# 5             sus-T hémisp              G             TT ini       aucune
# 7             sus-T hémisp              D             TT ini    partielle
# 8             sus-T hémisp              D             TT ini      exérèse
# 9             sus-T hémisp              G             TT ini      exérèse
# 10             non précisé              G             TT ini      exérèse
# 11             non précisé    non précisé             TT ini      exérèse
# 12            sus-T hémisp              G             TT ini    partielle
# 14            sus-T hémisp              G             TT ini    partielle
# 15            sus-T hémisp              D             TT ini      exérèse
# 16            sus-T hémisp              D             TT ini      exérèse
# 17             non précisé              D             TT ini      exérèse
# 18    sus-T hémisp+profond      bilatéral             TT ini    partielle
# 19    sus-T hémisp+profond      bilatéral             TT ini    partielle
# 20             non précisé      bilatéral             TT ini    partielle
# 24            sus-T hémisp              G             TT ini    partielle
# 25            sus-T hémisp              D             TT ini      exérèse
# 27             non précisé              G             TT ini      exérèse
# 28             non précisé              D             TT ini      exérèse
# 30             non précisé              G             TT ini       aucune
# 31    sus-T hémisp+profond    non précisé             TT ini    partielle
# 34            sus-T hémisp              D             TT ini    partielle
# 35            sus-T hémisp              D             TT ini    partielle
# 36            sus-T hémisp              D             TT ini       aucune
# 37            sus-T hémisp              D             TT ini      exérèse
# 40             non précisé              G             TT ini      exérèse
# 45            sus-T hémisp              D             TT ini      exérèse
# 50            sus-T hémisp              D             TT ini    partielle
# 51            sus-T hémisp              D             TT ini    partielle
# ...                    ...            ...                ...          ...
# 7685           non précisé    non précisé             TT ini       aucune
# 7689          sus-T hémisp              D             TT ini    partielle
# 7690               Frontal              G             TT ini      exérèse
# 7691          sus-T hémisp              D             TT ini    partielle
# 7692  sus-T hémisp+profond              D             TT ini      exérèse
# 7693          sus-T hémisp              D             TT ini    partielle
# 7694          sus-T hémisp              G             TT ini    partielle
# 7695         sus-T profond              D             TT ini      biopsie
# 7696          sus-T hémisp      bilatéral             TT ini      biopsie
# 7697          sus-T hémisp              D             TT ini    partielle
# 7698          sus-T hémisp              D             TT ini    partielle
# 7700          sus-T hémisp              G             TT ini    partielle
# 7701          sus-T hémisp              D             TT ini      biopsie
# 7704          sus-T hémisp              D             TT ini      biopsie
# 7707         sus-T profond              G             TT ini      biopsie
# 7709          sus-T hémisp              D             TT ini    partielle
# 7711          sus-T hémisp              G             TT ini      exérèse
# 7713          sus-T hémisp              G             TT ini      biopsie
# 7714          sus-T hémisp              G             TT ini    partielle
# 7715          sus-T hémisp              D             TT ini    partielle
# 7716         sus-T profond            NaN             TT ini      biopsie
# 7719         sus-T profond              G             TT ini      biopsie
# 7720         sus-T profond              G             TT ini      biopsie
# 7727          sus-T hémisp              D             TT ini    partielle
# 7729          sus-T hémisp              D             TT ini      exérèse
# 7732          sus-T hémisp              D             TT ini      biopsie
# 7735          sus-T hémisp              G             TT ini    partielle
# 7738                   NaN      bilatéral             TT ini      biopsie
# 7740          sus-T hémisp              D             TT ini    partielle
# 7755  sus-T hémisp+profond         médian             TT ini      biopsie
#
#         Rx_date Chemo_start_date  Age_surgery  life_expectancy
# 2    1992-05-01       1992-05-01         42.0             30.0
# 3    1986-04-01              NaT         28.0           2069.0
# 5    1990-03-14              NaT         59.0            393.0
# 7    1989-12-18              NaT         61.0            398.0
# 8           NaT              NaT         58.0            433.0
# 9    1991-11-19              NaT         56.0            143.0
# 10   1990-12-01              NaT         69.0            408.0
# 11          NaT              NaT         66.0              7.0
# 12   1992-03-01              NaT         61.0            316.0
# 14   1993-08-11       1993-08-05         43.0            571.0
# 15   1990-11-06       1990-07-19         58.0           1172.0
# 16   1990-11-06       1990-12-07         58.0           1172.0
# 17   1992-02-15       1992-02-15         49.0            701.0
# 18   1989-12-26       1990-02-16         32.0            521.0
# 19   1989-12-26       1990-10-03         32.0            521.0
# 20   1991-01-01       1990-12-01         60.0            194.0
# 24   1990-11-01              NaT         39.0           1255.0
# 25          NaT              NaT         34.0            169.0
# 27   1989-12-15              NaT         49.0            666.0
# 28   1989-05-01              NaT         72.0            355.0
# 30   1994-05-01              NaT         24.0             60.0
# 31   1989-11-20       1989-11-01         45.0             96.0
# 34   1989-05-01              NaT         15.0            566.0
# 35   1989-09-18       1989-09-01         62.0            320.0
# 36   1992-05-01              NaT         22.0            175.0
# 37   1991-03-18       1991-02-28         49.0            997.0
# 40   1992-01-01              NaT         41.0            220.0
# 45   1992-12-14       1992-12-03         60.0            478.0
# 50   1990-05-11       1990-07-01         63.0           1269.0
# 51   1990-05-11       1991-01-07         63.0           1269.0
# ...         ...              ...          ...              ...
# 7685        NaT              NaT         52.0              NaN
# 7689 2016-10-20       2016-12-24         63.0              NaN
# 7690 2016-09-01       2016-10-20         49.0              NaN
# 7691        NaT       2016-10-14         57.0              NaN
# 7692        NaT              NaT         20.0              NaN
# 7693 2015-11-20       2016-02-03         72.0              NaN
# 7694 2016-08-08       2016-10-25         53.0              NaN
# 7695        NaT              NaT         53.0              NaN
# 7696 2016-08-19       2016-11-16         48.0            310.0
# 7697 2017-03-20       2017-02-22         72.0              NaN
# 7698        NaT       2006-02-10         30.0              NaN
# 7700 2013-05-30       2013-08-22         38.0              NaN
# 7701 2007-01-20              NaT         44.0              NaN
# 7704 2016-11-14       2017-01-24         69.0              NaN
# 7707 2016-09-07       2017-02-01         58.0              NaN
# 7709 2016-06-01       2016-08-01         69.0              NaN
# 7711 2016-10-10       2017-01-02         24.0              NaN
# 7713 2016-06-29       2016-09-13         47.0              NaN
# 7714 2016-05-10       2016-06-25         46.0              NaN
# 7715 2016-06-01       2016-08-23         50.0              NaN
# 7716 2016-08-11       2016-10-25         59.0              NaN
# 7719        NaT       2004-10-07         30.0              NaN
# 7720        NaT       2005-04-01         30.0              NaN
# 7727        NaT              NaT         22.0              NaN
# 7729 2017-03-01       2017-03-09         45.0              NaN
# 7732        NaT              NaT         68.0              NaN
# 7735        NaT              NaT         61.0              NaN
# 7738 2017-04-26              NaT         75.0              NaN
# 7740 2017-03-15       2017-03-15         60.0              NaN
# 7755 2017-04-13              NaT         49.0              NaN
#
# [2430 rows x 33 columns]

# %%
#Marc comment recode Tumor_Location
# A-sus-T hémisp            3550
# A-sus-T hémisp+profond     524
# N-non précisé              257
# A-sus-T profond            209
# A-Frontal                  134
# B-tronc cérébral            32
# B-cervelet                  31
# C-ventriculaire             20
# autre                     18
# B-moelle/rachis             10
# A-Rolandique                 3

df_clean_test['Tumor_Location'].replace({"sus-T hémisp": "A", "sus-T hémisp+profond":"A",
                                "non précisé":"N", "sus-T profond": "A",
                                "Frontal": "A", "tronc cérébral": "B",
                                "cervelet": "B", "ventriculaire":"C",
                                "moelle/rachis":"B", "Rolandique":"A"}, inplace=True)
df_clean_test
# Out:
#               ID Gender        DoB  Dernieres_nouvelles Death_date  \
# 2             10      M 1949-11-05                  NaN 1992-05-15
# 3             11      M 1958-07-29                  NaN 1991-11-15
# 5             12      F 1930-12-07                  NaN 1991-03-13
# 7             13      M 1928-11-17                  NaN 1990-12-20
# 8             14      F 1934-07-17                  NaN 1993-03-30
# 9             15      M 1936-03-22                  NaN 1992-03-14
# 10            16      M 1922-04-18                  NaN 1991-12-22
# 11            17      M 1924-04-12                  NaN 1990-04-04
# 12            18      F 1931-06-05                  NaN 1992-12-18
# 14            22      M 1950-05-10                  NaN 1995-01-29
# 15            23      F 1932-10-09                  NaN 1993-09-10
# 16            23      F 1932-10-09                  NaN 1993-09-10
# 17            24      M 1943-03-04                  NaN 1993-12-15
# 18            25      M 1957-06-16                  NaN 1991-04-13
# 19            25      M 1957-06-16                  NaN 1991-04-13
# 20            26      M 1930-07-07                  NaN 1991-05-15
# 24            30      M 1952-02-01                  NaN 1994-03-03
# 25            31      M 1957-11-25                  NaN 1992-10-20
# 27            34      F 1939-06-30                  NaN 1990-09-15
# 28            35      F 1917-06-04                  NaN 1990-04-15
# 30            36      F 1972-12-01                  NaN 1996-10-19
# 31            37      M 1945-01-01                  NaN 1989-12-31
# 34            39      F 1974-06-21                  NaN 1990-10-30
# 35            40      M 1927-04-16                  NaN 1990-07-09
# 36            41      M 1970-04-07                  NaN 1992-09-01
# 37            42      F 1942-08-14                  NaN 1993-11-08
# 40            44      M 1951-03-28                  NaN 1992-08-06
# 45            47      F 1932-05-26                  NaN 1994-03-10
# 50            49      M 1927-04-07                  NaN 1993-10-01
# 51            49      M 1927-04-07                  NaN 1993-10-01
# ...          ...    ...        ...                  ...        ...
# 7685  8009475251      F 1956-12-25               2017.0        NaT
# 7689  8009496494      F 1953-07-01               2017.0        NaT
# 7690  8009502080      M 1967-02-03               2017.0        NaT
# 7691  8009502097      F 1959-04-19               2017.0        NaT
# 7692  8009504238      M 1996-12-28               2017.0        NaT
# 7693  8009508609      M 1944-02-26               2017.0        NaT
# 7694  8009509396      M 1963-12-08               2017.0        NaT
# 7695  8009510265      F 1962-06-07               2017.0        NaT
# 7696  8009536357      M 1968-04-16                  NaN 2017-05-13
# 7697  8009538232      M 1945-01-01               2017.0        NaT
# 7698  8009545405      F 1975-09-30               2017.0        NaT
# 7700  8009547563      F 1974-09-11               2017.0        NaT
# 7701  8009558455      F 1962-08-12               2017.0        NaT
# 7704  8009583738      F 1947-03-30               2017.0        NaT
# 7707  8009588647      F 1958-06-26               2017.0        NaT
# 7709  8009606625      F 1947-03-27               2017.0        NaT
# 7711  8009619135      F 1993-02-08               2017.0        NaT
# 7713  8009630406      F 1968-12-22               2017.0        NaT
# 7714  8009631994      M 1970-07-28               2017.0        NaT
# 7715  8009633302      M 1965-11-07               2017.0        NaT
# 7716  8009635074      M 1957-01-07               2017.0        NaT
# 7719  8009636704      M 1974-04-12               2017.0        NaT
# 7720  8009636704      M 1974-04-12               2017.0        NaT
# 7727  8009657835      F 1985-08-30               2017.0        NaT
# 7729  8009669708      F 1971-08-19               2017.0        NaT
# 7732  8009694199      M 1948-10-14               2017.0        NaT
# 7735  8009712826      M 1956-01-01               2017.0        NaT
# 7738  8009724274      F 1942-07-30               2017.0        NaT
# 7740  8009728167      F 1957-02-22               2017.0        NaT
# 7755  8009823797      F 1968-01-16               2017.0        NaT
#
#      Surgery_date                        Tumor_type  Tumor_grade Gene_Idh1  \
# 2      1992-04-15                            gliome          3.0    ALTERE
# 3      1986-03-17                       astrocytome          2.0        NC
# 5      1990-02-13                               GBM          4.0    NORMAL
# 7      1989-11-17                               GBM          4.0    NORMAL
# 8      1992-01-22                               GBM          4.0    NORMAL
# 9      1991-10-23                               GBM          4.0    NORMAL
# 10     1990-11-09                               GBM          4.0    NORMAL
# 11     1990-03-28                               GBM          4.0    NORMAL
# 12     1992-02-06                       astrocytome          3.0    NORMAL
# 14     1993-07-07                               GBM          4.0    NORMAL
# 15     1990-06-26                       astrocytome          3.0        NC
# 16     1990-06-26                       astrocytome          3.0        NC
# 17     1992-01-14                            gliome          3.0    NORMAL
# 18     1989-11-08                       astrocytome          2.0    NORMAL
# 19     1989-11-08                       astrocytome          2.0    NORMAL
# 20     1990-11-02                             oligo          3.0    ALTERE
# 24     1990-09-25                       astrocytome          3.0    NORMAL
# 25     1992-05-04                             oligo          2.0    NORMAL
# 27     1988-11-18                               GBM          4.0    NORMAL
# 28     1989-04-25                               GBM          4.0    NORMAL
# 30     1996-08-20                            gliome          3.0    ALTERE
# 31     1989-09-26                               GBM          4.0    NORMAL
# 34     1989-04-12                       astrocytome          2.0        NC
# 35     1989-08-23                               GBM          4.0    NORMAL
# 36     1992-03-10                               GBM          4.0    NORMAL
# 37     1991-02-15                               GBM          4.0    NORMAL
# 40     1991-12-30                               GBM          4.0        NC
# 45     1992-11-17                               GBM          4.0    NORMAL
# 50     1990-04-11                             oligo          3.0    NORMAL
# 51     1990-04-11                             oligo          3.0    NORMAL
# ...           ...                               ...          ...       ...
# 7685   2008-08-27                             oligo          2.0    ALTERE
# 7689   2016-08-31                               GBM          4.0    NORMAL
# 7690   2016-05-03                            gliome          3.0    ALTERE
# 7691   2016-08-23                             oligo          3.0    ALTERE
# 7692   2017-02-06                       astrocytome          3.0    ALTERE
# 7693   2015-10-28                               GBM          4.0    NORMAL
# 7694   2016-06-08                               GBM          4.0        NC
# 7695   2015-09-29                               GBM          4.0    NORMAL
# 7696   2016-07-07                       astrocytome          3.0    NORMAL
# 7697   2016-12-29                               GBM          4.0    ALTERE
# 7698   2005-11-25                             oligo          3.0    ALTERE
# 7700   2013-01-22                               GBM          4.0    ALTERE
# 7701   2006-07-19  astrocytome gémistocytique (=A2)          2.0    ALTERE
# 7704   2016-09-20                               GBM          4.0        NC
# 7707   2016-05-20                       astrocytome          2.0    NORMAL
# 7709   2016-04-06                               GBM          4.0        NC
# 7711   2016-08-30                               GBM          4.0    NORMAL
# 7713   2016-04-28                               GBM          4.0        NC
# 7714   2016-02-18                               GBM          4.0    NORMAL
# 7715   2016-03-17                             oligo          3.0    ALTERE
# 7716   2016-06-27                               GBM          4.0        NC
# 7719   2004-08-17                             oligo          2.0        NC
# 7720   2004-08-17                             oligo          2.0        NC
# 7727   2007-10-08                             oligo          2.0        NC
# 7729   2017-01-26                               GBM          4.0    NORMAL
# 7732   2017-03-08                       astrocytome          3.0    NORMAL
# 7735   2017-03-09                             oligo          3.0    ALTERE
# 7738   2017-03-10                       astrocytome          3.0    NORMAL
# 7740   2017-01-24                               GBM          4.0    NORMAL
# 7755   2017-03-20                               GBM          4.0    NORMAL
#
#      Gene_Idh2 Gene_Htert_C228T Gene_Htert_C250T Gene_P53    Gene_Mgmt  \
# 2       NORMAL           NORMAL           NORMAL       NC          NaN
# 3           NC              NaN              NaN       NC          NaN
# 5          NaN           NORMAL           ALTERE   NORMAL  NON METHYLE
# 7          NaN           NORMAL           NORMAL   NORMAL  NON METHYLE
# 8       NORMAL           NORMAL           ALTERE   NORMAL          NaN
# 9       NORMAL           ALTERE           NORMAL   ALTERE  NON METHYLE
# 10      NORMAL           NORMAL           NORMAL   NORMAL          NaN
# 11         NaN           NORMAL           ALTERE       NC      METHYLE
# 12      NORMAL           ALTERE           NORMAL   NORMAL          NaN
# 14      NORMAL           ALTERE           NORMAL   NORMAL      METHYLE
# 15          NC              NaN              NaN       NC          NaN
# 16          NC              NaN              NaN       NC          NaN
# 17      NORMAL           ALTERE           NORMAL   NORMAL      METHYLE
# 18      NORMAL           NORMAL           NORMAL       NC      METHYLE
# 19      NORMAL           NORMAL           NORMAL       NC      METHYLE
# 20      NORMAL              NaN              NaN   NORMAL          NaN
# 24         NaN           NORMAL           NORMAL   NORMAL          NaN
# 25      NORMAL           NORMAL           NORMAL       NC          NaN
# 27         NaN           NORMAL           ALTERE   NORMAL          NaN
# 28         NaN           ALTERE           NORMAL   NORMAL      METHYLE
# 30      NORMAL              NaN              NaN       NC          NaN
# 31         NaN           NORMAL           NORMAL       NC          NaN
# 34          NC              NaN              NaN       NC          NaN
# 35         NaN           NORMAL           NORMAL   NORMAL      METHYLE
# 36         NaN           ALTERE           NORMAL   NORMAL  NON METHYLE
# 37      NORMAL           ALTERE           NORMAL      NaN  NON METHYLE
# 40          NC              NaN              NaN       NC          NaN
# 45         NaN           NORMAL           NORMAL      NaN      METHYLE
# 50      NORMAL           NORMAL           NORMAL       NC          NaN
# 51      NORMAL           NORMAL           NORMAL       NC          NaN
# ...        ...              ...              ...      ...          ...
# 7685    NORMAL           NORMAL           NORMAL   NORMAL          NaN
# 7689    NORMAL               NC               NC       NC          NaN
# 7690    NORMAL           NORMAL           ALTERE   NORMAL          NaN
# 7691    NORMAL           NORMAL           ALTERE   NORMAL          NaN
# 7692    NORMAL           NORMAL           NORMAL   ALTERE          NaN
# 7693    NORMAL               NC               NC       NC      METHYLE
# 7694        NC               NC               NC       NC          NaN
# 7695    NORMAL           ALTERE           NORMAL       NC          NaN
# 7696    NORMAL           ALTERE           NORMAL   NORMAL          NaN
# 7697        NC               NC               NC       NC          NaN
# 7698    NORMAL           NORMAL           ALTERE      NaN          NaN
# 7700    NORMAL           NORMAL           NORMAL       NC          NaN
# 7701    NORMAL           NORMAL           NORMAL      NaN          NaN
# 7704        NC               NC               NC       NC          NaN
# 7707    NORMAL           NORMAL           NORMAL   NORMAL          NaN
# 7709        NC               NC               NC       NC          NaN
# 7711    NORMAL           NORMAL           NORMAL   ALTERE          NaN
# 7713        NC               NC               NC       NC          NaN
# 7714    NORMAL           ALTERE           NORMAL   NORMAL          NaN
# 7715    NORMAL           NORMAL           ALTERE   NORMAL          NaN
# 7716        NC               NC               NC       NC          NaN
# 7719        NC              NaN              NaN       NC          NaN
# 7720        NC              NaN              NaN       NC          NaN
# 7727        NC              NaN              NaN       NC          NaN
# 7729    NORMAL               NC               NC       NC          NaN
# 7732    NORMAL           ALTERE           NORMAL       NC          NaN
# 7735    NORMAL           NORMAL           ALTERE   NORMAL          NaN
# 7738    NORMAL           NORMAL           NORMAL       NC          NaN
# 7740    NORMAL           ALTERE           NORMAL       NC          NaN
# 7755    NORMAL           NORMAL           ALTERE   ALTERE          NaN
#
#      Gene_Egfr Gene_Mdm2 Gene_Cdk4 Gene_P16       Gene_Ihc_Atrx  Gene_Ch1P  \
# 2       NORMAL       NaN       NaN      NaN                 NaN  NON PERTE
# 3          NaN       NaN       NaN      NaN                 NaN        NaN
# 5       NORMAL    NORMAL    NORMAL   DELETE                 NaN    PARTIEL
# 7       NORMAL    NORMAL    NORMAL   NORMAL                 NaN  NON PERTE
# 8     AMPLIFIE    NORMAL    NORMAL   NORMAL                 NaN       GAIN
# 9     AMPLIFIE    NORMAL    NORMAL   DELETE                 NaN    PARTIEL
# 10      NORMAL    NORMAL    NORMAL   DELETE                 NaN    PARTIEL
# 11      NORMAL    NORMAL    NORMAL   NORMAL                 NaN  NON PERTE
# 12      NORMAL       NaN       NaN      NaN                 NaN  NON PERTE
# 14    AMPLIFIE    NORMAL    NORMAL   DELETE                 NaN    PARTIEL
# 15         NaN       NaN       NaN      NaN                 NaN        NaN
# 16         NaN       NaN       NaN      NaN                 NaN        NaN
# 17    AMPLIFIE    NORMAL    NORMAL   DELETE                 NaN  NON PERTE
# 18         NaN       NaN       NaN      NaN                 NaN  NON PERTE
# 19         NaN       NaN       NaN      NaN                 NaN  NON PERTE
# 20      NORMAL    NORMAL    NORMAL   NORMAL                 NaN      PERDU
# 24         NaN       NaN       NaN      NaN                 NaN  NON PERTE
# 25         NaN       NaN       NaN      NaN                 NaN        NaN
# 27      NORMAL    NORMAL    NORMAL   NORMAL                 NaN    PARTIEL
# 28      NORMAL    NORMAL    NORMAL   DELETE                 NaN  NON PERTE
# 30         NaN       NaN       NaN      NaN                 NaN        NaN
# 31      NORMAL    NORMAL    NORMAL   NORMAL                 NaN  NON PERTE
# 34         NaN       NaN       NaN      NaN                 NaN        NaN
# 35      NORMAL    NORMAL    NORMAL   DELETE                 NaN  NON PERTE
# 36      NORMAL    NORMAL    NORMAL   DELETE                 NaN  NON PERTE
# 37      NORMAL    NORMAL    NORMAL   NORMAL                 NaN  NON PERTE
# 40         NaN       NaN       NaN      NaN                 NaN        NaN
# 45      NORMAL    NORMAL  AMPLIFIE   NORMAL                 NaN  NON PERTE
# 50      NORMAL    NORMAL    NORMAL   NORMAL                 NaN  NON PERTE
# 51      NORMAL    NORMAL    NORMAL   NORMAL                 NaN  NON PERTE
# ...        ...       ...       ...      ...                 ...        ...
# 7685    NORMAL    NORMAL    NORMAL   NORMAL                 NaN      PERDU
# 7689       NaN       NaN       NaN      NaN            Maintien        NaN
# 7690    NORMAL    NORMAL    NORMAL   NORMAL            Maintien      PERDU
# 7691    NORMAL    NORMAL    NORMAL   NORMAL            Maintien      PERDU
# 7692    NORMAL    NORMAL    NORMAL   NORMAL  Extinction diffuse  NON PERTE
# 7693       NaN    NORMAL       NaN      NaN            Maintien        NaN
# 7694       NaN       NaN       NaN      NaN            Maintien        NaN
# 7695       NaN       NaN       NaN      NaN            Maintien        NaN
# 7696  AMPLIFIE    NORMAL    NORMAL   NORMAL            Maintien  NON PERTE
# 7697       NaN       NaN       NaN      NaN            Maintien        NaN
# 7698    NORMAL    NORMAL    NORMAL   NORMAL                 NaN      PERDU
# 7700    NORMAL    NORMAL    NORMAL   NORMAL                 NaN       GAIN
# 7701    NORMAL    NORMAL    NORMAL   NORMAL                 NaN    PARTIEL
# 7704       NaN       NaN       NaN      NaN            Maintien        NaN
# 7707    NORMAL    NORMAL    NORMAL   NORMAL            Maintien       GAIN
# 7709       NaN       NaN       NaN      NaN            Maintien        NaN
# 7711    NORMAL    NORMAL    NORMAL   NORMAL                 NaN  NON PERTE
# 7713       NaN       NaN       NaN      NaN                 NaN        NaN
# 7714    NORMAL    NORMAL    NORMAL   NORMAL            Maintien    PARTIEL
# 7715    NORMAL    NORMAL    NORMAL   NORMAL            Maintien      PERDU
# 7716       NaN       NaN       NaN      NaN            Maintien        NaN
# 7719       NaN       NaN       NaN      NaN                 NaN        NaN
# 7720       NaN       NaN       NaN      NaN                 NaN        NaN
# 7727       NaN       NaN       NaN      NaN                 NaN        NaN
# 7729       NaN       NaN       NaN      NaN            Maintien        NaN
# 7732       NaN       NaN       NaN      NaN                 NaN        NaN
# 7735    NORMAL    NORMAL    NORMAL   NORMAL            Maintien      PERDU
# 7738       NaN       NaN       NaN      NaN  Extinction diffuse        NaN
# 7740       NaN       NaN       NaN      NaN            Maintien        NaN
# 7755    NORMAL    NORMAL    NORMAL   NORMAL            Maintien  NON PERTE
#
#      Gene_Ch19Q Gene_Ch10P Gene_Ch10Q  Gene_Ch9P  Gene_Ch9Q Tumor_Location  \
# 2     NON PERTE  NON PERTE      PERDU  NON PERTE        NaN              A
# 3           NaN        NaN        NaN        NaN        NaN              N
# 5       PARTIEL      PERDU      PERDU      PERDU        NaN              A
# 7     NON PERTE  NON PERTE      PERDU        NaN        NaN              A
# 8     NON PERTE  NON PERTE      PERDU  NON PERTE  NON PERTE              A
# 9     NON PERTE  NON PERTE      PERDU  NON PERTE  NON PERTE              A
# 10      PARTIEL        NaN      PERDU  NON PERTE        NaN              N
# 11    NON PERTE  NON PERTE      PERDU  NON PERTE        NaN              N
# 12          NaN  NON PERTE  NON PERTE  NON PERTE        NaN              A
# 14    NON PERTE      PERDU      PERDU    PARTIEL  NON PERTE              A
# 15          NaN        NaN        NaN        NaN        NaN              A
# 16          NaN        NaN        NaN        NaN        NaN              A
# 17        PERDU      PERDU      PERDU      PERDU        NaN              N
# 18          NaN        NaN  NON PERTE      PERDU        NaN              A
# 19          NaN        NaN  NON PERTE      PERDU        NaN              A
# 20        PERDU  NON PERTE  NON PERTE    PARTIEL        NaN              N
# 24    NON PERTE  NON PERTE  NON PERTE  NON PERTE        NaN              A
# 25          NaN        NaN        NaN        NaN        NaN              A
# 27      PARTIEL      PERDU      PERDU  NON PERTE        NaN              N
# 28    NON PERTE      PERDU      PERDU      PERDU  NON PERTE              N
# 30          NaN        NaN        NaN        NaN        NaN              N
# 31    NON PERTE      PERDU      PERDU      PERDU        NaN              A
# 34          NaN        NaN        NaN        NaN        NaN              A
# 35        PERDU        NaN  NON PERTE  NON PERTE        NaN              A
# 36        PERDU  NON PERTE  NON PERTE      PERDU        NaN              A
# 37      PARTIEL        NaN  NON PERTE  NON PERTE        NaN              A
# 40          NaN        NaN        NaN        NaN        NaN              N
# 45    NON PERTE  NON PERTE  NON PERTE  NON PERTE        NaN              A
# 50          NaN        NaN        NaN      PERDU        NaN              A
# 51          NaN        NaN        NaN      PERDU        NaN              A
# ...         ...        ...        ...        ...        ...            ...
# 7685      PERDU  NON PERTE  NON PERTE    PARTIEL  NON PERTE              N
# 7689        NaN        NaN        NaN        NaN        NaN              A
# 7690      PERDU  NON PERTE  NON PERTE      PERDU  NON PERTE              A
# 7691      PERDU  NON PERTE  NON PERTE  NON PERTE  NON PERTE              A
# 7692  NON PERTE  NON PERTE  NON PERTE  NON PERTE        NaN              A
# 7693        NaN        NaN        NaN        NaN        NaN              A
# 7694        NaN        NaN        NaN        NaN        NaN              A
# 7695        NaN        NaN        NaN        NaN        NaN              A
# 7696  NON PERTE  NON PERTE  NON PERTE  NON PERTE        NaN              A
# 7697        NaN        NaN        NaN        NaN        NaN              A
# 7698      PERDU        NaN  NON PERTE        NaN        NaN              A
# 7700      PERDU  NON PERTE  NON PERTE  NON PERTE  NON PERTE              A
# 7701  NON PERTE    PARTIEL      PERDU  NON PERTE  NON PERTE              A
# 7704        NaN        NaN        NaN        NaN        NaN              A
# 7707       GAIN  NON PERTE  NON PERTE  NON PERTE        NaN              A
# 7709        NaN        NaN        NaN        NaN        NaN              A
# 7711  NON PERTE    PARTIEL    PARTIEL      PERDU        NaN              A
# 7713        NaN        NaN        NaN        NaN        NaN              A
# 7714    PARTIEL      PERDU      PERDU       GAIN        NaN              A
# 7715      PERDU  NON PERTE  NON PERTE  NON PERTE  NON PERTE              A
# 7716        NaN        NaN        NaN        NaN        NaN              A
# 7719        NaN        NaN        NaN        NaN        NaN              A
# 7720        NaN        NaN        NaN        NaN        NaN              A
# 7727        NaN        NaN        NaN        NaN        NaN              A
# 7729        NaN        NaN        NaN        NaN        NaN              A
# 7732        NaN        NaN        NaN        NaN        NaN              A
# 7735      PERDU  NON PERTE  NON PERTE      PERDU        NaN              A
# 7738        NaN        NaN        NaN        NaN        NaN            NaN
# 7740        NaN        NaN        NaN        NaN        NaN              A
# 7755  NON PERTE       GAIN       GAIN  NON PERTE        NaN              A
#
#      Tumor_Position Clinical_evolution Surgery_type    Rx_date  \
# 2                 G             TT ini    partielle 1992-05-01
# 3       non précisé             TT ini      exérèse 1986-04-01
# 5                 G             TT ini       aucune 1990-03-14
# 7                 D             TT ini    partielle 1989-12-18
# 8                 D             TT ini      exérèse        NaT
# 9                 G             TT ini      exérèse 1991-11-19
# 10                G             TT ini      exérèse 1990-12-01
# 11      non précisé             TT ini      exérèse        NaT
# 12                G             TT ini    partielle 1992-03-01
# 14                G             TT ini    partielle 1993-08-11
# 15                D             TT ini      exérèse 1990-11-06
# 16                D             TT ini      exérèse 1990-11-06
# 17                D             TT ini      exérèse 1992-02-15
# 18        bilatéral             TT ini    partielle 1989-12-26
# 19        bilatéral             TT ini    partielle 1989-12-26
# 20        bilatéral             TT ini    partielle 1991-01-01
# 24                G             TT ini    partielle 1990-11-01
# 25                D             TT ini      exérèse        NaT
# 27                G             TT ini      exérèse 1989-12-15
# 28                D             TT ini      exérèse 1989-05-01
# 30                G             TT ini       aucune 1994-05-01
# 31      non précisé             TT ini    partielle 1989-11-20
# 34                D             TT ini    partielle 1989-05-01
# 35                D             TT ini    partielle 1989-09-18
# 36                D             TT ini       aucune 1992-05-01
# 37                D             TT ini      exérèse 1991-03-18
# 40                G             TT ini      exérèse 1992-01-01
# 45                D             TT ini      exérèse 1992-12-14
# 50                D             TT ini    partielle 1990-05-11
# 51                D             TT ini    partielle 1990-05-11
# ...             ...                ...          ...        ...
# 7685    non précisé             TT ini       aucune        NaT
# 7689              D             TT ini    partielle 2016-10-20
# 7690              G             TT ini      exérèse 2016-09-01
# 7691              D             TT ini    partielle        NaT
# 7692              D             TT ini      exérèse        NaT
# 7693              D             TT ini    partielle 2015-11-20
# 7694              G             TT ini    partielle 2016-08-08
# 7695              D             TT ini      biopsie        NaT
# 7696      bilatéral             TT ini      biopsie 2016-08-19
# 7697              D             TT ini    partielle 2017-03-20
# 7698              D             TT ini    partielle        NaT
# 7700              G             TT ini    partielle 2013-05-30
# 7701              D             TT ini      biopsie 2007-01-20
# 7704              D             TT ini      biopsie 2016-11-14
# 7707              G             TT ini      biopsie 2016-09-07
# 7709              D             TT ini    partielle 2016-06-01
# 7711              G             TT ini      exérèse 2016-10-10
# 7713              G             TT ini      biopsie 2016-06-29
# 7714              G             TT ini    partielle 2016-05-10
# 7715              D             TT ini    partielle 2016-06-01
# 7716            NaN             TT ini      biopsie 2016-08-11
# 7719              G             TT ini      biopsie        NaT
# 7720              G             TT ini      biopsie        NaT
# 7727              D             TT ini    partielle        NaT
# 7729              D             TT ini      exérèse 2017-03-01
# 7732              D             TT ini      biopsie        NaT
# 7735              G             TT ini    partielle        NaT
# 7738      bilatéral             TT ini      biopsie 2017-04-26
# 7740              D             TT ini    partielle 2017-03-15
# 7755         médian             TT ini      biopsie 2017-04-13
#
#      Chemo_start_date  Age_surgery  life_expectancy
# 2          1992-05-01         42.0             30.0
# 3                 NaT         28.0           2069.0
# 5                 NaT         59.0            393.0
# 7                 NaT         61.0            398.0
# 8                 NaT         58.0            433.0
# 9                 NaT         56.0            143.0
# 10                NaT         69.0            408.0
# 11                NaT         66.0              7.0
# 12                NaT         61.0            316.0
# 14         1993-08-05         43.0            571.0
# 15         1990-07-19         58.0           1172.0
# 16         1990-12-07         58.0           1172.0
# 17         1992-02-15         49.0            701.0
# 18         1990-02-16         32.0            521.0
# 19         1990-10-03         32.0            521.0
# 20         1990-12-01         60.0            194.0
# 24                NaT         39.0           1255.0
# 25                NaT         34.0            169.0
# 27                NaT         49.0            666.0
# 28                NaT         72.0            355.0
# 30                NaT         24.0             60.0
# 31         1989-11-01         45.0             96.0
# 34                NaT         15.0            566.0
# 35         1989-09-01         62.0            320.0
# 36                NaT         22.0            175.0
# 37         1991-02-28         49.0            997.0
# 40                NaT         41.0            220.0
# 45         1992-12-03         60.0            478.0
# 50         1990-07-01         63.0           1269.0
# 51         1991-01-07         63.0           1269.0
# ...               ...          ...              ...
# 7685              NaT         52.0              NaN
# 7689       2016-12-24         63.0              NaN
# 7690       2016-10-20         49.0              NaN
# 7691       2016-10-14         57.0              NaN
# 7692              NaT         20.0              NaN
# 7693       2016-02-03         72.0              NaN
# 7694       2016-10-25         53.0              NaN
# 7695              NaT         53.0              NaN
# 7696       2016-11-16         48.0            310.0
# 7697       2017-02-22         72.0              NaN
# 7698       2006-02-10         30.0              NaN
# 7700       2013-08-22         38.0              NaN
# 7701              NaT         44.0              NaN
# 7704       2017-01-24         69.0              NaN
# 7707       2017-02-01         58.0              NaN
# 7709       2016-08-01         69.0              NaN
# 7711       2017-01-02         24.0              NaN
# 7713       2016-09-13         47.0              NaN
# 7714       2016-06-25         46.0              NaN
# 7715       2016-08-23         50.0              NaN
# 7716       2016-10-25         59.0              NaN
# 7719       2004-10-07         30.0              NaN
# 7720       2005-04-01         30.0              NaN
# 7727              NaT         22.0              NaN
# 7729       2017-03-09         45.0              NaN
# 7732              NaT         68.0              NaN
# 7735              NaT         61.0              NaN
# 7738              NaT         75.0              NaN
# 7740       2017-03-15         60.0              NaN
# 7755              NaT         49.0              NaN
#
# [2430 rows x 33 columns]

# %%
# implementing rule per Marc comments
# collapse'Gene_Idh1', 'Gene_Idh2' into "IDH"
# IDH mutant = 'Gene_Idh1' OR 'Gene_Idh2' mutant
# IDHwt = 'Gene_Idh1'wt AND  'Gene_Idh2'wt; OR 'Gene_Idh1'wt AND IDH2 unknown
# Expl : IDH2 mutation are much less frequent than IDH1 mutations (5% of all the mutations)

df_clean_test.loc[(df_clean_test['Gene_Idh1'] == 'ALTERE') | (df_clean_test['Gene_Idh2'] == 'ALTERE'), "IDH"] = "mutant"
df_clean_test.loc[(df_clean_test['Gene_Idh1'] == 'NORMAL') & (df_clean_test['Gene_Idh2'] == 'NORMAL'), "IDH"] = "wt"
df_clean_test.loc[(df_clean_test['Gene_Idh1'] == 'NORMAL') & (df_clean_test['Gene_Idh2'].isnull()), "IDH"] = "wt"
df_clean_test.loc[(df_clean_test['Gene_Idh1'] == 'NORMAL') & (df_clean_test['Gene_Idh2'] == "NC"), "IDH"] = "wt"
df_clean_test.loc[(df_clean_test['Gene_Idh1'] == 'NC') & (df_clean_test['Gene_Idh2'] == 'NC'), "IDH"] = "NC"
df_clean_test
# Out:
#               ID Gender        DoB  Dernieres_nouvelles Death_date  \
# 2             10      M 1949-11-05                  NaN 1992-05-15
# 3             11      M 1958-07-29                  NaN 1991-11-15
# 5             12      F 1930-12-07                  NaN 1991-03-13
# 7             13      M 1928-11-17                  NaN 1990-12-20
# 8             14      F 1934-07-17                  NaN 1993-03-30
# 9             15      M 1936-03-22                  NaN 1992-03-14
# 10            16      M 1922-04-18                  NaN 1991-12-22
# 11            17      M 1924-04-12                  NaN 1990-04-04
# 12            18      F 1931-06-05                  NaN 1992-12-18
# 14            22      M 1950-05-10                  NaN 1995-01-29
# 15            23      F 1932-10-09                  NaN 1993-09-10
# 16            23      F 1932-10-09                  NaN 1993-09-10
# 17            24      M 1943-03-04                  NaN 1993-12-15
# 18            25      M 1957-06-16                  NaN 1991-04-13
# 19            25      M 1957-06-16                  NaN 1991-04-13
# 20            26      M 1930-07-07                  NaN 1991-05-15
# 24            30      M 1952-02-01                  NaN 1994-03-03
# 25            31      M 1957-11-25                  NaN 1992-10-20
# 27            34      F 1939-06-30                  NaN 1990-09-15
# 28            35      F 1917-06-04                  NaN 1990-04-15
# 30            36      F 1972-12-01                  NaN 1996-10-19
# 31            37      M 1945-01-01                  NaN 1989-12-31
# 34            39      F 1974-06-21                  NaN 1990-10-30
# 35            40      M 1927-04-16                  NaN 1990-07-09
# 36            41      M 1970-04-07                  NaN 1992-09-01
# 37            42      F 1942-08-14                  NaN 1993-11-08
# 40            44      M 1951-03-28                  NaN 1992-08-06
# 45            47      F 1932-05-26                  NaN 1994-03-10
# 50            49      M 1927-04-07                  NaN 1993-10-01
# 51            49      M 1927-04-07                  NaN 1993-10-01
# ...          ...    ...        ...                  ...        ...
# 7685  8009475251      F 1956-12-25               2017.0        NaT
# 7689  8009496494      F 1953-07-01               2017.0        NaT
# 7690  8009502080      M 1967-02-03               2017.0        NaT
# 7691  8009502097      F 1959-04-19               2017.0        NaT
# 7692  8009504238      M 1996-12-28               2017.0        NaT
# 7693  8009508609      M 1944-02-26               2017.0        NaT
# 7694  8009509396      M 1963-12-08               2017.0        NaT
# 7695  8009510265      F 1962-06-07               2017.0        NaT
# 7696  8009536357      M 1968-04-16                  NaN 2017-05-13
# 7697  8009538232      M 1945-01-01               2017.0        NaT
# 7698  8009545405      F 1975-09-30               2017.0        NaT
# 7700  8009547563      F 1974-09-11               2017.0        NaT
# 7701  8009558455      F 1962-08-12               2017.0        NaT
# 7704  8009583738      F 1947-03-30               2017.0        NaT
# 7707  8009588647      F 1958-06-26               2017.0        NaT
# 7709  8009606625      F 1947-03-27               2017.0        NaT
# 7711  8009619135      F 1993-02-08               2017.0        NaT
# 7713  8009630406      F 1968-12-22               2017.0        NaT
# 7714  8009631994      M 1970-07-28               2017.0        NaT
# 7715  8009633302      M 1965-11-07               2017.0        NaT
# 7716  8009635074      M 1957-01-07               2017.0        NaT
# 7719  8009636704      M 1974-04-12               2017.0        NaT
# 7720  8009636704      M 1974-04-12               2017.0        NaT
# 7727  8009657835      F 1985-08-30               2017.0        NaT
# 7729  8009669708      F 1971-08-19               2017.0        NaT
# 7732  8009694199      M 1948-10-14               2017.0        NaT
# 7735  8009712826      M 1956-01-01               2017.0        NaT
# 7738  8009724274      F 1942-07-30               2017.0        NaT
# 7740  8009728167      F 1957-02-22               2017.0        NaT
# 7755  8009823797      F 1968-01-16               2017.0        NaT
#
#      Surgery_date                        Tumor_type  Tumor_grade Gene_Idh1  \
# 2      1992-04-15                            gliome          3.0    ALTERE
# 3      1986-03-17                       astrocytome          2.0        NC
# 5      1990-02-13                               GBM          4.0    NORMAL
# 7      1989-11-17                               GBM          4.0    NORMAL
# 8      1992-01-22                               GBM          4.0    NORMAL
# 9      1991-10-23                               GBM          4.0    NORMAL
# 10     1990-11-09                               GBM          4.0    NORMAL
# 11     1990-03-28                               GBM          4.0    NORMAL
# 12     1992-02-06                       astrocytome          3.0    NORMAL
# 14     1993-07-07                               GBM          4.0    NORMAL
# 15     1990-06-26                       astrocytome          3.0        NC
# 16     1990-06-26                       astrocytome          3.0        NC
# 17     1992-01-14                            gliome          3.0    NORMAL
# 18     1989-11-08                       astrocytome          2.0    NORMAL
# 19     1989-11-08                       astrocytome          2.0    NORMAL
# 20     1990-11-02                             oligo          3.0    ALTERE
# 24     1990-09-25                       astrocytome          3.0    NORMAL
# 25     1992-05-04                             oligo          2.0    NORMAL
# 27     1988-11-18                               GBM          4.0    NORMAL
# 28     1989-04-25                               GBM          4.0    NORMAL
# 30     1996-08-20                            gliome          3.0    ALTERE
# 31     1989-09-26                               GBM          4.0    NORMAL
# 34     1989-04-12                       astrocytome          2.0        NC
# 35     1989-08-23                               GBM          4.0    NORMAL
# 36     1992-03-10                               GBM          4.0    NORMAL
# 37     1991-02-15                               GBM          4.0    NORMAL
# 40     1991-12-30                               GBM          4.0        NC
# 45     1992-11-17                               GBM          4.0    NORMAL
# 50     1990-04-11                             oligo          3.0    NORMAL
# 51     1990-04-11                             oligo          3.0    NORMAL
# ...           ...                               ...          ...       ...
# 7685   2008-08-27                             oligo          2.0    ALTERE
# 7689   2016-08-31                               GBM          4.0    NORMAL
# 7690   2016-05-03                            gliome          3.0    ALTERE
# 7691   2016-08-23                             oligo          3.0    ALTERE
# 7692   2017-02-06                       astrocytome          3.0    ALTERE
# 7693   2015-10-28                               GBM          4.0    NORMAL
# 7694   2016-06-08                               GBM          4.0        NC
# 7695   2015-09-29                               GBM          4.0    NORMAL
# 7696   2016-07-07                       astrocytome          3.0    NORMAL
# 7697   2016-12-29                               GBM          4.0    ALTERE
# 7698   2005-11-25                             oligo          3.0    ALTERE
# 7700   2013-01-22                               GBM          4.0    ALTERE
# 7701   2006-07-19  astrocytome gémistocytique (=A2)          2.0    ALTERE
# 7704   2016-09-20                               GBM          4.0        NC
# 7707   2016-05-20                       astrocytome          2.0    NORMAL
# 7709   2016-04-06                               GBM          4.0        NC
# 7711   2016-08-30                               GBM          4.0    NORMAL
# 7713   2016-04-28                               GBM          4.0        NC
# 7714   2016-02-18                               GBM          4.0    NORMAL
# 7715   2016-03-17                             oligo          3.0    ALTERE
# 7716   2016-06-27                               GBM          4.0        NC
# 7719   2004-08-17                             oligo          2.0        NC
# 7720   2004-08-17                             oligo          2.0        NC
# 7727   2007-10-08                             oligo          2.0        NC
# 7729   2017-01-26                               GBM          4.0    NORMAL
# 7732   2017-03-08                       astrocytome          3.0    NORMAL
# 7735   2017-03-09                             oligo          3.0    ALTERE
# 7738   2017-03-10                       astrocytome          3.0    NORMAL
# 7740   2017-01-24                               GBM          4.0    NORMAL
# 7755   2017-03-20                               GBM          4.0    NORMAL
#
#      Gene_Idh2 Gene_Htert_C228T Gene_Htert_C250T Gene_P53    Gene_Mgmt  \
# 2       NORMAL           NORMAL           NORMAL       NC          NaN
# 3           NC              NaN              NaN       NC          NaN
# 5          NaN           NORMAL           ALTERE   NORMAL  NON METHYLE
# 7          NaN           NORMAL           NORMAL   NORMAL  NON METHYLE
# 8       NORMAL           NORMAL           ALTERE   NORMAL          NaN
# 9       NORMAL           ALTERE           NORMAL   ALTERE  NON METHYLE
# 10      NORMAL           NORMAL           NORMAL   NORMAL          NaN
# 11         NaN           NORMAL           ALTERE       NC      METHYLE
# 12      NORMAL           ALTERE           NORMAL   NORMAL          NaN
# 14      NORMAL           ALTERE           NORMAL   NORMAL      METHYLE
# 15          NC              NaN              NaN       NC          NaN
# 16          NC              NaN              NaN       NC          NaN
# 17      NORMAL           ALTERE           NORMAL   NORMAL      METHYLE
# 18      NORMAL           NORMAL           NORMAL       NC      METHYLE
# 19      NORMAL           NORMAL           NORMAL       NC      METHYLE
# 20      NORMAL              NaN              NaN   NORMAL          NaN
# 24         NaN           NORMAL           NORMAL   NORMAL          NaN
# 25      NORMAL           NORMAL           NORMAL       NC          NaN
# 27         NaN           NORMAL           ALTERE   NORMAL          NaN
# 28         NaN           ALTERE           NORMAL   NORMAL      METHYLE
# 30      NORMAL              NaN              NaN       NC          NaN
# 31         NaN           NORMAL           NORMAL       NC          NaN
# 34          NC              NaN              NaN       NC          NaN
# 35         NaN           NORMAL           NORMAL   NORMAL      METHYLE
# 36         NaN           ALTERE           NORMAL   NORMAL  NON METHYLE
# 37      NORMAL           ALTERE           NORMAL      NaN  NON METHYLE
# 40          NC              NaN              NaN       NC          NaN
# 45         NaN           NORMAL           NORMAL      NaN      METHYLE
# 50      NORMAL           NORMAL           NORMAL       NC          NaN
# 51      NORMAL           NORMAL           NORMAL       NC          NaN
# ...        ...              ...              ...      ...          ...
# 7685    NORMAL           NORMAL           NORMAL   NORMAL          NaN
# 7689    NORMAL               NC               NC       NC          NaN
# 7690    NORMAL           NORMAL           ALTERE   NORMAL          NaN
# 7691    NORMAL           NORMAL           ALTERE   NORMAL          NaN
# 7692    NORMAL           NORMAL           NORMAL   ALTERE          NaN
# 7693    NORMAL               NC               NC       NC      METHYLE
# 7694        NC               NC               NC       NC          NaN
# 7695    NORMAL           ALTERE           NORMAL       NC          NaN
# 7696    NORMAL           ALTERE           NORMAL   NORMAL          NaN
# 7697        NC               NC               NC       NC          NaN
# 7698    NORMAL           NORMAL           ALTERE      NaN          NaN
# 7700    NORMAL           NORMAL           NORMAL       NC          NaN
# 7701    NORMAL           NORMAL           NORMAL      NaN          NaN
# 7704        NC               NC               NC       NC          NaN
# 7707    NORMAL           NORMAL           NORMAL   NORMAL          NaN
# 7709        NC               NC               NC       NC          NaN
# 7711    NORMAL           NORMAL           NORMAL   ALTERE          NaN
# 7713        NC               NC               NC       NC          NaN
# 7714    NORMAL           ALTERE           NORMAL   NORMAL          NaN
# 7715    NORMAL           NORMAL           ALTERE   NORMAL          NaN
# 7716        NC               NC               NC       NC          NaN
# 7719        NC              NaN              NaN       NC          NaN
# 7720        NC              NaN              NaN       NC          NaN
# 7727        NC              NaN              NaN       NC          NaN
# 7729    NORMAL               NC               NC       NC          NaN
# 7732    NORMAL           ALTERE           NORMAL       NC          NaN
# 7735    NORMAL           NORMAL           ALTERE   NORMAL          NaN
# 7738    NORMAL           NORMAL           NORMAL       NC          NaN
# 7740    NORMAL           ALTERE           NORMAL       NC          NaN
# 7755    NORMAL           NORMAL           ALTERE   ALTERE          NaN
#
#      Gene_Egfr Gene_Mdm2 Gene_Cdk4 Gene_P16       Gene_Ihc_Atrx  Gene_Ch1P  \
# 2       NORMAL       NaN       NaN      NaN                 NaN  NON PERTE
# 3          NaN       NaN       NaN      NaN                 NaN        NaN
# 5       NORMAL    NORMAL    NORMAL   DELETE                 NaN    PARTIEL
# 7       NORMAL    NORMAL    NORMAL   NORMAL                 NaN  NON PERTE
# 8     AMPLIFIE    NORMAL    NORMAL   NORMAL                 NaN       GAIN
# 9     AMPLIFIE    NORMAL    NORMAL   DELETE                 NaN    PARTIEL
# 10      NORMAL    NORMAL    NORMAL   DELETE                 NaN    PARTIEL
# 11      NORMAL    NORMAL    NORMAL   NORMAL                 NaN  NON PERTE
# 12      NORMAL       NaN       NaN      NaN                 NaN  NON PERTE
# 14    AMPLIFIE    NORMAL    NORMAL   DELETE                 NaN    PARTIEL
# 15         NaN       NaN       NaN      NaN                 NaN        NaN
# 16         NaN       NaN       NaN      NaN                 NaN        NaN
# 17    AMPLIFIE    NORMAL    NORMAL   DELETE                 NaN  NON PERTE
# 18         NaN       NaN       NaN      NaN                 NaN  NON PERTE
# 19         NaN       NaN       NaN      NaN                 NaN  NON PERTE
# 20      NORMAL    NORMAL    NORMAL   NORMAL                 NaN      PERDU
# 24         NaN       NaN       NaN      NaN                 NaN  NON PERTE
# 25         NaN       NaN       NaN      NaN                 NaN        NaN
# 27      NORMAL    NORMAL    NORMAL   NORMAL                 NaN    PARTIEL
# 28      NORMAL    NORMAL    NORMAL   DELETE                 NaN  NON PERTE
# 30         NaN       NaN       NaN      NaN                 NaN        NaN
# 31      NORMAL    NORMAL    NORMAL   NORMAL                 NaN  NON PERTE
# 34         NaN       NaN       NaN      NaN                 NaN        NaN
# 35      NORMAL    NORMAL    NORMAL   DELETE                 NaN  NON PERTE
# 36      NORMAL    NORMAL    NORMAL   DELETE                 NaN  NON PERTE
# 37      NORMAL    NORMAL    NORMAL   NORMAL                 NaN  NON PERTE
# 40         NaN       NaN       NaN      NaN                 NaN        NaN
# 45      NORMAL    NORMAL  AMPLIFIE   NORMAL                 NaN  NON PERTE
# 50      NORMAL    NORMAL    NORMAL   NORMAL                 NaN  NON PERTE
# 51      NORMAL    NORMAL    NORMAL   NORMAL                 NaN  NON PERTE
# ...        ...       ...       ...      ...                 ...        ...
# 7685    NORMAL    NORMAL    NORMAL   NORMAL                 NaN      PERDU
# 7689       NaN       NaN       NaN      NaN            Maintien        NaN
# 7690    NORMAL    NORMAL    NORMAL   NORMAL            Maintien      PERDU
# 7691    NORMAL    NORMAL    NORMAL   NORMAL            Maintien      PERDU
# 7692    NORMAL    NORMAL    NORMAL   NORMAL  Extinction diffuse  NON PERTE
# 7693       NaN    NORMAL       NaN      NaN            Maintien        NaN
# 7694       NaN       NaN       NaN      NaN            Maintien        NaN
# 7695       NaN       NaN       NaN      NaN            Maintien        NaN
# 7696  AMPLIFIE    NORMAL    NORMAL   NORMAL            Maintien  NON PERTE
# 7697       NaN       NaN       NaN      NaN            Maintien        NaN
# 7698    NORMAL    NORMAL    NORMAL   NORMAL                 NaN      PERDU
# 7700    NORMAL    NORMAL    NORMAL   NORMAL                 NaN       GAIN
# 7701    NORMAL    NORMAL    NORMAL   NORMAL                 NaN    PARTIEL
# 7704       NaN       NaN       NaN      NaN            Maintien        NaN
# 7707    NORMAL    NORMAL    NORMAL   NORMAL            Maintien       GAIN
# 7709       NaN       NaN       NaN      NaN            Maintien        NaN
# 7711    NORMAL    NORMAL    NORMAL   NORMAL                 NaN  NON PERTE
# 7713       NaN       NaN       NaN      NaN                 NaN        NaN
# 7714    NORMAL    NORMAL    NORMAL   NORMAL            Maintien    PARTIEL
# 7715    NORMAL    NORMAL    NORMAL   NORMAL            Maintien      PERDU
# 7716       NaN       NaN       NaN      NaN            Maintien        NaN
# 7719       NaN       NaN       NaN      NaN                 NaN        NaN
# 7720       NaN       NaN       NaN      NaN                 NaN        NaN
# 7727       NaN       NaN       NaN      NaN                 NaN        NaN
# 7729       NaN       NaN       NaN      NaN            Maintien        NaN
# 7732       NaN       NaN       NaN      NaN                 NaN        NaN
# 7735    NORMAL    NORMAL    NORMAL   NORMAL            Maintien      PERDU
# 7738       NaN       NaN       NaN      NaN  Extinction diffuse        NaN
# 7740       NaN       NaN       NaN      NaN            Maintien        NaN
# 7755    NORMAL    NORMAL    NORMAL   NORMAL            Maintien  NON PERTE
#
#      Gene_Ch19Q Gene_Ch10P Gene_Ch10Q  Gene_Ch9P  Gene_Ch9Q Tumor_Location  \
# 2     NON PERTE  NON PERTE      PERDU  NON PERTE        NaN              A
# 3           NaN        NaN        NaN        NaN        NaN              N
# 5       PARTIEL      PERDU      PERDU      PERDU        NaN              A
# 7     NON PERTE  NON PERTE      PERDU        NaN        NaN              A
# 8     NON PERTE  NON PERTE      PERDU  NON PERTE  NON PERTE              A
# 9     NON PERTE  NON PERTE      PERDU  NON PERTE  NON PERTE              A
# 10      PARTIEL        NaN      PERDU  NON PERTE        NaN              N
# 11    NON PERTE  NON PERTE      PERDU  NON PERTE        NaN              N
# 12          NaN  NON PERTE  NON PERTE  NON PERTE        NaN              A
# 14    NON PERTE      PERDU      PERDU    PARTIEL  NON PERTE              A
# 15          NaN        NaN        NaN        NaN        NaN              A
# 16          NaN        NaN        NaN        NaN        NaN              A
# 17        PERDU      PERDU      PERDU      PERDU        NaN              N
# 18          NaN        NaN  NON PERTE      PERDU        NaN              A
# 19          NaN        NaN  NON PERTE      PERDU        NaN              A
# 20        PERDU  NON PERTE  NON PERTE    PARTIEL        NaN              N
# 24    NON PERTE  NON PERTE  NON PERTE  NON PERTE        NaN              A
# 25          NaN        NaN        NaN        NaN        NaN              A
# 27      PARTIEL      PERDU      PERDU  NON PERTE        NaN              N
# 28    NON PERTE      PERDU      PERDU      PERDU  NON PERTE              N
# 30          NaN        NaN        NaN        NaN        NaN              N
# 31    NON PERTE      PERDU      PERDU      PERDU        NaN              A
# 34          NaN        NaN        NaN        NaN        NaN              A
# 35        PERDU        NaN  NON PERTE  NON PERTE        NaN              A
# 36        PERDU  NON PERTE  NON PERTE      PERDU        NaN              A
# 37      PARTIEL        NaN  NON PERTE  NON PERTE        NaN              A
# 40          NaN        NaN        NaN        NaN        NaN              N
# 45    NON PERTE  NON PERTE  NON PERTE  NON PERTE        NaN              A
# 50          NaN        NaN        NaN      PERDU        NaN              A
# 51          NaN        NaN        NaN      PERDU        NaN              A
# ...         ...        ...        ...        ...        ...            ...
# 7685      PERDU  NON PERTE  NON PERTE    PARTIEL  NON PERTE              N
# 7689        NaN        NaN        NaN        NaN        NaN              A
# 7690      PERDU  NON PERTE  NON PERTE      PERDU  NON PERTE              A
# 7691      PERDU  NON PERTE  NON PERTE  NON PERTE  NON PERTE              A
# 7692  NON PERTE  NON PERTE  NON PERTE  NON PERTE        NaN              A
# 7693        NaN        NaN        NaN        NaN        NaN              A
# 7694        NaN        NaN        NaN        NaN        NaN              A
# 7695        NaN        NaN        NaN        NaN        NaN              A
# 7696  NON PERTE  NON PERTE  NON PERTE  NON PERTE        NaN              A
# 7697        NaN        NaN        NaN        NaN        NaN              A
# 7698      PERDU        NaN  NON PERTE        NaN        NaN              A
# 7700      PERDU  NON PERTE  NON PERTE  NON PERTE  NON PERTE              A
# 7701  NON PERTE    PARTIEL      PERDU  NON PERTE  NON PERTE              A
# 7704        NaN        NaN        NaN        NaN        NaN              A
# 7707       GAIN  NON PERTE  NON PERTE  NON PERTE        NaN              A
# 7709        NaN        NaN        NaN        NaN        NaN              A
# 7711  NON PERTE    PARTIEL    PARTIEL      PERDU        NaN              A
# 7713        NaN        NaN        NaN        NaN        NaN              A
# 7714    PARTIEL      PERDU      PERDU       GAIN        NaN              A
# 7715      PERDU  NON PERTE  NON PERTE  NON PERTE  NON PERTE              A
# 7716        NaN        NaN        NaN        NaN        NaN              A
# 7719        NaN        NaN        NaN        NaN        NaN              A
# 7720        NaN        NaN        NaN        NaN        NaN              A
# 7727        NaN        NaN        NaN        NaN        NaN              A
# 7729        NaN        NaN        NaN        NaN        NaN              A
# 7732        NaN        NaN        NaN        NaN        NaN              A
# 7735      PERDU  NON PERTE  NON PERTE      PERDU        NaN              A
# 7738        NaN        NaN        NaN        NaN        NaN            NaN
# 7740        NaN        NaN        NaN        NaN        NaN              A
# 7755  NON PERTE       GAIN       GAIN  NON PERTE        NaN              A
#
#      Tumor_Position Clinical_evolution Surgery_type    Rx_date  \
# 2                 G             TT ini    partielle 1992-05-01
# 3       non précisé             TT ini      exérèse 1986-04-01
# 5                 G             TT ini       aucune 1990-03-14
# 7                 D             TT ini    partielle 1989-12-18
# 8                 D             TT ini      exérèse        NaT
# 9                 G             TT ini      exérèse 1991-11-19
# 10                G             TT ini      exérèse 1990-12-01
# 11      non précisé             TT ini      exérèse        NaT
# 12                G             TT ini    partielle 1992-03-01
# 14                G             TT ini    partielle 1993-08-11
# 15                D             TT ini      exérèse 1990-11-06
# 16                D             TT ini      exérèse 1990-11-06
# 17                D             TT ini      exérèse 1992-02-15
# 18        bilatéral             TT ini    partielle 1989-12-26
# 19        bilatéral             TT ini    partielle 1989-12-26
# 20        bilatéral             TT ini    partielle 1991-01-01
# 24                G             TT ini    partielle 1990-11-01
# 25                D             TT ini      exérèse        NaT
# 27                G             TT ini      exérèse 1989-12-15
# 28                D             TT ini      exérèse 1989-05-01
# 30                G             TT ini       aucune 1994-05-01
# 31      non précisé             TT ini    partielle 1989-11-20
# 34                D             TT ini    partielle 1989-05-01
# 35                D             TT ini    partielle 1989-09-18
# 36                D             TT ini       aucune 1992-05-01
# 37                D             TT ini      exérèse 1991-03-18
# 40                G             TT ini      exérèse 1992-01-01
# 45                D             TT ini      exérèse 1992-12-14
# 50                D             TT ini    partielle 1990-05-11
# 51                D             TT ini    partielle 1990-05-11
# ...             ...                ...          ...        ...
# 7685    non précisé             TT ini       aucune        NaT
# 7689              D             TT ini    partielle 2016-10-20
# 7690              G             TT ini      exérèse 2016-09-01
# 7691              D             TT ini    partielle        NaT
# 7692              D             TT ini      exérèse        NaT
# 7693              D             TT ini    partielle 2015-11-20
# 7694              G             TT ini    partielle 2016-08-08
# 7695              D             TT ini      biopsie        NaT
# 7696      bilatéral             TT ini      biopsie 2016-08-19
# 7697              D             TT ini    partielle 2017-03-20
# 7698              D             TT ini    partielle        NaT
# 7700              G             TT ini    partielle 2013-05-30
# 7701              D             TT ini      biopsie 2007-01-20
# 7704              D             TT ini      biopsie 2016-11-14
# 7707              G             TT ini      biopsie 2016-09-07
# 7709              D             TT ini    partielle 2016-06-01
# 7711              G             TT ini      exérèse 2016-10-10
# 7713              G             TT ini      biopsie 2016-06-29
# 7714              G             TT ini    partielle 2016-05-10
# 7715              D             TT ini    partielle 2016-06-01
# 7716            NaN             TT ini      biopsie 2016-08-11
# 7719              G             TT ini      biopsie        NaT
# 7720              G             TT ini      biopsie        NaT
# 7727              D             TT ini    partielle        NaT
# 7729              D             TT ini      exérèse 2017-03-01
# 7732              D             TT ini      biopsie        NaT
# 7735              G             TT ini    partielle        NaT
# 7738      bilatéral             TT ini      biopsie 2017-04-26
# 7740              D             TT ini    partielle 2017-03-15
# 7755         médian             TT ini      biopsie 2017-04-13
#
#      Chemo_start_date  Age_surgery  life_expectancy     IDH
# 2          1992-05-01         42.0             30.0  mutant
# 3                 NaT         28.0           2069.0      NC
# 5                 NaT         59.0            393.0      wt
# 7                 NaT         61.0            398.0      wt
# 8                 NaT         58.0            433.0      wt
# 9                 NaT         56.0            143.0      wt
# 10                NaT         69.0            408.0      wt
# 11                NaT         66.0              7.0      wt
# 12                NaT         61.0            316.0      wt
# 14         1993-08-05         43.0            571.0      wt
# 15         1990-07-19         58.0           1172.0      NC
# 16         1990-12-07         58.0           1172.0      NC
# 17         1992-02-15         49.0            701.0      wt
# 18         1990-02-16         32.0            521.0      wt
# 19         1990-10-03         32.0            521.0      wt
# 20         1990-12-01         60.0            194.0  mutant
# 24                NaT         39.0           1255.0      wt
# 25                NaT         34.0            169.0      wt
# 27                NaT         49.0            666.0      wt
# 28                NaT         72.0            355.0      wt
# 30                NaT         24.0             60.0  mutant
# 31         1989-11-01         45.0             96.0      wt
# 34                NaT         15.0            566.0      NC
# 35         1989-09-01         62.0            320.0      wt
# 36                NaT         22.0            175.0      wt
# 37         1991-02-28         49.0            997.0      wt
# 40                NaT         41.0            220.0      NC
# 45         1992-12-03         60.0            478.0      wt
# 50         1990-07-01         63.0           1269.0      wt
# 51         1991-01-07         63.0           1269.0      wt
# ...               ...          ...              ...     ...
# 7685              NaT         52.0              NaN  mutant
# 7689       2016-12-24         63.0              NaN      wt
# 7690       2016-10-20         49.0              NaN  mutant
# 7691       2016-10-14         57.0              NaN  mutant
# 7692              NaT         20.0              NaN  mutant
# 7693       2016-02-03         72.0              NaN      wt
# 7694       2016-10-25         53.0              NaN      NC
# 7695              NaT         53.0              NaN      wt
# 7696       2016-11-16         48.0            310.0      wt
# 7697       2017-02-22         72.0              NaN  mutant
# 7698       2006-02-10         30.0              NaN  mutant
# 7700       2013-08-22         38.0              NaN  mutant
# 7701              NaT         44.0              NaN  mutant
# 7704       2017-01-24         69.0              NaN      NC
# 7707       2017-02-01         58.0              NaN      wt
# 7709       2016-08-01         69.0              NaN      NC
# 7711       2017-01-02         24.0              NaN      wt
# 7713       2016-09-13         47.0              NaN      NC
# 7714       2016-06-25         46.0              NaN      wt
# 7715       2016-08-23         50.0              NaN  mutant
# 7716       2016-10-25         59.0              NaN      NC
# 7719       2004-10-07         30.0              NaN      NC
# 7720       2005-04-01         30.0              NaN      NC
# 7727              NaT         22.0              NaN      NC
# 7729       2017-03-09         45.0              NaN      wt
# 7732              NaT         68.0              NaN      wt
# 7735              NaT         61.0              NaN  mutant
# 7738              NaT         75.0              NaN      wt
# 7740       2017-03-15         60.0              NaN      wt
# 7755              NaT         49.0              NaN      wt
#
# [2430 rows x 34 columns]

# %%
#implementing rule per Marc comments
#Tert instead of 'Gene_Htert_C228T', 'Gene_Htert_C250T'
#Tert mutant= 'Gene_Htert_C228T'mut OR 'Gene_Htert_C250T'mut
#Tert wt= 'Gene_Htert_C228T'wt  AND 'Gene_Htert_C250T' wt
df_clean_test.loc[(df_clean_test['Gene_Htert_C228T'] == 'ALTERE') | (df_clean_test['Gene_Htert_C250T'] == 'ALTERE'), "TERT"] = "mutant"
df_clean_test.loc[(df_clean_test['Gene_Htert_C228T'] == 'NORMAL') & (df_clean_test['Gene_Htert_C250T'] == 'NORMAL'), "TERT"] = "wt"
df_clean_test
# Out:
#               ID Gender        DoB  Dernieres_nouvelles Death_date  \
# 2             10      M 1949-11-05                  NaN 1992-05-15
# 3             11      M 1958-07-29                  NaN 1991-11-15
# 5             12      F 1930-12-07                  NaN 1991-03-13
# 7             13      M 1928-11-17                  NaN 1990-12-20
# 8             14      F 1934-07-17                  NaN 1993-03-30
# 9             15      M 1936-03-22                  NaN 1992-03-14
# 10            16      M 1922-04-18                  NaN 1991-12-22
# 11            17      M 1924-04-12                  NaN 1990-04-04
# 12            18      F 1931-06-05                  NaN 1992-12-18
# 14            22      M 1950-05-10                  NaN 1995-01-29
# 15            23      F 1932-10-09                  NaN 1993-09-10
# 16            23      F 1932-10-09                  NaN 1993-09-10
# 17            24      M 1943-03-04                  NaN 1993-12-15
# 18            25      M 1957-06-16                  NaN 1991-04-13
# 19            25      M 1957-06-16                  NaN 1991-04-13
# 20            26      M 1930-07-07                  NaN 1991-05-15
# 24            30      M 1952-02-01                  NaN 1994-03-03
# 25            31      M 1957-11-25                  NaN 1992-10-20
# 27            34      F 1939-06-30                  NaN 1990-09-15
# 28            35      F 1917-06-04                  NaN 1990-04-15
# 30            36      F 1972-12-01                  NaN 1996-10-19
# 31            37      M 1945-01-01                  NaN 1989-12-31
# 34            39      F 1974-06-21                  NaN 1990-10-30
# 35            40      M 1927-04-16                  NaN 1990-07-09
# 36            41      M 1970-04-07                  NaN 1992-09-01
# 37            42      F 1942-08-14                  NaN 1993-11-08
# 40            44      M 1951-03-28                  NaN 1992-08-06
# 45            47      F 1932-05-26                  NaN 1994-03-10
# 50            49      M 1927-04-07                  NaN 1993-10-01
# 51            49      M 1927-04-07                  NaN 1993-10-01
# ...          ...    ...        ...                  ...        ...
# 7685  8009475251      F 1956-12-25               2017.0        NaT
# 7689  8009496494      F 1953-07-01               2017.0        NaT
# 7690  8009502080      M 1967-02-03               2017.0        NaT
# 7691  8009502097      F 1959-04-19               2017.0        NaT
# 7692  8009504238      M 1996-12-28               2017.0        NaT
# 7693  8009508609      M 1944-02-26               2017.0        NaT
# 7694  8009509396      M 1963-12-08               2017.0        NaT
# 7695  8009510265      F 1962-06-07               2017.0        NaT
# 7696  8009536357      M 1968-04-16                  NaN 2017-05-13
# 7697  8009538232      M 1945-01-01               2017.0        NaT
# 7698  8009545405      F 1975-09-30               2017.0        NaT
# 7700  8009547563      F 1974-09-11               2017.0        NaT
# 7701  8009558455      F 1962-08-12               2017.0        NaT
# 7704  8009583738      F 1947-03-30               2017.0        NaT
# 7707  8009588647      F 1958-06-26               2017.0        NaT
# 7709  8009606625      F 1947-03-27               2017.0        NaT
# 7711  8009619135      F 1993-02-08               2017.0        NaT
# 7713  8009630406      F 1968-12-22               2017.0        NaT
# 7714  8009631994      M 1970-07-28               2017.0        NaT
# 7715  8009633302      M 1965-11-07               2017.0        NaT
# 7716  8009635074      M 1957-01-07               2017.0        NaT
# 7719  8009636704      M 1974-04-12               2017.0        NaT
# 7720  8009636704      M 1974-04-12               2017.0        NaT
# 7727  8009657835      F 1985-08-30               2017.0        NaT
# 7729  8009669708      F 1971-08-19               2017.0        NaT
# 7732  8009694199      M 1948-10-14               2017.0        NaT
# 7735  8009712826      M 1956-01-01               2017.0        NaT
# 7738  8009724274      F 1942-07-30               2017.0        NaT
# 7740  8009728167      F 1957-02-22               2017.0        NaT
# 7755  8009823797      F 1968-01-16               2017.0        NaT
#
#      Surgery_date                        Tumor_type  Tumor_grade Gene_Idh1  \
# 2      1992-04-15                            gliome          3.0    ALTERE
# 3      1986-03-17                       astrocytome          2.0        NC
# 5      1990-02-13                               GBM          4.0    NORMAL
# 7      1989-11-17                               GBM          4.0    NORMAL
# 8      1992-01-22                               GBM          4.0    NORMAL
# 9      1991-10-23                               GBM          4.0    NORMAL
# 10     1990-11-09                               GBM          4.0    NORMAL
# 11     1990-03-28                               GBM          4.0    NORMAL
# 12     1992-02-06                       astrocytome          3.0    NORMAL
# 14     1993-07-07                               GBM          4.0    NORMAL
# 15     1990-06-26                       astrocytome          3.0        NC
# 16     1990-06-26                       astrocytome          3.0        NC
# 17     1992-01-14                            gliome          3.0    NORMAL
# 18     1989-11-08                       astrocytome          2.0    NORMAL
# 19     1989-11-08                       astrocytome          2.0    NORMAL
# 20     1990-11-02                             oligo          3.0    ALTERE
# 24     1990-09-25                       astrocytome          3.0    NORMAL
# 25     1992-05-04                             oligo          2.0    NORMAL
# 27     1988-11-18                               GBM          4.0    NORMAL
# 28     1989-04-25                               GBM          4.0    NORMAL
# 30     1996-08-20                            gliome          3.0    ALTERE
# 31     1989-09-26                               GBM          4.0    NORMAL
# 34     1989-04-12                       astrocytome          2.0        NC
# 35     1989-08-23                               GBM          4.0    NORMAL
# 36     1992-03-10                               GBM          4.0    NORMAL
# 37     1991-02-15                               GBM          4.0    NORMAL
# 40     1991-12-30                               GBM          4.0        NC
# 45     1992-11-17                               GBM          4.0    NORMAL
# 50     1990-04-11                             oligo          3.0    NORMAL
# 51     1990-04-11                             oligo          3.0    NORMAL
# ...           ...                               ...          ...       ...
# 7685   2008-08-27                             oligo          2.0    ALTERE
# 7689   2016-08-31                               GBM          4.0    NORMAL
# 7690   2016-05-03                            gliome          3.0    ALTERE
# 7691   2016-08-23                             oligo          3.0    ALTERE
# 7692   2017-02-06                       astrocytome          3.0    ALTERE
# 7693   2015-10-28                               GBM          4.0    NORMAL
# 7694   2016-06-08                               GBM          4.0        NC
# 7695   2015-09-29                               GBM          4.0    NORMAL
# 7696   2016-07-07                       astrocytome          3.0    NORMAL
# 7697   2016-12-29                               GBM          4.0    ALTERE
# 7698   2005-11-25                             oligo          3.0    ALTERE
# 7700   2013-01-22                               GBM          4.0    ALTERE
# 7701   2006-07-19  astrocytome gémistocytique (=A2)          2.0    ALTERE
# 7704   2016-09-20                               GBM          4.0        NC
# 7707   2016-05-20                       astrocytome          2.0    NORMAL
# 7709   2016-04-06                               GBM          4.0        NC
# 7711   2016-08-30                               GBM          4.0    NORMAL
# 7713   2016-04-28                               GBM          4.0        NC
# 7714   2016-02-18                               GBM          4.0    NORMAL
# 7715   2016-03-17                             oligo          3.0    ALTERE
# 7716   2016-06-27                               GBM          4.0        NC
# 7719   2004-08-17                             oligo          2.0        NC
# 7720   2004-08-17                             oligo          2.0        NC
# 7727   2007-10-08                             oligo          2.0        NC
# 7729   2017-01-26                               GBM          4.0    NORMAL
# 7732   2017-03-08                       astrocytome          3.0    NORMAL
# 7735   2017-03-09                             oligo          3.0    ALTERE
# 7738   2017-03-10                       astrocytome          3.0    NORMAL
# 7740   2017-01-24                               GBM          4.0    NORMAL
# 7755   2017-03-20                               GBM          4.0    NORMAL
#
#      Gene_Idh2 Gene_Htert_C228T Gene_Htert_C250T Gene_P53    Gene_Mgmt  \
# 2       NORMAL           NORMAL           NORMAL       NC          NaN
# 3           NC              NaN              NaN       NC          NaN
# 5          NaN           NORMAL           ALTERE   NORMAL  NON METHYLE
# 7          NaN           NORMAL           NORMAL   NORMAL  NON METHYLE
# 8       NORMAL           NORMAL           ALTERE   NORMAL          NaN
# 9       NORMAL           ALTERE           NORMAL   ALTERE  NON METHYLE
# 10      NORMAL           NORMAL           NORMAL   NORMAL          NaN
# 11         NaN           NORMAL           ALTERE       NC      METHYLE
# 12      NORMAL           ALTERE           NORMAL   NORMAL          NaN
# 14      NORMAL           ALTERE           NORMAL   NORMAL      METHYLE
# 15          NC              NaN              NaN       NC          NaN
# 16          NC              NaN              NaN       NC          NaN
# 17      NORMAL           ALTERE           NORMAL   NORMAL      METHYLE
# 18      NORMAL           NORMAL           NORMAL       NC      METHYLE
# 19      NORMAL           NORMAL           NORMAL       NC      METHYLE
# 20      NORMAL              NaN              NaN   NORMAL          NaN
# 24         NaN           NORMAL           NORMAL   NORMAL          NaN
# 25      NORMAL           NORMAL           NORMAL       NC          NaN
# 27         NaN           NORMAL           ALTERE   NORMAL          NaN
# 28         NaN           ALTERE           NORMAL   NORMAL      METHYLE
# 30      NORMAL              NaN              NaN       NC          NaN
# 31         NaN           NORMAL           NORMAL       NC          NaN
# 34          NC              NaN              NaN       NC          NaN
# 35         NaN           NORMAL           NORMAL   NORMAL      METHYLE
# 36         NaN           ALTERE           NORMAL   NORMAL  NON METHYLE
# 37      NORMAL           ALTERE           NORMAL      NaN  NON METHYLE
# 40          NC              NaN              NaN       NC          NaN
# 45         NaN           NORMAL           NORMAL      NaN      METHYLE
# 50      NORMAL           NORMAL           NORMAL       NC          NaN
# 51      NORMAL           NORMAL           NORMAL       NC          NaN
# ...        ...              ...              ...      ...          ...
# 7685    NORMAL           NORMAL           NORMAL   NORMAL          NaN
# 7689    NORMAL               NC               NC       NC          NaN
# 7690    NORMAL           NORMAL           ALTERE   NORMAL          NaN
# 7691    NORMAL           NORMAL           ALTERE   NORMAL          NaN
# 7692    NORMAL           NORMAL           NORMAL   ALTERE          NaN
# 7693    NORMAL               NC               NC       NC      METHYLE
# 7694        NC               NC               NC       NC          NaN
# 7695    NORMAL           ALTERE           NORMAL       NC          NaN
# 7696    NORMAL           ALTERE           NORMAL   NORMAL          NaN
# 7697        NC               NC               NC       NC          NaN
# 7698    NORMAL           NORMAL           ALTERE      NaN          NaN
# 7700    NORMAL           NORMAL           NORMAL       NC          NaN
# 7701    NORMAL           NORMAL           NORMAL      NaN          NaN
# 7704        NC               NC               NC       NC          NaN
# 7707    NORMAL           NORMAL           NORMAL   NORMAL          NaN
# 7709        NC               NC               NC       NC          NaN
# 7711    NORMAL           NORMAL           NORMAL   ALTERE          NaN
# 7713        NC               NC               NC       NC          NaN
# 7714    NORMAL           ALTERE           NORMAL   NORMAL          NaN
# 7715    NORMAL           NORMAL           ALTERE   NORMAL          NaN
# 7716        NC               NC               NC       NC          NaN
# 7719        NC              NaN              NaN       NC          NaN
# 7720        NC              NaN              NaN       NC          NaN
# 7727        NC              NaN              NaN       NC          NaN
# 7729    NORMAL               NC               NC       NC          NaN
# 7732    NORMAL           ALTERE           NORMAL       NC          NaN
# 7735    NORMAL           NORMAL           ALTERE   NORMAL          NaN
# 7738    NORMAL           NORMAL           NORMAL       NC          NaN
# 7740    NORMAL           ALTERE           NORMAL       NC          NaN
# 7755    NORMAL           NORMAL           ALTERE   ALTERE          NaN
#
#      Gene_Egfr Gene_Mdm2 Gene_Cdk4 Gene_P16       Gene_Ihc_Atrx  Gene_Ch1P  \
# 2       NORMAL       NaN       NaN      NaN                 NaN  NON PERTE
# 3          NaN       NaN       NaN      NaN                 NaN        NaN
# 5       NORMAL    NORMAL    NORMAL   DELETE                 NaN    PARTIEL
# 7       NORMAL    NORMAL    NORMAL   NORMAL                 NaN  NON PERTE
# 8     AMPLIFIE    NORMAL    NORMAL   NORMAL                 NaN       GAIN
# 9     AMPLIFIE    NORMAL    NORMAL   DELETE                 NaN    PARTIEL
# 10      NORMAL    NORMAL    NORMAL   DELETE                 NaN    PARTIEL
# 11      NORMAL    NORMAL    NORMAL   NORMAL                 NaN  NON PERTE
# 12      NORMAL       NaN       NaN      NaN                 NaN  NON PERTE
# 14    AMPLIFIE    NORMAL    NORMAL   DELETE                 NaN    PARTIEL
# 15         NaN       NaN       NaN      NaN                 NaN        NaN
# 16         NaN       NaN       NaN      NaN                 NaN        NaN
# 17    AMPLIFIE    NORMAL    NORMAL   DELETE                 NaN  NON PERTE
# 18         NaN       NaN       NaN      NaN                 NaN  NON PERTE
# 19         NaN       NaN       NaN      NaN                 NaN  NON PERTE
# 20      NORMAL    NORMAL    NORMAL   NORMAL                 NaN      PERDU
# 24         NaN       NaN       NaN      NaN                 NaN  NON PERTE
# 25         NaN       NaN       NaN      NaN                 NaN        NaN
# 27      NORMAL    NORMAL    NORMAL   NORMAL                 NaN    PARTIEL
# 28      NORMAL    NORMAL    NORMAL   DELETE                 NaN  NON PERTE
# 30         NaN       NaN       NaN      NaN                 NaN        NaN
# 31      NORMAL    NORMAL    NORMAL   NORMAL                 NaN  NON PERTE
# 34         NaN       NaN       NaN      NaN                 NaN        NaN
# 35      NORMAL    NORMAL    NORMAL   DELETE                 NaN  NON PERTE
# 36      NORMAL    NORMAL    NORMAL   DELETE                 NaN  NON PERTE
# 37      NORMAL    NORMAL    NORMAL   NORMAL                 NaN  NON PERTE
# 40         NaN       NaN       NaN      NaN                 NaN        NaN
# 45      NORMAL    NORMAL  AMPLIFIE   NORMAL                 NaN  NON PERTE
# 50      NORMAL    NORMAL    NORMAL   NORMAL                 NaN  NON PERTE
# 51      NORMAL    NORMAL    NORMAL   NORMAL                 NaN  NON PERTE
# ...        ...       ...       ...      ...                 ...        ...
# 7685    NORMAL    NORMAL    NORMAL   NORMAL                 NaN      PERDU
# 7689       NaN       NaN       NaN      NaN            Maintien        NaN
# 7690    NORMAL    NORMAL    NORMAL   NORMAL            Maintien      PERDU
# 7691    NORMAL    NORMAL    NORMAL   NORMAL            Maintien      PERDU
# 7692    NORMAL    NORMAL    NORMAL   NORMAL  Extinction diffuse  NON PERTE
# 7693       NaN    NORMAL       NaN      NaN            Maintien        NaN
# 7694       NaN       NaN       NaN      NaN            Maintien        NaN
# 7695       NaN       NaN       NaN      NaN            Maintien        NaN
# 7696  AMPLIFIE    NORMAL    NORMAL   NORMAL            Maintien  NON PERTE
# 7697       NaN       NaN       NaN      NaN            Maintien        NaN
# 7698    NORMAL    NORMAL    NORMAL   NORMAL                 NaN      PERDU
# 7700    NORMAL    NORMAL    NORMAL   NORMAL                 NaN       GAIN
# 7701    NORMAL    NORMAL    NORMAL   NORMAL                 NaN    PARTIEL
# 7704       NaN       NaN       NaN      NaN            Maintien        NaN
# 7707    NORMAL    NORMAL    NORMAL   NORMAL            Maintien       GAIN
# 7709       NaN       NaN       NaN      NaN            Maintien        NaN
# 7711    NORMAL    NORMAL    NORMAL   NORMAL                 NaN  NON PERTE
# 7713       NaN       NaN       NaN      NaN                 NaN        NaN
# 7714    NORMAL    NORMAL    NORMAL   NORMAL            Maintien    PARTIEL
# 7715    NORMAL    NORMAL    NORMAL   NORMAL            Maintien      PERDU
# 7716       NaN       NaN       NaN      NaN            Maintien        NaN
# 7719       NaN       NaN       NaN      NaN                 NaN        NaN
# 7720       NaN       NaN       NaN      NaN                 NaN        NaN
# 7727       NaN       NaN       NaN      NaN                 NaN        NaN
# 7729       NaN       NaN       NaN      NaN            Maintien        NaN
# 7732       NaN       NaN       NaN      NaN                 NaN        NaN
# 7735    NORMAL    NORMAL    NORMAL   NORMAL            Maintien      PERDU
# 7738       NaN       NaN       NaN      NaN  Extinction diffuse        NaN
# 7740       NaN       NaN       NaN      NaN            Maintien        NaN
# 7755    NORMAL    NORMAL    NORMAL   NORMAL            Maintien  NON PERTE
#
#      Gene_Ch19Q Gene_Ch10P Gene_Ch10Q  Gene_Ch9P  Gene_Ch9Q Tumor_Location  \
# 2     NON PERTE  NON PERTE      PERDU  NON PERTE        NaN              A
# 3           NaN        NaN        NaN        NaN        NaN              N
# 5       PARTIEL      PERDU      PERDU      PERDU        NaN              A
# 7     NON PERTE  NON PERTE      PERDU        NaN        NaN              A
# 8     NON PERTE  NON PERTE      PERDU  NON PERTE  NON PERTE              A
# 9     NON PERTE  NON PERTE      PERDU  NON PERTE  NON PERTE              A
# 10      PARTIEL        NaN      PERDU  NON PERTE        NaN              N
# 11    NON PERTE  NON PERTE      PERDU  NON PERTE        NaN              N
# 12          NaN  NON PERTE  NON PERTE  NON PERTE        NaN              A
# 14    NON PERTE      PERDU      PERDU    PARTIEL  NON PERTE              A
# 15          NaN        NaN        NaN        NaN        NaN              A
# 16          NaN        NaN        NaN        NaN        NaN              A
# 17        PERDU      PERDU      PERDU      PERDU        NaN              N
# 18          NaN        NaN  NON PERTE      PERDU        NaN              A
# 19          NaN        NaN  NON PERTE      PERDU        NaN              A
# 20        PERDU  NON PERTE  NON PERTE    PARTIEL        NaN              N
# 24    NON PERTE  NON PERTE  NON PERTE  NON PERTE        NaN              A
# 25          NaN        NaN        NaN        NaN        NaN              A
# 27      PARTIEL      PERDU      PERDU  NON PERTE        NaN              N
# 28    NON PERTE      PERDU      PERDU      PERDU  NON PERTE              N
# 30          NaN        NaN        NaN        NaN        NaN              N
# 31    NON PERTE      PERDU      PERDU      PERDU        NaN              A
# 34          NaN        NaN        NaN        NaN        NaN              A
# 35        PERDU        NaN  NON PERTE  NON PERTE        NaN              A
# 36        PERDU  NON PERTE  NON PERTE      PERDU        NaN              A
# 37      PARTIEL        NaN  NON PERTE  NON PERTE        NaN              A
# 40          NaN        NaN        NaN        NaN        NaN              N
# 45    NON PERTE  NON PERTE  NON PERTE  NON PERTE        NaN              A
# 50          NaN        NaN        NaN      PERDU        NaN              A
# 51          NaN        NaN        NaN      PERDU        NaN              A
# ...         ...        ...        ...        ...        ...            ...
# 7685      PERDU  NON PERTE  NON PERTE    PARTIEL  NON PERTE              N
# 7689        NaN        NaN        NaN        NaN        NaN              A
# 7690      PERDU  NON PERTE  NON PERTE      PERDU  NON PERTE              A
# 7691      PERDU  NON PERTE  NON PERTE  NON PERTE  NON PERTE              A
# 7692  NON PERTE  NON PERTE  NON PERTE  NON PERTE        NaN              A
# 7693        NaN        NaN        NaN        NaN        NaN              A
# 7694        NaN        NaN        NaN        NaN        NaN              A
# 7695        NaN        NaN        NaN        NaN        NaN              A
# 7696  NON PERTE  NON PERTE  NON PERTE  NON PERTE        NaN              A
# 7697        NaN        NaN        NaN        NaN        NaN              A
# 7698      PERDU        NaN  NON PERTE        NaN        NaN              A
# 7700      PERDU  NON PERTE  NON PERTE  NON PERTE  NON PERTE              A
# 7701  NON PERTE    PARTIEL      PERDU  NON PERTE  NON PERTE              A
# 7704        NaN        NaN        NaN        NaN        NaN              A
# 7707       GAIN  NON PERTE  NON PERTE  NON PERTE        NaN              A
# 7709        NaN        NaN        NaN        NaN        NaN              A
# 7711  NON PERTE    PARTIEL    PARTIEL      PERDU        NaN              A
# 7713        NaN        NaN        NaN        NaN        NaN              A
# 7714    PARTIEL      PERDU      PERDU       GAIN        NaN              A
# 7715      PERDU  NON PERTE  NON PERTE  NON PERTE  NON PERTE              A
# 7716        NaN        NaN        NaN        NaN        NaN              A
# 7719        NaN        NaN        NaN        NaN        NaN              A
# 7720        NaN        NaN        NaN        NaN        NaN              A
# 7727        NaN        NaN        NaN        NaN        NaN              A
# 7729        NaN        NaN        NaN        NaN        NaN              A
# 7732        NaN        NaN        NaN        NaN        NaN              A
# 7735      PERDU  NON PERTE  NON PERTE      PERDU        NaN              A
# 7738        NaN        NaN        NaN        NaN        NaN            NaN
# 7740        NaN        NaN        NaN        NaN        NaN              A
# 7755  NON PERTE       GAIN       GAIN  NON PERTE        NaN              A
#
#      Tumor_Position Clinical_evolution Surgery_type    Rx_date  \
# 2                 G             TT ini    partielle 1992-05-01
# 3       non précisé             TT ini      exérèse 1986-04-01
# 5                 G             TT ini       aucune 1990-03-14
# 7                 D             TT ini    partielle 1989-12-18
# 8                 D             TT ini      exérèse        NaT
# 9                 G             TT ini      exérèse 1991-11-19
# 10                G             TT ini      exérèse 1990-12-01
# 11      non précisé             TT ini      exérèse        NaT
# 12                G             TT ini    partielle 1992-03-01
# 14                G             TT ini    partielle 1993-08-11
# 15                D             TT ini      exérèse 1990-11-06
# 16                D             TT ini      exérèse 1990-11-06
# 17                D             TT ini      exérèse 1992-02-15
# 18        bilatéral             TT ini    partielle 1989-12-26
# 19        bilatéral             TT ini    partielle 1989-12-26
# 20        bilatéral             TT ini    partielle 1991-01-01
# 24                G             TT ini    partielle 1990-11-01
# 25                D             TT ini      exérèse        NaT
# 27                G             TT ini      exérèse 1989-12-15
# 28                D             TT ini      exérèse 1989-05-01
# 30                G             TT ini       aucune 1994-05-01
# 31      non précisé             TT ini    partielle 1989-11-20
# 34                D             TT ini    partielle 1989-05-01
# 35                D             TT ini    partielle 1989-09-18
# 36                D             TT ini       aucune 1992-05-01
# 37                D             TT ini      exérèse 1991-03-18
# 40                G             TT ini      exérèse 1992-01-01
# 45                D             TT ini      exérèse 1992-12-14
# 50                D             TT ini    partielle 1990-05-11
# 51                D             TT ini    partielle 1990-05-11
# ...             ...                ...          ...        ...
# 7685    non précisé             TT ini       aucune        NaT
# 7689              D             TT ini    partielle 2016-10-20
# 7690              G             TT ini      exérèse 2016-09-01
# 7691              D             TT ini    partielle        NaT
# 7692              D             TT ini      exérèse        NaT
# 7693              D             TT ini    partielle 2015-11-20
# 7694              G             TT ini    partielle 2016-08-08
# 7695              D             TT ini      biopsie        NaT
# 7696      bilatéral             TT ini      biopsie 2016-08-19
# 7697              D             TT ini    partielle 2017-03-20
# 7698              D             TT ini    partielle        NaT
# 7700              G             TT ini    partielle 2013-05-30
# 7701              D             TT ini      biopsie 2007-01-20
# 7704              D             TT ini      biopsie 2016-11-14
# 7707              G             TT ini      biopsie 2016-09-07
# 7709              D             TT ini    partielle 2016-06-01
# 7711              G             TT ini      exérèse 2016-10-10
# 7713              G             TT ini      biopsie 2016-06-29
# 7714              G             TT ini    partielle 2016-05-10
# 7715              D             TT ini    partielle 2016-06-01
# 7716            NaN             TT ini      biopsie 2016-08-11
# 7719              G             TT ini      biopsie        NaT
# 7720              G             TT ini      biopsie        NaT
# 7727              D             TT ini    partielle        NaT
# 7729              D             TT ini      exérèse 2017-03-01
# 7732              D             TT ini      biopsie        NaT
# 7735              G             TT ini    partielle        NaT
# 7738      bilatéral             TT ini      biopsie 2017-04-26
# 7740              D             TT ini    partielle 2017-03-15
# 7755         médian             TT ini      biopsie 2017-04-13
#
#      Chemo_start_date  Age_surgery  life_expectancy     IDH    TERT
# 2          1992-05-01         42.0             30.0  mutant      wt
# 3                 NaT         28.0           2069.0      NC     NaN
# 5                 NaT         59.0            393.0      wt  mutant
# 7                 NaT         61.0            398.0      wt      wt
# 8                 NaT         58.0            433.0      wt  mutant
# 9                 NaT         56.0            143.0      wt  mutant
# 10                NaT         69.0            408.0      wt      wt
# 11                NaT         66.0              7.0      wt  mutant
# 12                NaT         61.0            316.0      wt  mutant
# 14         1993-08-05         43.0            571.0      wt  mutant
# 15         1990-07-19         58.0           1172.0      NC     NaN
# 16         1990-12-07         58.0           1172.0      NC     NaN
# 17         1992-02-15         49.0            701.0      wt  mutant
# 18         1990-02-16         32.0            521.0      wt      wt
# 19         1990-10-03         32.0            521.0      wt      wt
# 20         1990-12-01         60.0            194.0  mutant     NaN
# 24                NaT         39.0           1255.0      wt      wt
# 25                NaT         34.0            169.0      wt      wt
# 27                NaT         49.0            666.0      wt  mutant
# 28                NaT         72.0            355.0      wt  mutant
# 30                NaT         24.0             60.0  mutant     NaN
# 31         1989-11-01         45.0             96.0      wt      wt
# 34                NaT         15.0            566.0      NC     NaN
# 35         1989-09-01         62.0            320.0      wt      wt
# 36                NaT         22.0            175.0      wt  mutant
# 37         1991-02-28         49.0            997.0      wt  mutant
# 40                NaT         41.0            220.0      NC     NaN
# 45         1992-12-03         60.0            478.0      wt      wt
# 50         1990-07-01         63.0           1269.0      wt      wt
# 51         1991-01-07         63.0           1269.0      wt      wt
# ...               ...          ...              ...     ...     ...
# 7685              NaT         52.0              NaN  mutant      wt
# 7689       2016-12-24         63.0              NaN      wt     NaN
# 7690       2016-10-20         49.0              NaN  mutant  mutant
# 7691       2016-10-14         57.0              NaN  mutant  mutant
# 7692              NaT         20.0              NaN  mutant      wt
# 7693       2016-02-03         72.0              NaN      wt     NaN
# 7694       2016-10-25         53.0              NaN      NC     NaN
# 7695              NaT         53.0              NaN      wt  mutant
# 7696       2016-11-16         48.0            310.0      wt  mutant
# 7697       2017-02-22         72.0              NaN  mutant     NaN
# 7698       2006-02-10         30.0              NaN  mutant  mutant
# 7700       2013-08-22         38.0              NaN  mutant      wt
# 7701              NaT         44.0              NaN  mutant      wt
# 7704       2017-01-24         69.0              NaN      NC     NaN
# 7707       2017-02-01         58.0              NaN      wt      wt
# 7709       2016-08-01         69.0              NaN      NC     NaN
# 7711       2017-01-02         24.0              NaN      wt      wt
# 7713       2016-09-13         47.0              NaN      NC     NaN
# 7714       2016-06-25         46.0              NaN      wt  mutant
# 7715       2016-08-23         50.0              NaN  mutant  mutant
# 7716       2016-10-25         59.0              NaN      NC     NaN
# 7719       2004-10-07         30.0              NaN      NC     NaN
# 7720       2005-04-01         30.0              NaN      NC     NaN
# 7727              NaT         22.0              NaN      NC     NaN
# 7729       2017-03-09         45.0              NaN      wt     NaN
# 7732              NaT         68.0              NaN      wt  mutant
# 7735              NaT         61.0              NaN  mutant  mutant
# 7738              NaT         75.0              NaN      wt      wt
# 7740       2017-03-15         60.0              NaN      wt  mutant
# 7755              NaT         49.0              NaN      wt  mutant
#
# [2430 rows x 35 columns]

# %%
# Marc comment: implementing clinical interaction variable between IDH and TERT
# we will implement this rule based on the underlying IDH1, IDH2, TERT C250T and TERT C228T because they contain more information
# for example if IDH1 is missing, and IDH 2 is NORMAL, IDH will also be missing even though IDH2 is present 
# IDH+ TERT+ == 1 (very good prognosis)
# IDH+ TERT- == 2
# IDH- TERT- == 3
# IDH- TERT+ == 4

df_clean_test.loc[((df_clean_test['Gene_Idh1'] == 'ALTERE') | (df_clean_test['Gene_Idh2'] == 'ALTERE')) & ((df_clean_test['Gene_Htert_C228T'] == "ALTERE") | (df_clean_test['Gene_Htert_C250T'] == "ALTERE")), "IDH_TERT"] = 1; df_clean_test
df_clean_test.loc[((df_clean_test['Gene_Idh1'] == 'ALTERE') | (df_clean_test['Gene_Idh2'] == 'ALTERE')) & ((df_clean_test['Gene_Htert_C228T'] == "NORMAL") | (df_clean_test['Gene_Htert_C250T'] == "NORMAL")), "IDH_TERT"] = 2; df_clean_test
df_clean_test.loc[((df_clean_test['Gene_Idh1'] == 'NORMAL') | (df_clean_test['Gene_Idh2'] == 'NORMAL')) & ((df_clean_test['Gene_Htert_C228T'] == "NORMAL") | (df_clean_test['Gene_Htert_C250T'] == "NORMAL")), "IDH_TERT"] = 3; df_clean_test
df_clean_test.loc[((df_clean_test['Gene_Idh1'] == 'NORMAL') | (df_clean_test['Gene_Idh2'] == 'NORMAL')) & ((df_clean_test['Gene_Htert_C228T'] == "ALTERE") | (df_clean_test['Gene_Htert_C250T'] == "ALTERE")), "IDH_TERT"] = 4; df_clean_test

# ignore below implementation based on IDH and TERT directly
# df_clean_test.loc[(df_clean_test['IDH'] == 'mutant') & (df_clean_test['TERT'] == 'mutant'), "IDH_TERT"] = 1
# df_clean_test.loc[(df_clean_test['IDH'] == 'mutant') & (df_clean_test['TERT'] == 'wt'), "IDH_TERT"] = 2
# df_clean_test.loc[(df_clean_test['IDH'] == 'wt') & (df_clean_test['TERT'] == 'wt'), "IDH_TERT"] = 3
# df_clean_test.loc[(df_clean_test['IDH'] == 'wt') & (df_clean_test['TERT'] == 'mutant'), "IDH_TERT"] = 4
# Out:
#               ID Gender        DoB  Dernieres_nouvelles Death_date  \
# 2             10      M 1949-11-05                  NaN 1992-05-15
# 3             11      M 1958-07-29                  NaN 1991-11-15
# 5             12      F 1930-12-07                  NaN 1991-03-13
# 7             13      M 1928-11-17                  NaN 1990-12-20
# 8             14      F 1934-07-17                  NaN 1993-03-30
# 9             15      M 1936-03-22                  NaN 1992-03-14
# 10            16      M 1922-04-18                  NaN 1991-12-22
# 11            17      M 1924-04-12                  NaN 1990-04-04
# 12            18      F 1931-06-05                  NaN 1992-12-18
# 14            22      M 1950-05-10                  NaN 1995-01-29
# 15            23      F 1932-10-09                  NaN 1993-09-10
# 16            23      F 1932-10-09                  NaN 1993-09-10
# 17            24      M 1943-03-04                  NaN 1993-12-15
# 18            25      M 1957-06-16                  NaN 1991-04-13
# 19            25      M 1957-06-16                  NaN 1991-04-13
# 20            26      M 1930-07-07                  NaN 1991-05-15
# 24            30      M 1952-02-01                  NaN 1994-03-03
# 25            31      M 1957-11-25                  NaN 1992-10-20
# 27            34      F 1939-06-30                  NaN 1990-09-15
# 28            35      F 1917-06-04                  NaN 1990-04-15
# 30            36      F 1972-12-01                  NaN 1996-10-19
# 31            37      M 1945-01-01                  NaN 1989-12-31
# 34            39      F 1974-06-21                  NaN 1990-10-30
# 35            40      M 1927-04-16                  NaN 1990-07-09
# 36            41      M 1970-04-07                  NaN 1992-09-01
# 37            42      F 1942-08-14                  NaN 1993-11-08
# 40            44      M 1951-03-28                  NaN 1992-08-06
# 45            47      F 1932-05-26                  NaN 1994-03-10
# 50            49      M 1927-04-07                  NaN 1993-10-01
# 51            49      M 1927-04-07                  NaN 1993-10-01
# ...          ...    ...        ...                  ...        ...
# 7685  8009475251      F 1956-12-25               2017.0        NaT
# 7689  8009496494      F 1953-07-01               2017.0        NaT
# 7690  8009502080      M 1967-02-03               2017.0        NaT
# 7691  8009502097      F 1959-04-19               2017.0        NaT
# 7692  8009504238      M 1996-12-28               2017.0        NaT
# 7693  8009508609      M 1944-02-26               2017.0        NaT
# 7694  8009509396      M 1963-12-08               2017.0        NaT
# 7695  8009510265      F 1962-06-07               2017.0        NaT
# 7696  8009536357      M 1968-04-16                  NaN 2017-05-13
# 7697  8009538232      M 1945-01-01               2017.0        NaT
# 7698  8009545405      F 1975-09-30               2017.0        NaT
# 7700  8009547563      F 1974-09-11               2017.0        NaT
# 7701  8009558455      F 1962-08-12               2017.0        NaT
# 7704  8009583738      F 1947-03-30               2017.0        NaT
# 7707  8009588647      F 1958-06-26               2017.0        NaT
# 7709  8009606625      F 1947-03-27               2017.0        NaT
# 7711  8009619135      F 1993-02-08               2017.0        NaT
# 7713  8009630406      F 1968-12-22               2017.0        NaT
# 7714  8009631994      M 1970-07-28               2017.0        NaT
# 7715  8009633302      M 1965-11-07               2017.0        NaT
# 7716  8009635074      M 1957-01-07               2017.0        NaT
# 7719  8009636704      M 1974-04-12               2017.0        NaT
# 7720  8009636704      M 1974-04-12               2017.0        NaT
# 7727  8009657835      F 1985-08-30               2017.0        NaT
# 7729  8009669708      F 1971-08-19               2017.0        NaT
# 7732  8009694199      M 1948-10-14               2017.0        NaT
# 7735  8009712826      M 1956-01-01               2017.0        NaT
# 7738  8009724274      F 1942-07-30               2017.0        NaT
# 7740  8009728167      F 1957-02-22               2017.0        NaT
# 7755  8009823797      F 1968-01-16               2017.0        NaT
#
#      Surgery_date                        Tumor_type  Tumor_grade Gene_Idh1  \
# 2      1992-04-15                            gliome          3.0    ALTERE
# 3      1986-03-17                       astrocytome          2.0        NC
# 5      1990-02-13                               GBM          4.0    NORMAL
# 7      1989-11-17                               GBM          4.0    NORMAL
# 8      1992-01-22                               GBM          4.0    NORMAL
# 9      1991-10-23                               GBM          4.0    NORMAL
# 10     1990-11-09                               GBM          4.0    NORMAL
# 11     1990-03-28                               GBM          4.0    NORMAL
# 12     1992-02-06                       astrocytome          3.0    NORMAL
# 14     1993-07-07                               GBM          4.0    NORMAL
# 15     1990-06-26                       astrocytome          3.0        NC
# 16     1990-06-26                       astrocytome          3.0        NC
# 17     1992-01-14                            gliome          3.0    NORMAL
# 18     1989-11-08                       astrocytome          2.0    NORMAL
# 19     1989-11-08                       astrocytome          2.0    NORMAL
# 20     1990-11-02                             oligo          3.0    ALTERE
# 24     1990-09-25                       astrocytome          3.0    NORMAL
# 25     1992-05-04                             oligo          2.0    NORMAL
# 27     1988-11-18                               GBM          4.0    NORMAL
# 28     1989-04-25                               GBM          4.0    NORMAL
# 30     1996-08-20                            gliome          3.0    ALTERE
# 31     1989-09-26                               GBM          4.0    NORMAL
# 34     1989-04-12                       astrocytome          2.0        NC
# 35     1989-08-23                               GBM          4.0    NORMAL
# 36     1992-03-10                               GBM          4.0    NORMAL
# 37     1991-02-15                               GBM          4.0    NORMAL
# 40     1991-12-30                               GBM          4.0        NC
# 45     1992-11-17                               GBM          4.0    NORMAL
# 50     1990-04-11                             oligo          3.0    NORMAL
# 51     1990-04-11                             oligo          3.0    NORMAL
# ...           ...                               ...          ...       ...
# 7685   2008-08-27                             oligo          2.0    ALTERE
# 7689   2016-08-31                               GBM          4.0    NORMAL
# 7690   2016-05-03                            gliome          3.0    ALTERE
# 7691   2016-08-23                             oligo          3.0    ALTERE
# 7692   2017-02-06                       astrocytome          3.0    ALTERE
# 7693   2015-10-28                               GBM          4.0    NORMAL
# 7694   2016-06-08                               GBM          4.0        NC
# 7695   2015-09-29                               GBM          4.0    NORMAL
# 7696   2016-07-07                       astrocytome          3.0    NORMAL
# 7697   2016-12-29                               GBM          4.0    ALTERE
# 7698   2005-11-25                             oligo          3.0    ALTERE
# 7700   2013-01-22                               GBM          4.0    ALTERE
# 7701   2006-07-19  astrocytome gémistocytique (=A2)          2.0    ALTERE
# 7704   2016-09-20                               GBM          4.0        NC
# 7707   2016-05-20                       astrocytome          2.0    NORMAL
# 7709   2016-04-06                               GBM          4.0        NC
# 7711   2016-08-30                               GBM          4.0    NORMAL
# 7713   2016-04-28                               GBM          4.0        NC
# 7714   2016-02-18                               GBM          4.0    NORMAL
# 7715   2016-03-17                             oligo          3.0    ALTERE
# 7716   2016-06-27                               GBM          4.0        NC
# 7719   2004-08-17                             oligo          2.0        NC
# 7720   2004-08-17                             oligo          2.0        NC
# 7727   2007-10-08                             oligo          2.0        NC
# 7729   2017-01-26                               GBM          4.0    NORMAL
# 7732   2017-03-08                       astrocytome          3.0    NORMAL
# 7735   2017-03-09                             oligo          3.0    ALTERE
# 7738   2017-03-10                       astrocytome          3.0    NORMAL
# 7740   2017-01-24                               GBM          4.0    NORMAL
# 7755   2017-03-20                               GBM          4.0    NORMAL
#
#      Gene_Idh2 Gene_Htert_C228T Gene_Htert_C250T Gene_P53    Gene_Mgmt  \
# 2       NORMAL           NORMAL           NORMAL       NC          NaN
# 3           NC              NaN              NaN       NC          NaN
# 5          NaN           NORMAL           ALTERE   NORMAL  NON METHYLE
# 7          NaN           NORMAL           NORMAL   NORMAL  NON METHYLE
# 8       NORMAL           NORMAL           ALTERE   NORMAL          NaN
# 9       NORMAL           ALTERE           NORMAL   ALTERE  NON METHYLE
# 10      NORMAL           NORMAL           NORMAL   NORMAL          NaN
# 11         NaN           NORMAL           ALTERE       NC      METHYLE
# 12      NORMAL           ALTERE           NORMAL   NORMAL          NaN
# 14      NORMAL           ALTERE           NORMAL   NORMAL      METHYLE
# 15          NC              NaN              NaN       NC          NaN
# 16          NC              NaN              NaN       NC          NaN
# 17      NORMAL           ALTERE           NORMAL   NORMAL      METHYLE
# 18      NORMAL           NORMAL           NORMAL       NC      METHYLE
# 19      NORMAL           NORMAL           NORMAL       NC      METHYLE
# 20      NORMAL              NaN              NaN   NORMAL          NaN
# 24         NaN           NORMAL           NORMAL   NORMAL          NaN
# 25      NORMAL           NORMAL           NORMAL       NC          NaN
# 27         NaN           NORMAL           ALTERE   NORMAL          NaN
# 28         NaN           ALTERE           NORMAL   NORMAL      METHYLE
# 30      NORMAL              NaN              NaN       NC          NaN
# 31         NaN           NORMAL           NORMAL       NC          NaN
# 34          NC              NaN              NaN       NC          NaN
# 35         NaN           NORMAL           NORMAL   NORMAL      METHYLE
# 36         NaN           ALTERE           NORMAL   NORMAL  NON METHYLE
# 37      NORMAL           ALTERE           NORMAL      NaN  NON METHYLE
# 40          NC              NaN              NaN       NC          NaN
# 45         NaN           NORMAL           NORMAL      NaN      METHYLE
# 50      NORMAL           NORMAL           NORMAL       NC          NaN
# 51      NORMAL           NORMAL           NORMAL       NC          NaN
# ...        ...              ...              ...      ...          ...
# 7685    NORMAL           NORMAL           NORMAL   NORMAL          NaN
# 7689    NORMAL               NC               NC       NC          NaN
# 7690    NORMAL           NORMAL           ALTERE   NORMAL          NaN
# 7691    NORMAL           NORMAL           ALTERE   NORMAL          NaN
# 7692    NORMAL           NORMAL           NORMAL   ALTERE          NaN
# 7693    NORMAL               NC               NC       NC      METHYLE
# 7694        NC               NC               NC       NC          NaN
# 7695    NORMAL           ALTERE           NORMAL       NC          NaN
# 7696    NORMAL           ALTERE           NORMAL   NORMAL          NaN
# 7697        NC               NC               NC       NC          NaN
# 7698    NORMAL           NORMAL           ALTERE      NaN          NaN
# 7700    NORMAL           NORMAL           NORMAL       NC          NaN
# 7701    NORMAL           NORMAL           NORMAL      NaN          NaN
# 7704        NC               NC               NC       NC          NaN
# 7707    NORMAL           NORMAL           NORMAL   NORMAL          NaN
# 7709        NC               NC               NC       NC          NaN
# 7711    NORMAL           NORMAL           NORMAL   ALTERE          NaN
# 7713        NC               NC               NC       NC          NaN
# 7714    NORMAL           ALTERE           NORMAL   NORMAL          NaN
# 7715    NORMAL           NORMAL           ALTERE   NORMAL          NaN
# 7716        NC               NC               NC       NC          NaN
# 7719        NC              NaN              NaN       NC          NaN
# 7720        NC              NaN              NaN       NC          NaN
# 7727        NC              NaN              NaN       NC          NaN
# 7729    NORMAL               NC               NC       NC          NaN
# 7732    NORMAL           ALTERE           NORMAL       NC          NaN
# 7735    NORMAL           NORMAL           ALTERE   NORMAL          NaN
# 7738    NORMAL           NORMAL           NORMAL       NC          NaN
# 7740    NORMAL           ALTERE           NORMAL       NC          NaN
# 7755    NORMAL           NORMAL           ALTERE   ALTERE          NaN
#
#      Gene_Egfr Gene_Mdm2 Gene_Cdk4 Gene_P16       Gene_Ihc_Atrx  Gene_Ch1P  \
# 2       NORMAL       NaN       NaN      NaN                 NaN  NON PERTE
# 3          NaN       NaN       NaN      NaN                 NaN        NaN
# 5       NORMAL    NORMAL    NORMAL   DELETE                 NaN    PARTIEL
# 7       NORMAL    NORMAL    NORMAL   NORMAL                 NaN  NON PERTE
# 8     AMPLIFIE    NORMAL    NORMAL   NORMAL                 NaN       GAIN
# 9     AMPLIFIE    NORMAL    NORMAL   DELETE                 NaN    PARTIEL
# 10      NORMAL    NORMAL    NORMAL   DELETE                 NaN    PARTIEL
# 11      NORMAL    NORMAL    NORMAL   NORMAL                 NaN  NON PERTE
# 12      NORMAL       NaN       NaN      NaN                 NaN  NON PERTE
# 14    AMPLIFIE    NORMAL    NORMAL   DELETE                 NaN    PARTIEL
# 15         NaN       NaN       NaN      NaN                 NaN        NaN
# 16         NaN       NaN       NaN      NaN                 NaN        NaN
# 17    AMPLIFIE    NORMAL    NORMAL   DELETE                 NaN  NON PERTE
# 18         NaN       NaN       NaN      NaN                 NaN  NON PERTE
# 19         NaN       NaN       NaN      NaN                 NaN  NON PERTE
# 20      NORMAL    NORMAL    NORMAL   NORMAL                 NaN      PERDU
# 24         NaN       NaN       NaN      NaN                 NaN  NON PERTE
# 25         NaN       NaN       NaN      NaN                 NaN        NaN
# 27      NORMAL    NORMAL    NORMAL   NORMAL                 NaN    PARTIEL
# 28      NORMAL    NORMAL    NORMAL   DELETE                 NaN  NON PERTE
# 30         NaN       NaN       NaN      NaN                 NaN        NaN
# 31      NORMAL    NORMAL    NORMAL   NORMAL                 NaN  NON PERTE
# 34         NaN       NaN       NaN      NaN                 NaN        NaN
# 35      NORMAL    NORMAL    NORMAL   DELETE                 NaN  NON PERTE
# 36      NORMAL    NORMAL    NORMAL   DELETE                 NaN  NON PERTE
# 37      NORMAL    NORMAL    NORMAL   NORMAL                 NaN  NON PERTE
# 40         NaN       NaN       NaN      NaN                 NaN        NaN
# 45      NORMAL    NORMAL  AMPLIFIE   NORMAL                 NaN  NON PERTE
# 50      NORMAL    NORMAL    NORMAL   NORMAL                 NaN  NON PERTE
# 51      NORMAL    NORMAL    NORMAL   NORMAL                 NaN  NON PERTE
# ...        ...       ...       ...      ...                 ...        ...
# 7685    NORMAL    NORMAL    NORMAL   NORMAL                 NaN      PERDU
# 7689       NaN       NaN       NaN      NaN            Maintien        NaN
# 7690    NORMAL    NORMAL    NORMAL   NORMAL            Maintien      PERDU
# 7691    NORMAL    NORMAL    NORMAL   NORMAL            Maintien      PERDU
# 7692    NORMAL    NORMAL    NORMAL   NORMAL  Extinction diffuse  NON PERTE
# 7693       NaN    NORMAL       NaN      NaN            Maintien        NaN
# 7694       NaN       NaN       NaN      NaN            Maintien        NaN
# 7695       NaN       NaN       NaN      NaN            Maintien        NaN
# 7696  AMPLIFIE    NORMAL    NORMAL   NORMAL            Maintien  NON PERTE
# 7697       NaN       NaN       NaN      NaN            Maintien        NaN
# 7698    NORMAL    NORMAL    NORMAL   NORMAL                 NaN      PERDU
# 7700    NORMAL    NORMAL    NORMAL   NORMAL                 NaN       GAIN
# 7701    NORMAL    NORMAL    NORMAL   NORMAL                 NaN    PARTIEL
# 7704       NaN       NaN       NaN      NaN            Maintien        NaN
# 7707    NORMAL    NORMAL    NORMAL   NORMAL            Maintien       GAIN
# 7709       NaN       NaN       NaN      NaN            Maintien        NaN
# 7711    NORMAL    NORMAL    NORMAL   NORMAL                 NaN  NON PERTE
# 7713       NaN       NaN       NaN      NaN                 NaN        NaN
# 7714    NORMAL    NORMAL    NORMAL   NORMAL            Maintien    PARTIEL
# 7715    NORMAL    NORMAL    NORMAL   NORMAL            Maintien      PERDU
# 7716       NaN       NaN       NaN      NaN            Maintien        NaN
# 7719       NaN       NaN       NaN      NaN                 NaN        NaN
# 7720       NaN       NaN       NaN      NaN                 NaN        NaN
# 7727       NaN       NaN       NaN      NaN                 NaN        NaN
# 7729       NaN       NaN       NaN      NaN            Maintien        NaN
# 7732       NaN       NaN       NaN      NaN                 NaN        NaN
# 7735    NORMAL    NORMAL    NORMAL   NORMAL            Maintien      PERDU
# 7738       NaN       NaN       NaN      NaN  Extinction diffuse        NaN
# 7740       NaN       NaN       NaN      NaN            Maintien        NaN
# 7755    NORMAL    NORMAL    NORMAL   NORMAL            Maintien  NON PERTE
#
#      Gene_Ch19Q Gene_Ch10P Gene_Ch10Q  Gene_Ch9P  Gene_Ch9Q Tumor_Location  \
# 2     NON PERTE  NON PERTE      PERDU  NON PERTE        NaN              A
# 3           NaN        NaN        NaN        NaN        NaN              N
# 5       PARTIEL      PERDU      PERDU      PERDU        NaN              A
# 7     NON PERTE  NON PERTE      PERDU        NaN        NaN              A
# 8     NON PERTE  NON PERTE      PERDU  NON PERTE  NON PERTE              A
# 9     NON PERTE  NON PERTE      PERDU  NON PERTE  NON PERTE              A
# 10      PARTIEL        NaN      PERDU  NON PERTE        NaN              N
# 11    NON PERTE  NON PERTE      PERDU  NON PERTE        NaN              N
# 12          NaN  NON PERTE  NON PERTE  NON PERTE        NaN              A
# 14    NON PERTE      PERDU      PERDU    PARTIEL  NON PERTE              A
# 15          NaN        NaN        NaN        NaN        NaN              A
# 16          NaN        NaN        NaN        NaN        NaN              A
# 17        PERDU      PERDU      PERDU      PERDU        NaN              N
# 18          NaN        NaN  NON PERTE      PERDU        NaN              A
# 19          NaN        NaN  NON PERTE      PERDU        NaN              A
# 20        PERDU  NON PERTE  NON PERTE    PARTIEL        NaN              N
# 24    NON PERTE  NON PERTE  NON PERTE  NON PERTE        NaN              A
# 25          NaN        NaN        NaN        NaN        NaN              A
# 27      PARTIEL      PERDU      PERDU  NON PERTE        NaN              N
# 28    NON PERTE      PERDU      PERDU      PERDU  NON PERTE              N
# 30          NaN        NaN        NaN        NaN        NaN              N
# 31    NON PERTE      PERDU      PERDU      PERDU        NaN              A
# 34          NaN        NaN        NaN        NaN        NaN              A
# 35        PERDU        NaN  NON PERTE  NON PERTE        NaN              A
# 36        PERDU  NON PERTE  NON PERTE      PERDU        NaN              A
# 37      PARTIEL        NaN  NON PERTE  NON PERTE        NaN              A
# 40          NaN        NaN        NaN        NaN        NaN              N
# 45    NON PERTE  NON PERTE  NON PERTE  NON PERTE        NaN              A
# 50          NaN        NaN        NaN      PERDU        NaN              A
# 51          NaN        NaN        NaN      PERDU        NaN              A
# ...         ...        ...        ...        ...        ...            ...
# 7685      PERDU  NON PERTE  NON PERTE    PARTIEL  NON PERTE              N
# 7689        NaN        NaN        NaN        NaN        NaN              A
# 7690      PERDU  NON PERTE  NON PERTE      PERDU  NON PERTE              A
# 7691      PERDU  NON PERTE  NON PERTE  NON PERTE  NON PERTE              A
# 7692  NON PERTE  NON PERTE  NON PERTE  NON PERTE        NaN              A
# 7693        NaN        NaN        NaN        NaN        NaN              A
# 7694        NaN        NaN        NaN        NaN        NaN              A
# 7695        NaN        NaN        NaN        NaN        NaN              A
# 7696  NON PERTE  NON PERTE  NON PERTE  NON PERTE        NaN              A
# 7697        NaN        NaN        NaN        NaN        NaN              A
# 7698      PERDU        NaN  NON PERTE        NaN        NaN              A
# 7700      PERDU  NON PERTE  NON PERTE  NON PERTE  NON PERTE              A
# 7701  NON PERTE    PARTIEL      PERDU  NON PERTE  NON PERTE              A
# 7704        NaN        NaN        NaN        NaN        NaN              A
# 7707       GAIN  NON PERTE  NON PERTE  NON PERTE        NaN              A
# 7709        NaN        NaN        NaN        NaN        NaN              A
# 7711  NON PERTE    PARTIEL    PARTIEL      PERDU        NaN              A
# 7713        NaN        NaN        NaN        NaN        NaN              A
# 7714    PARTIEL      PERDU      PERDU       GAIN        NaN              A
# 7715      PERDU  NON PERTE  NON PERTE  NON PERTE  NON PERTE              A
# 7716        NaN        NaN        NaN        NaN        NaN              A
# 7719        NaN        NaN        NaN        NaN        NaN              A
# 7720        NaN        NaN        NaN        NaN        NaN              A
# 7727        NaN        NaN        NaN        NaN        NaN              A
# 7729        NaN        NaN        NaN        NaN        NaN              A
# 7732        NaN        NaN        NaN        NaN        NaN              A
# 7735      PERDU  NON PERTE  NON PERTE      PERDU        NaN              A
# 7738        NaN        NaN        NaN        NaN        NaN            NaN
# 7740        NaN        NaN        NaN        NaN        NaN              A
# 7755  NON PERTE       GAIN       GAIN  NON PERTE        NaN              A
#
#      Tumor_Position Clinical_evolution Surgery_type    Rx_date  \
# 2                 G             TT ini    partielle 1992-05-01
# 3       non précisé             TT ini      exérèse 1986-04-01
# 5                 G             TT ini       aucune 1990-03-14
# 7                 D             TT ini    partielle 1989-12-18
# 8                 D             TT ini      exérèse        NaT
# 9                 G             TT ini      exérèse 1991-11-19
# 10                G             TT ini      exérèse 1990-12-01
# 11      non précisé             TT ini      exérèse        NaT
# 12                G             TT ini    partielle 1992-03-01
# 14                G             TT ini    partielle 1993-08-11
# 15                D             TT ini      exérèse 1990-11-06
# 16                D             TT ini      exérèse 1990-11-06
# 17                D             TT ini      exérèse 1992-02-15
# 18        bilatéral             TT ini    partielle 1989-12-26
# 19        bilatéral             TT ini    partielle 1989-12-26
# 20        bilatéral             TT ini    partielle 1991-01-01
# 24                G             TT ini    partielle 1990-11-01
# 25                D             TT ini      exérèse        NaT
# 27                G             TT ini      exérèse 1989-12-15
# 28                D             TT ini      exérèse 1989-05-01
# 30                G             TT ini       aucune 1994-05-01
# 31      non précisé             TT ini    partielle 1989-11-20
# 34                D             TT ini    partielle 1989-05-01
# 35                D             TT ini    partielle 1989-09-18
# 36                D             TT ini       aucune 1992-05-01
# 37                D             TT ini      exérèse 1991-03-18
# 40                G             TT ini      exérèse 1992-01-01
# 45                D             TT ini      exérèse 1992-12-14
# 50                D             TT ini    partielle 1990-05-11
# 51                D             TT ini    partielle 1990-05-11
# ...             ...                ...          ...        ...
# 7685    non précisé             TT ini       aucune        NaT
# 7689              D             TT ini    partielle 2016-10-20
# 7690              G             TT ini      exérèse 2016-09-01
# 7691              D             TT ini    partielle        NaT
# 7692              D             TT ini      exérèse        NaT
# 7693              D             TT ini    partielle 2015-11-20
# 7694              G             TT ini    partielle 2016-08-08
# 7695              D             TT ini      biopsie        NaT
# 7696      bilatéral             TT ini      biopsie 2016-08-19
# 7697              D             TT ini    partielle 2017-03-20
# 7698              D             TT ini    partielle        NaT
# 7700              G             TT ini    partielle 2013-05-30
# 7701              D             TT ini      biopsie 2007-01-20
# 7704              D             TT ini      biopsie 2016-11-14
# 7707              G             TT ini      biopsie 2016-09-07
# 7709              D             TT ini    partielle 2016-06-01
# 7711              G             TT ini      exérèse 2016-10-10
# 7713              G             TT ini      biopsie 2016-06-29
# 7714              G             TT ini    partielle 2016-05-10
# 7715              D             TT ini    partielle 2016-06-01
# 7716            NaN             TT ini      biopsie 2016-08-11
# 7719              G             TT ini      biopsie        NaT
# 7720              G             TT ini      biopsie        NaT
# 7727              D             TT ini    partielle        NaT
# 7729              D             TT ini      exérèse 2017-03-01
# 7732              D             TT ini      biopsie        NaT
# 7735              G             TT ini    partielle        NaT
# 7738      bilatéral             TT ini      biopsie 2017-04-26
# 7740              D             TT ini    partielle 2017-03-15
# 7755         médian             TT ini      biopsie 2017-04-13
#
#      Chemo_start_date  Age_surgery  life_expectancy     IDH    TERT  IDH_TERT
# 2          1992-05-01         42.0             30.0  mutant      wt       3.0
# 3                 NaT         28.0           2069.0      NC     NaN       NaN
# 5                 NaT         59.0            393.0      wt  mutant       4.0
# 7                 NaT         61.0            398.0      wt      wt       3.0
# 8                 NaT         58.0            433.0      wt  mutant       4.0
# 9                 NaT         56.0            143.0      wt  mutant       4.0
# 10                NaT         69.0            408.0      wt      wt       3.0
# 11                NaT         66.0              7.0      wt  mutant       4.0
# 12                NaT         61.0            316.0      wt  mutant       4.0
# 14         1993-08-05         43.0            571.0      wt  mutant       4.0
# 15         1990-07-19         58.0           1172.0      NC     NaN       NaN
# 16         1990-12-07         58.0           1172.0      NC     NaN       NaN
# 17         1992-02-15         49.0            701.0      wt  mutant       4.0
# 18         1990-02-16         32.0            521.0      wt      wt       3.0
# 19         1990-10-03         32.0            521.0      wt      wt       3.0
# 20         1990-12-01         60.0            194.0  mutant     NaN       NaN
# 24                NaT         39.0           1255.0      wt      wt       3.0
# 25                NaT         34.0            169.0      wt      wt       3.0
# 27                NaT         49.0            666.0      wt  mutant       4.0
# 28                NaT         72.0            355.0      wt  mutant       4.0
# 30                NaT         24.0             60.0  mutant     NaN       NaN
# 31         1989-11-01         45.0             96.0      wt      wt       3.0
# 34                NaT         15.0            566.0      NC     NaN       NaN
# 35         1989-09-01         62.0            320.0      wt      wt       3.0
# 36                NaT         22.0            175.0      wt  mutant       4.0
# 37         1991-02-28         49.0            997.0      wt  mutant       4.0
# 40                NaT         41.0            220.0      NC     NaN       NaN
# 45         1992-12-03         60.0            478.0      wt      wt       3.0
# 50         1990-07-01         63.0           1269.0      wt      wt       3.0
# 51         1991-01-07         63.0           1269.0      wt      wt       3.0
# ...               ...          ...              ...     ...     ...       ...
# 7685              NaT         52.0              NaN  mutant      wt       3.0
# 7689       2016-12-24         63.0              NaN      wt     NaN       NaN
# 7690       2016-10-20         49.0              NaN  mutant  mutant       4.0
# 7691       2016-10-14         57.0              NaN  mutant  mutant       4.0
# 7692              NaT         20.0              NaN  mutant      wt       3.0
# 7693       2016-02-03         72.0              NaN      wt     NaN       NaN
# 7694       2016-10-25         53.0              NaN      NC     NaN       NaN
# 7695              NaT         53.0              NaN      wt  mutant       4.0
# 7696       2016-11-16         48.0            310.0      wt  mutant       4.0
# 7697       2017-02-22         72.0              NaN  mutant     NaN       NaN
# 7698       2006-02-10         30.0              NaN  mutant  mutant       4.0
# 7700       2013-08-22         38.0              NaN  mutant      wt       3.0
# 7701              NaT         44.0              NaN  mutant      wt       3.0
# 7704       2017-01-24         69.0              NaN      NC     NaN       NaN
# 7707       2017-02-01         58.0              NaN      wt      wt       3.0
# 7709       2016-08-01         69.0              NaN      NC     NaN       NaN
# 7711       2017-01-02         24.0              NaN      wt      wt       3.0
# 7713       2016-09-13         47.0              NaN      NC     NaN       NaN
# 7714       2016-06-25         46.0              NaN      wt  mutant       4.0
# 7715       2016-08-23         50.0              NaN  mutant  mutant       4.0
# 7716       2016-10-25         59.0              NaN      NC     NaN       NaN
# 7719       2004-10-07         30.0              NaN      NC     NaN       NaN
# 7720       2005-04-01         30.0              NaN      NC     NaN       NaN
# 7727              NaT         22.0              NaN      NC     NaN       NaN
# 7729       2017-03-09         45.0              NaN      wt     NaN       NaN
# 7732              NaT         68.0              NaN      wt  mutant       4.0
# 7735              NaT         61.0              NaN  mutant  mutant       4.0
# 7738              NaT         75.0              NaN      wt      wt       3.0
# 7740       2017-03-15         60.0              NaN      wt  mutant       4.0
# 7755              NaT         49.0              NaN      wt  mutant       4.0
#
# [2430 rows x 36 columns]

# %%
#now delete IDH1 and IDH2 variables
df_clean_test.drop("Gene_Idh1", axis = 1, inplace=True)
df_clean_test.drop("Gene_Idh2", axis = 1, inplace=True)

# %%
#now delete TERT variables C228T and C250T
df_clean_test.drop("Gene_Htert_C228T", axis = 1, inplace=True)
df_clean_test.drop("Gene_Htert_C250T", axis = 1, inplace=True)

# %%
# Marc comment: implementing clinical 1p19q codeletion variable
# 1p19q codel instead of 'Gene_Ch1P', 'Gene_Ch19Q'= in fact not relevant when separated (consider complete loss, 
# no partial loss) = What is important is : 1p19q codélétion and this is always associated with IDH
# 1p19q codélétion = 'Gene_Ch1P loss AND  'Gene_Ch19Q loss AND IDH mutant (see above)

# if Ch1P is "PERDU" AND CH19Q is PERDU, then 1p19q_codel = 1
df_clean_test.loc[(df_clean_test['Gene_Ch1P'] == 'PERDU') & (df_clean_test['Gene_Ch19Q'] == 'PERDU'), "1p19q_codel"] = 1

#problem with following command is that if one value is missing, it will also impute 0 instead of keeping it as missing
#df_clean_test.loc[((df_clean_test['Gene_Ch1P'] != 'PERDU') | (df_clean_test['Gene_Ch19Q'] != 'PERDU'), "1p19q_codel"] = 0

# if ((Ch1P is not null) AND (CH19Q is not null)) AND ((Ch1Q != PERDU) OR (Ch19Q != PERDU)) then 1p19q_codel is 0

df_clean_test.loc[((df_clean_test['Gene_Ch1P'].notnull()) & (df_clean_test['Gene_Ch19Q'].notnull()) & ((df_clean_test['Gene_Ch1P'] != 'PERDU') | (df_clean_test['Gene_Ch19Q'] != 'PERDU'))), "1p19q_codel"] = 0

# %%
df_clean_test['1p19q_codel'].isnull().value_counts()
# Out:
# True     1299
# False    1131
# Name: 1p19q_codel, dtype: int64

# %%
# Marc comment: now delete 1P and 19Q since alone they are each insignificant
df_clean_test.drop("Gene_Ch1P", axis = 1, inplace=True)
df_clean_test.drop("Gene_Ch19Q", axis = 1, inplace=True)

# %%
# Marc comment: If IDH is missing, the tumor type is GBM, and the patient is >55 y, the probability of 
# IDHmutation is around 5%, so you may also consider to fill this gap
# we will use age at surgery here for this purpose
# we will impute both IDH missing and IDH NC (non conclusive) based on this rule

df_clean_test.loc[((df_clean_test['IDH'].isnull()) & (df_clean_test['Tumor_type'] == "GBM") & (df_clean_test['Age_surgery'] > 55.0)), "IDH"] = "wt"
df_clean_test.loc[((df_clean_test['IDH'] == "NC") & (df_clean_test['Tumor_type'] == "GBM") & (df_clean_test['Age_surgery'] > 55.0)), "IDH"] = "wt"

# %%
# Marc comment: delete Dwh Chr CH9Q
df_clean_test.drop("Gene_Ch9Q", axis = 1, inplace=True)

# %%
# Marc comment: recode CH9P
df_clean_test['Gene_Ch9P'].replace({"PARTIEL":"PERTE", "PERDU": "PERTE"}, inplace=True)

# %%
# sanity check of above recoding
df_clean_test['Gene_Ch9P'].value_counts()
# Out:
# NON PERTE    580
# PERTE        505
# GAIN          32
# Name: Gene_Ch9P, dtype: int64

# %%
# for Ch10Q, consider just instance where = PERDU, per Marc comments
# create binary variable PERTE and NON PERTE therefore
df_clean_test['Gene_Ch10Q'].replace({"PERDU":"PERTE", "PARTIEL": "NON PERTE", "GAIN": "NON PERTE"}, inplace=True)

# %%
# sanity check of the above
df_clean_test['Gene_Ch10Q'].value_counts()
# Out:
# PERTE        570
# NON PERTE    568
# Name: Gene_Ch10Q, dtype: int64

# %%
# Marc comment: delete Ch10P
df_clean_test.drop("Gene_Ch10P", axis = 1, inplace=True)

# %%
# Marc comment: IDHmut-Tertmut are 1p19codel in 90% of the cases
# impute missing 1p19q codel values per above
df_clean_test.loc[(df_clean_test['IDH_TERT'] == 1) & (df_clean_test['1p19q_codel'].isnull()), "1p19q_codel"] = 1

# %%
# Marc comment: IDHmut-Tertwt are ATRX mut in 90% of the cases
# impute missing ATRX values per above
df_clean_test.loc[(df_clean_test['IDH_TERT'] == 2) & (df_clean_test['Gene_Ihc_Atrx'].isnull()), "Gene_Ihc_Atrx"] = "extinction"

# %%
# Marc comment: EGFR amplification is extremely rare in IDH mutant
# impute missing EGFR values per above
df_clean_test.loc[(df_clean_test['IDH'] == "mutant") & (df_clean_test['Gene_Egfr'].isnull()), "Gene_Egfr"] = "NORMAL"

# %% [markdown]
# #Marc comment: EGFR amplification never occurs in 1p19q codel
# #impute missing EGFR values per above
# df_clean_test.loc[(df_clean_test['1p19q_codel'] == 1) & (df_clean_test['Gene_Egfr'].isnull()), "Gene_Egfr"] = "NORMAL"

# %%
# Marc comment: Loss of chr 10q is rarely associated with IDH mutant (<5%) and almost never (1%) with 1p19q codel
df_clean_test.loc[(df_clean_test['IDH'] == "mutant") & (df_clean_test['Gene_Ch10Q'].isnull()), "Gene_Ch10Q"] = "NON PERTE"
df_clean_test.loc[(df_clean_test['1p19q_codel'] == 1) & (df_clean_test['Gene_Ch10Q'].isnull()), "Gene_Ch10Q"] = "NON PERTE"

# %%
# We keep only the first record of patients with multiple surgeries
df_clean_test['ID'].duplicated().value_counts()
# Out:
# False    2358
# True       72
# Name: ID, dtype: int64

# %%
# Sort by ID and Surgery date, in order to keep only earliest surgery date
df_clean_test.sort_values(['ID', 'Surgery_date'], inplace=True)

# %%
# Indicate whether duplicate and check sum of them
df_clean_test['multiple_surgeries'] = df_clean_test.duplicated(['ID'])
df_clean_test['multiple_surgeries'].sum()
# Out:
# 72

# %%
# Reduce to observations that don't have multiple surgeries

df_clean_test.drop_duplicates('ID',keep='first',inplace=True)
df_clean_test.head(5)
# Out:
#    ID Gender        DoB  Dernieres_nouvelles Death_date Surgery_date  \
# 2  10      M 1949-11-05                  NaN 1992-05-15   1992-04-15
# 3  11      M 1958-07-29                  NaN 1991-11-15   1986-03-17
# 5  12      F 1930-12-07                  NaN 1991-03-13   1990-02-13
# 7  13      M 1928-11-17                  NaN 1990-12-20   1989-11-17
# 8  14      F 1934-07-17                  NaN 1993-03-30   1992-01-22
#
#     Tumor_type  Tumor_grade Gene_P53    Gene_Mgmt Gene_Egfr Gene_Mdm2  \
# 2       gliome          3.0       NC          NaN    NORMAL       NaN
# 3  astrocytome          2.0       NC          NaN       NaN       NaN
# 5          GBM          4.0   NORMAL  NON METHYLE    NORMAL    NORMAL
# 7          GBM          4.0   NORMAL  NON METHYLE    NORMAL    NORMAL
# 8          GBM          4.0   NORMAL          NaN  AMPLIFIE    NORMAL
#
#   Gene_Cdk4 Gene_P16 Gene_Ihc_Atrx Gene_Ch10Q  Gene_Ch9P Tumor_Location  \
# 2       NaN      NaN           NaN      PERTE  NON PERTE              A
# 3       NaN      NaN           NaN        NaN        NaN              N
# 5    NORMAL   DELETE           NaN      PERTE      PERTE              A
# 7    NORMAL   NORMAL           NaN      PERTE        NaN              A
# 8    NORMAL   NORMAL           NaN      PERTE  NON PERTE              A
#
#   Tumor_Position Clinical_evolution Surgery_type    Rx_date Chemo_start_date  \
# 2              G             TT ini    partielle 1992-05-01       1992-05-01
# 3    non précisé             TT ini      exérèse 1986-04-01              NaT
# 5              G             TT ini       aucune 1990-03-14              NaT
# 7              D             TT ini    partielle 1989-12-18              NaT
# 8              D             TT ini      exérèse        NaT              NaT
#
#    Age_surgery  life_expectancy     IDH    TERT  IDH_TERT  1p19q_codel  \
# 2         42.0             30.0  mutant      wt       3.0          0.0
# 3         28.0           2069.0      NC     NaN       NaN          NaN
# 5         59.0            393.0      wt  mutant       4.0          0.0
# 7         61.0            398.0      wt      wt       3.0          0.0
# 8         58.0            433.0      wt  mutant       4.0          0.0
#
#   multiple_surgeries
# 2              False
# 3              False
# 5              False
# 7              False
# 8              False

# %%
df_final = df_clean_test.copy(deep=True)
df_final.multiple_surgeries.isnull().value_counts()
# Out:
# False    2358
# Name: multiple_surgeries, dtype: int64

# %%
# They seem to have been datetime objects without the below conversions?
# See here why we need to use loc: 
# https://stackoverflow.com/questions/26724378/pandas-settingwithcopywarning?noredirect=1&lq=1

df_final.loc[:,'Rx_date'] = pd.to_datetime(df_final.Rx_date,errors = 'coerce')
df_final.loc[:,'Chemo_start_date'] = pd.to_datetime(df_final.Chemo_start_date,errors = 'coerce')

df_final.loc[:,'Rx_date'] = df_final['Rx_date'].dt.year
df_final.loc[:,'Chemo_start_date']=df_final.Chemo_start_date.dt.year

# %%
# Useful
#for col in df_clean.columns:
 #    print('{0}\n  {1}\n'.format(col,df_clean[col].isnull().value_counts()))

# %% [markdown]
# # Merge KPS dataset

# %%
# Import KPS dataset to merge it
kps = pd.read_excel('Dropbox/Healthcare work Patric/KPS.xlsx')

# %%
# Sort by ID and surgery date, as above
kps.sort_values(['NIP', 'CHIR_DATE'],inplace=True)

# %%
# Reduce to single observations as with multiple surgeries from previous dataset
kps.drop_duplicates('NIP',keep='first',inplace=True)

# %%
kps.shape
# Out:
# (6772, 6)

# %%
# Keep only columns that are of interest or needed for the merge
kps_sorted_final = kps[['NIP', 'ID_EC', 'IK_CLINIQUE', 'CHIR_DATE', 'CHIR_IK_PRE', 'RX_IK_PRE']]

# %%
# Merge the two datasets using surgery date and chirurgie date, only the later is not a datetime.
# Use ID for merge as well 
kps.loc[:,'CHIR_DATE'] = pd.to_datetime(kps.CHIR_DATE, errors = 'coerce')

# %%
df_final_kps = pd.merge(df_final, kps, how = 'left', left_on = ['ID', 'Surgery_date'], right_on = ['NIP', 'CHIR_DATE'])

# %%
len(df_final)
# Out:
# 2358

# %%
len(df_final_kps)
# Out:
# 2358

# %%
df_final_kps
# Out:
#               ID Gender        DoB  Dernieres_nouvelles Death_date  \
# 0             10      M 1949-11-05                  NaN 1992-05-15
# 1             11      M 1958-07-29                  NaN 1991-11-15
# 2             12      F 1930-12-07                  NaN 1991-03-13
# 3             13      M 1928-11-17                  NaN 1990-12-20
# 4             14      F 1934-07-17                  NaN 1993-03-30
# 5             15      M 1936-03-22                  NaN 1992-03-14
# 6             16      M 1922-04-18                  NaN 1991-12-22
# 7             17      M 1924-04-12                  NaN 1990-04-04
# 8             18      F 1931-06-05                  NaN 1992-12-18
# 9             22      M 1950-05-10                  NaN 1995-01-29
# 10            23      F 1932-10-09                  NaN 1993-09-10
# 11            24      M 1943-03-04                  NaN 1993-12-15
# 12            25      M 1957-06-16                  NaN 1991-04-13
# 13            26      M 1930-07-07                  NaN 1991-05-15
# 14            30      M 1952-02-01                  NaN 1994-03-03
# 15            31      M 1957-11-25                  NaN 1992-10-20
# 16            34      F 1939-06-30                  NaN 1990-09-15
# 17            35      F 1917-06-04                  NaN 1990-04-15
# 18            36      F 1972-12-01                  NaN 1996-10-19
# 19            37      M 1945-01-01                  NaN 1989-12-31
# 20            39      F 1974-06-21                  NaN 1990-10-30
# 21            40      M 1927-04-16                  NaN 1990-07-09
# 22            41      M 1970-04-07                  NaN 1992-09-01
# 23            42      F 1942-08-14                  NaN 1993-11-08
# 24            44      M 1951-03-28                  NaN 1992-08-06
# 25            47      F 1932-05-26                  NaN 1994-03-10
# 26            49      M 1927-04-07                  NaN 1993-10-01
# 27            50      M 1930-11-01                  NaN 1990-02-15
# 28            51      M 1932-04-29                  NaN 1991-10-01
# 29            53      F 1926-10-20                  NaN 1992-12-15
# ...          ...    ...        ...                  ...        ...
# 2328  8009474433      M 1969-07-16               2017.0        NaT
# 2329  8009475251      F 1956-12-25               2017.0        NaT
# 2330  8009496494      F 1953-07-01               2017.0        NaT
# 2331  8009502080      M 1967-02-03               2017.0        NaT
# 2332  8009502097      F 1959-04-19               2017.0        NaT
# 2333  8009504238      M 1996-12-28               2017.0        NaT
# 2334  8009508609      M 1944-02-26               2017.0        NaT
# 2335  8009509396      M 1963-12-08               2017.0        NaT
# 2336  8009510265      F 1962-06-07               2017.0        NaT
# 2337  8009536357      M 1968-04-16                  NaN 2017-05-13
# 2338  8009538232      M 1945-01-01               2017.0        NaT
# 2339  8009545405      F 1975-09-30               2017.0        NaT
# 2340  8009547563      F 1974-09-11               2017.0        NaT
# 2341  8009558455      F 1962-08-12               2017.0        NaT
# 2342  8009583738      F 1947-03-30               2017.0        NaT
# 2343  8009588647      F 1958-06-26               2017.0        NaT
# 2344  8009606625      F 1947-03-27               2017.0        NaT
# 2345  8009619135      F 1993-02-08               2017.0        NaT
# 2346  8009630406      F 1968-12-22               2017.0        NaT
# 2347  8009631994      M 1970-07-28               2017.0        NaT
# 2348  8009633302      M 1965-11-07               2017.0        NaT
# 2349  8009635074      M 1957-01-07               2017.0        NaT
# 2350  8009636704      M 1974-04-12               2017.0        NaT
# 2351  8009657835      F 1985-08-30               2017.0        NaT
# 2352  8009669708      F 1971-08-19               2017.0        NaT
# 2353  8009694199      M 1948-10-14               2017.0        NaT
# 2354  8009712826      M 1956-01-01               2017.0        NaT
# 2355  8009724274      F 1942-07-30               2017.0        NaT
# 2356  8009728167      F 1957-02-22               2017.0        NaT
# 2357  8009823797      F 1968-01-16               2017.0        NaT
#
#      Surgery_date                        Tumor_type  Tumor_grade Gene_P53  \
# 0      1992-04-15                            gliome          3.0       NC
# 1      1986-03-17                       astrocytome          2.0       NC
# 2      1990-02-13                               GBM          4.0   NORMAL
# 3      1989-11-17                               GBM          4.0   NORMAL
# 4      1992-01-22                               GBM          4.0   NORMAL
# 5      1991-10-23                               GBM          4.0   ALTERE
# 6      1990-11-09                               GBM          4.0   NORMAL
# 7      1990-03-28                               GBM          4.0       NC
# 8      1992-02-06                       astrocytome          3.0   NORMAL
# 9      1993-07-07                               GBM          4.0   NORMAL
# 10     1990-06-26                       astrocytome          3.0       NC
# 11     1992-01-14                            gliome          3.0   NORMAL
# 12     1989-11-08                       astrocytome          2.0       NC
# 13     1990-11-02                             oligo          3.0   NORMAL
# 14     1990-09-25                       astrocytome          3.0   NORMAL
# 15     1992-05-04                             oligo          2.0       NC
# 16     1988-11-18                               GBM          4.0   NORMAL
# 17     1989-04-25                               GBM          4.0   NORMAL
# 18     1996-08-20                            gliome          3.0       NC
# 19     1989-09-26                               GBM          4.0       NC
# 20     1989-04-12                       astrocytome          2.0       NC
# 21     1989-08-23                               GBM          4.0   NORMAL
# 22     1992-03-10                               GBM          4.0   NORMAL
# 23     1991-02-15                               GBM          4.0      NaN
# 24     1991-12-30                               GBM          4.0       NC
# 25     1992-11-17                               GBM          4.0      NaN
# 26     1990-04-11                             oligo          3.0       NC
# 27     1989-10-19                               GBM          4.0   NORMAL
# 28     1991-08-02                       astrocytome          3.0       NC
# 29     1990-12-20                       astrocytome          3.0       NC
# ...           ...                               ...          ...      ...
# 2328   2015-10-06                               GBM          4.0       NC
# 2329   2008-08-27                             oligo          2.0   NORMAL
# 2330   2016-08-31                               GBM          4.0       NC
# 2331   2016-05-03                            gliome          3.0   NORMAL
# 2332   2016-08-23                             oligo          3.0   NORMAL
# 2333   2017-02-06                       astrocytome          3.0   ALTERE
# 2334   2015-10-28                               GBM          4.0       NC
# 2335   2016-06-08                               GBM          4.0       NC
# 2336   2015-09-29                               GBM          4.0       NC
# 2337   2016-07-07                       astrocytome          3.0   NORMAL
# 2338   2016-12-29                               GBM          4.0       NC
# 2339   2005-11-25                             oligo          3.0      NaN
# 2340   2013-01-22                               GBM          4.0       NC
# 2341   2006-07-19  astrocytome gémistocytique (=A2)          2.0      NaN
# 2342   2016-09-20                               GBM          4.0       NC
# 2343   2016-05-20                       astrocytome          2.0   NORMAL
# 2344   2016-04-06                               GBM          4.0       NC
# 2345   2016-08-30                               GBM          4.0   ALTERE
# 2346   2016-04-28                               GBM          4.0       NC
# 2347   2016-02-18                               GBM          4.0   NORMAL
# 2348   2016-03-17                             oligo          3.0   NORMAL
# 2349   2016-06-27                               GBM          4.0       NC
# 2350   2004-08-17                             oligo          2.0       NC
# 2351   2007-10-08                             oligo          2.0       NC
# 2352   2017-01-26                               GBM          4.0       NC
# 2353   2017-03-08                       astrocytome          3.0       NC
# 2354   2017-03-09                             oligo          3.0   NORMAL
# 2355   2017-03-10                       astrocytome          3.0       NC
# 2356   2017-01-24                               GBM          4.0       NC
# 2357   2017-03-20                               GBM          4.0   ALTERE
#
#         Gene_Mgmt Gene_Egfr Gene_Mdm2 Gene_Cdk4 Gene_P16       Gene_Ihc_Atrx  \
# 0             NaN    NORMAL       NaN       NaN      NaN                 NaN
# 1             NaN       NaN       NaN       NaN      NaN                 NaN
# 2     NON METHYLE    NORMAL    NORMAL    NORMAL   DELETE                 NaN
# 3     NON METHYLE    NORMAL    NORMAL    NORMAL   NORMAL                 NaN
# 4             NaN  AMPLIFIE    NORMAL    NORMAL   NORMAL                 NaN
# 5     NON METHYLE  AMPLIFIE    NORMAL    NORMAL   DELETE                 NaN
# 6             NaN    NORMAL    NORMAL    NORMAL   DELETE                 NaN
# 7         METHYLE    NORMAL    NORMAL    NORMAL   NORMAL                 NaN
# 8             NaN    NORMAL       NaN       NaN      NaN                 NaN
# 9         METHYLE  AMPLIFIE    NORMAL    NORMAL   DELETE                 NaN
# 10            NaN       NaN       NaN       NaN      NaN                 NaN
# 11        METHYLE  AMPLIFIE    NORMAL    NORMAL   DELETE                 NaN
# 12        METHYLE       NaN       NaN       NaN      NaN                 NaN
# 13            NaN    NORMAL    NORMAL    NORMAL   NORMAL                 NaN
# 14            NaN       NaN       NaN       NaN      NaN                 NaN
# 15            NaN       NaN       NaN       NaN      NaN                 NaN
# 16            NaN    NORMAL    NORMAL    NORMAL   NORMAL                 NaN
# 17        METHYLE    NORMAL    NORMAL    NORMAL   DELETE                 NaN
# 18            NaN    NORMAL       NaN       NaN      NaN                 NaN
# 19            NaN    NORMAL    NORMAL    NORMAL   NORMAL                 NaN
# 20            NaN       NaN       NaN       NaN      NaN                 NaN
# 21        METHYLE    NORMAL    NORMAL    NORMAL   DELETE                 NaN
# 22    NON METHYLE    NORMAL    NORMAL    NORMAL   DELETE                 NaN
# 23    NON METHYLE    NORMAL    NORMAL    NORMAL   NORMAL                 NaN
# 24            NaN       NaN       NaN       NaN      NaN                 NaN
# 25        METHYLE    NORMAL    NORMAL  AMPLIFIE   NORMAL                 NaN
# 26            NaN    NORMAL    NORMAL    NORMAL   NORMAL                 NaN
# 27        METHYLE    NORMAL    NORMAL    NORMAL   DELETE                 NaN
# 28            NaN    NORMAL    NORMAL    NORMAL   NORMAL                 NaN
# 29            NaN       NaN       NaN       NaN      NaN                 NaN
# ...           ...       ...       ...       ...      ...                 ...
# 2328          NaN       NaN       NaN       NaN      NaN            Maintien
# 2329          NaN    NORMAL    NORMAL    NORMAL   NORMAL                 NaN
# 2330          NaN       NaN       NaN       NaN      NaN            Maintien
# 2331          NaN    NORMAL    NORMAL    NORMAL   NORMAL            Maintien
# 2332          NaN    NORMAL    NORMAL    NORMAL   NORMAL            Maintien
# 2333          NaN    NORMAL    NORMAL    NORMAL   NORMAL  Extinction diffuse
# 2334      METHYLE       NaN    NORMAL       NaN      NaN            Maintien
# 2335          NaN       NaN       NaN       NaN      NaN            Maintien
# 2336          NaN       NaN       NaN       NaN      NaN            Maintien
# 2337          NaN  AMPLIFIE    NORMAL    NORMAL   NORMAL            Maintien
# 2338          NaN    NORMAL       NaN       NaN      NaN            Maintien
# 2339          NaN    NORMAL    NORMAL    NORMAL   NORMAL                 NaN
# 2340          NaN    NORMAL    NORMAL    NORMAL   NORMAL                 NaN
# 2341          NaN    NORMAL    NORMAL    NORMAL   NORMAL                 NaN
# 2342          NaN       NaN       NaN       NaN      NaN            Maintien
# 2343          NaN    NORMAL    NORMAL    NORMAL   NORMAL            Maintien
# 2344          NaN       NaN       NaN       NaN      NaN            Maintien
# 2345          NaN    NORMAL    NORMAL    NORMAL   NORMAL                 NaN
# 2346          NaN       NaN       NaN       NaN      NaN                 NaN
# 2347          NaN    NORMAL    NORMAL    NORMAL   NORMAL            Maintien
# 2348          NaN    NORMAL    NORMAL    NORMAL   NORMAL            Maintien
# 2349          NaN       NaN       NaN       NaN      NaN            Maintien
# 2350          NaN       NaN       NaN       NaN      NaN                 NaN
# 2351          NaN       NaN       NaN       NaN      NaN                 NaN
# 2352          NaN       NaN       NaN       NaN      NaN            Maintien
# 2353          NaN       NaN       NaN       NaN      NaN                 NaN
# 2354          NaN    NORMAL    NORMAL    NORMAL   NORMAL            Maintien
# 2355          NaN       NaN       NaN       NaN      NaN  Extinction diffuse
# 2356          NaN       NaN       NaN       NaN      NaN            Maintien
# 2357          NaN    NORMAL    NORMAL    NORMAL   NORMAL            Maintien
#
#      Gene_Ch10Q  Gene_Ch9P Tumor_Location Tumor_Position Clinical_evolution  \
# 0         PERTE  NON PERTE              A              G             TT ini
# 1           NaN        NaN              N    non précisé             TT ini
# 2         PERTE      PERTE              A              G             TT ini
# 3         PERTE        NaN              A              D             TT ini
# 4         PERTE  NON PERTE              A              D             TT ini
# 5         PERTE  NON PERTE              A              G             TT ini
# 6         PERTE  NON PERTE              N              G             TT ini
# 7         PERTE  NON PERTE              N    non précisé             TT ini
# 8     NON PERTE  NON PERTE              A              G             TT ini
# 9         PERTE      PERTE              A              G             TT ini
# 10          NaN        NaN              A              D             TT ini
# 11        PERTE      PERTE              N              D             TT ini
# 12    NON PERTE      PERTE              A      bilatéral             TT ini
# 13    NON PERTE      PERTE              N      bilatéral             TT ini
# 14    NON PERTE  NON PERTE              A              G             TT ini
# 15          NaN        NaN              A              D             TT ini
# 16        PERTE  NON PERTE              N              G             TT ini
# 17        PERTE      PERTE              N              D             TT ini
# 18    NON PERTE        NaN              N              G             TT ini
# 19        PERTE      PERTE              A    non précisé             TT ini
# 20          NaN        NaN              A              D             TT ini
# 21    NON PERTE  NON PERTE              A              D             TT ini
# 22    NON PERTE      PERTE              A              D             TT ini
# 23    NON PERTE  NON PERTE              A              D             TT ini
# 24          NaN        NaN              N              G             TT ini
# 25    NON PERTE  NON PERTE              A              D             TT ini
# 26          NaN      PERTE              A              D             TT ini
# 27    NON PERTE      PERTE              N              G             TT ini
# 28    NON PERTE  NON PERTE              A              D             TT ini
# 29          NaN        NaN              N              D             TT ini
# ...         ...        ...            ...            ...                ...
# 2328        NaN        NaN              A              G             TT ini
# 2329  NON PERTE      PERTE              N    non précisé             TT ini
# 2330        NaN        NaN              A              D             TT ini
# 2331  NON PERTE      PERTE              A              G             TT ini
# 2332  NON PERTE  NON PERTE              A              D             TT ini
# 2333  NON PERTE  NON PERTE              A              D             TT ini
# 2334        NaN        NaN              A              D             TT ini
# 2335        NaN        NaN              A              G             TT ini
# 2336        NaN        NaN              A              D             TT ini
# 2337  NON PERTE  NON PERTE              A      bilatéral             TT ini
# 2338  NON PERTE        NaN              A              D             TT ini
# 2339  NON PERTE        NaN              A              D             TT ini
# 2340  NON PERTE  NON PERTE              A              G             TT ini
# 2341      PERTE  NON PERTE              A              D             TT ini
# 2342        NaN        NaN              A              D             TT ini
# 2343  NON PERTE  NON PERTE              A              G             TT ini
# 2344        NaN        NaN              A              D             TT ini
# 2345  NON PERTE      PERTE              A              G             TT ini
# 2346        NaN        NaN              A              G             TT ini
# 2347      PERTE       GAIN              A              G             TT ini
# 2348  NON PERTE  NON PERTE              A              D             TT ini
# 2349        NaN        NaN              A            NaN             TT ini
# 2350        NaN        NaN              A              G             TT ini
# 2351        NaN        NaN              A              D             TT ini
# 2352        NaN        NaN              A              D             TT ini
# 2353        NaN        NaN              A              D             TT ini
# 2354  NON PERTE      PERTE              A              G             TT ini
# 2355        NaN        NaN            NaN      bilatéral             TT ini
# 2356        NaN        NaN              A              D             TT ini
# 2357  NON PERTE  NON PERTE              A         médian             TT ini
#
#      Surgery_type  Rx_date  Chemo_start_date  Age_surgery  life_expectancy  \
# 0       partielle   1992.0            1992.0         42.0             30.0
# 1         exérèse   1986.0               NaN         28.0           2069.0
# 2          aucune   1990.0               NaN         59.0            393.0
# 3       partielle   1989.0               NaN         61.0            398.0
# 4         exérèse      NaN               NaN         58.0            433.0
# 5         exérèse   1991.0               NaN         56.0            143.0
# 6         exérèse   1990.0               NaN         69.0            408.0
# 7         exérèse      NaN               NaN         66.0              7.0
# 8       partielle   1992.0               NaN         61.0            316.0
# 9       partielle   1993.0            1993.0         43.0            571.0
# 10        exérèse   1990.0            1990.0         58.0           1172.0
# 11        exérèse   1992.0            1992.0         49.0            701.0
# 12      partielle   1989.0            1990.0         32.0            521.0
# 13      partielle   1991.0            1990.0         60.0            194.0
# 14      partielle   1990.0               NaN         39.0           1255.0
# 15        exérèse      NaN               NaN         34.0            169.0
# 16        exérèse   1989.0               NaN         49.0            666.0
# 17        exérèse   1989.0               NaN         72.0            355.0
# 18         aucune   1994.0               NaN         24.0             60.0
# 19      partielle   1989.0            1989.0         45.0             96.0
# 20      partielle   1989.0               NaN         15.0            566.0
# 21      partielle   1989.0            1989.0         62.0            320.0
# 22         aucune   1992.0               NaN         22.0            175.0
# 23        exérèse   1991.0            1991.0         49.0            997.0
# 24        exérèse   1992.0               NaN         41.0            220.0
# 25        exérèse   1992.0            1992.0         60.0            478.0
# 26      partielle   1990.0            1990.0         63.0           1269.0
# 27        exérèse   1989.0               NaN         59.0            119.0
# 28      partielle   1991.0            1991.0         59.0             60.0
# 29        exérèse   1991.0            1991.0         64.0            726.0
# ...           ...      ...               ...          ...              ...
# 2328      biopsie   2015.0            2016.0         46.0              NaN
# 2329       aucune      NaN               NaN         52.0              NaN
# 2330    partielle   2016.0            2016.0         63.0              NaN
# 2331      exérèse   2016.0            2016.0         49.0              NaN
# 2332    partielle      NaN            2016.0         57.0              NaN
# 2333      exérèse      NaN               NaN         20.0              NaN
# 2334    partielle   2015.0            2016.0         72.0              NaN
# 2335    partielle   2016.0            2016.0         53.0              NaN
# 2336      biopsie      NaN               NaN         53.0              NaN
# 2337      biopsie   2016.0            2016.0         48.0            310.0
# 2338    partielle   2017.0            2017.0         72.0              NaN
# 2339    partielle      NaN            2006.0         30.0              NaN
# 2340    partielle   2013.0            2013.0         38.0              NaN
# 2341      biopsie   2007.0               NaN         44.0              NaN
# 2342      biopsie   2016.0            2017.0         69.0              NaN
# 2343      biopsie   2016.0            2017.0         58.0              NaN
# 2344    partielle   2016.0            2016.0         69.0              NaN
# 2345      exérèse   2016.0            2017.0         24.0              NaN
# 2346      biopsie   2016.0            2016.0         47.0              NaN
# 2347    partielle   2016.0            2016.0         46.0              NaN
# 2348    partielle   2016.0            2016.0         50.0              NaN
# 2349      biopsie   2016.0            2016.0         59.0              NaN
# 2350      biopsie      NaN            2004.0         30.0              NaN
# 2351    partielle      NaN               NaN         22.0              NaN
# 2352      exérèse   2017.0            2017.0         45.0              NaN
# 2353      biopsie      NaN               NaN         68.0              NaN
# 2354    partielle      NaN               NaN         61.0              NaN
# 2355      biopsie   2017.0               NaN         75.0              NaN
# 2356    partielle   2017.0            2017.0         60.0              NaN
# 2357      biopsie   2017.0               NaN         49.0              NaN
#
#          IDH    TERT  IDH_TERT  1p19q_codel multiple_surgeries           NIP  \
# 0     mutant      wt       3.0          0.0              False  1.000000e+01
# 1         NC     NaN       NaN          NaN              False           NaN
# 2         wt  mutant       4.0          0.0              False  1.200000e+01
# 3         wt      wt       3.0          0.0              False  1.300000e+01
# 4         wt  mutant       4.0          0.0              False  1.400000e+01
# 5         wt  mutant       4.0          0.0              False  1.500000e+01
# 6         wt      wt       3.0          0.0              False           NaN
# 7         wt  mutant       4.0          0.0              False  1.700000e+01
# 8         wt  mutant       4.0          NaN              False           NaN
# 9         wt  mutant       4.0          0.0              False  2.200000e+01
# 10        NC     NaN       NaN          NaN              False  2.300000e+01
# 11        wt  mutant       4.0          0.0              False  2.400000e+01
# 12        wt      wt       3.0          NaN              False           NaN
# 13    mutant     NaN       NaN          1.0              False           NaN
# 14        wt      wt       3.0          0.0              False  3.000000e+01
# 15        wt      wt       3.0          NaN              False           NaN
# 16        wt  mutant       4.0          0.0              False  3.400000e+01
# 17        wt  mutant       4.0          0.0              False  3.500000e+01
# 18    mutant     NaN       NaN          NaN              False           NaN
# 19        wt      wt       3.0          0.0              False  3.700000e+01
# 20        NC     NaN       NaN          NaN              False           NaN
# 21        wt      wt       3.0          0.0              False  4.000000e+01
# 22        wt  mutant       4.0          0.0              False           NaN
# 23        wt  mutant       4.0          0.0              False  4.200000e+01
# 24        NC     NaN       NaN          NaN              False           NaN
# 25        wt      wt       3.0          0.0              False  4.700000e+01
# 26        wt      wt       3.0          NaN              False           NaN
# 27        wt  mutant       4.0          0.0              False  5.000000e+01
# 28    mutant      wt       3.0          0.0              False           NaN
# 29        wt  mutant       4.0          NaN              False  5.300000e+01
# ...      ...     ...       ...          ...                ...           ...
# 2328      NC     NaN       NaN          NaN              False           NaN
# 2329  mutant      wt       3.0          1.0              False           NaN
# 2330      wt     NaN       NaN          NaN              False  8.009496e+09
# 2331  mutant  mutant       4.0          1.0              False           NaN
# 2332  mutant  mutant       4.0          1.0              False  8.009502e+09
# 2333  mutant      wt       3.0          0.0              False           NaN
# 2334      wt     NaN       NaN          NaN              False           NaN
# 2335      NC     NaN       NaN          NaN              False           NaN
# 2336      wt  mutant       4.0          NaN              False           NaN
# 2337      wt  mutant       4.0          0.0              False  8.009536e+09
# 2338  mutant     NaN       NaN          NaN              False  8.009538e+09
# 2339  mutant  mutant       4.0          1.0              False  8.009545e+09
# 2340  mutant      wt       3.0          0.0              False  8.009548e+09
# 2341  mutant      wt       3.0          0.0              False  8.009558e+09
# 2342      wt     NaN       NaN          NaN              False  8.009584e+09
# 2343      wt      wt       3.0          0.0              False  8.009589e+09
# 2344      wt     NaN       NaN          NaN              False           NaN
# 2345      wt      wt       3.0          0.0              False           NaN
# 2346      NC     NaN       NaN          NaN              False  8.009630e+09
# 2347      wt  mutant       4.0          0.0              False           NaN
# 2348  mutant  mutant       4.0          1.0              False  8.009633e+09
# 2349      wt     NaN       NaN          NaN              False  8.009635e+09
# 2350      NC     NaN       NaN          NaN              False  8.009637e+09
# 2351      NC     NaN       NaN          NaN              False           NaN
# 2352      wt     NaN       NaN          NaN              False  8.009670e+09
# 2353      wt  mutant       4.0          NaN              False           NaN
# 2354  mutant  mutant       4.0          1.0              False           NaN
# 2355      wt      wt       3.0          NaN              False           NaN
# 2356      wt  mutant       4.0          NaN              False  8.009728e+09
# 2357      wt  mutant       4.0          0.0              False  8.009824e+09
#
#       ID_EC  CHIR_DATE  IK_CLINIQUE  CHIR_IK_PRE  RX_IK_PRE
# 0     TTini 1992-04-15          NaN          NaN        NaN
# 1       NaN        NaT          NaN          NaN        NaN
# 2     TTini 1990-02-13          NaN          NaN       70.0
# 3     TTini 1989-11-17          NaN         60.0        NaN
# 4     TTini 1992-01-22          NaN         70.0        NaN
# 5     TTini 1991-10-23          NaN         80.0       80.0
# 6       NaN        NaT          NaN          NaN        NaN
# 7     TTini 1990-03-28          NaN          NaN        NaN
# 8       NaN        NaT          NaN          NaN        NaN
# 9     TTini 1993-07-07          NaN         80.0       90.0
# 10    TTini 1990-06-26          NaN         90.0       90.0
# 11    TTini 1992-01-14          NaN        100.0        NaN
# 12      NaN        NaT          NaN          NaN        NaN
# 13      NaN        NaT          NaN          NaN        NaN
# 14    TTini 1990-09-25          NaN        100.0      100.0
# 15      NaN        NaT          NaN          NaN        NaN
# 16    TTini 1988-11-18          NaN          NaN       40.0
# 17    TTini 1989-04-25          NaN          NaN       50.0
# 18      NaN        NaT          NaN          NaN        NaN
# 19    TTini 1989-09-26          NaN        100.0        NaN
# 20      NaN        NaT          NaN          NaN        NaN
# 21    TTini 1989-08-23          NaN         80.0        NaN
# 22      NaN        NaT          NaN          NaN        NaN
# 23    TTini 1991-02-15          NaN         90.0       90.0
# 24      NaN        NaT          NaN          NaN        NaN
# 25    TTini 1992-11-17          NaN         60.0       80.0
# 26      NaN        NaT          NaN          NaN        NaN
# 27    TTini 1989-10-19          NaN          NaN       90.0
# 28      NaN        NaT          NaN          NaN        NaN
# 29    TTini 1990-12-20          NaN        100.0      100.0
# ...     ...        ...          ...          ...        ...
# 2328    NaN        NaT          NaN          NaN        NaN
# 2329    NaN        NaT          NaN          NaN        NaN
# 2330  TTini 2016-08-31          NaN         80.0       90.0
# 2331    NaN        NaT          NaN          NaN        NaN
# 2332  TTini 2016-08-23         90.0         90.0        NaN
# 2333    NaN        NaT          NaN          NaN        NaN
# 2334    NaN        NaT          NaN          NaN        NaN
# 2335    NaN        NaT          NaN          NaN        NaN
# 2336    NaN        NaT          NaN          NaN        NaN
# 2337  TTini 2016-07-07          NaN         80.0       70.0
# 2338  TTini 2016-12-29          NaN         80.0       80.0
# 2339  TTini 2005-11-25          NaN         90.0        NaN
# 2340  TTini 2013-01-22         90.0         90.0       90.0
# 2341  TTini 2006-07-19          NaN         90.0       90.0
# 2342  TTini 2016-09-20          NaN         80.0       90.0
# 2343  TTini 2016-05-20         70.0         70.0       90.0
# 2344    NaN        NaT          NaN          NaN        NaN
# 2345    NaN        NaT          NaN          NaN        NaN
# 2346  TTini 2016-04-28          NaN         80.0        NaN
# 2347    NaN        NaT          NaN          NaN        NaN
# 2348  TTini 2016-03-17          NaN         80.0       80.0
# 2349  TTini 2016-06-27          NaN         70.0       80.0
# 2350  TTini 2004-08-17          NaN        100.0        NaN
# 2351    NaN        NaT          NaN          NaN        NaN
# 2352  TTini 2017-01-26          NaN         70.0       80.0
# 2353    NaN        NaT          NaN          NaN        NaN
# 2354    NaN        NaT          NaN          NaN        NaN
# 2355    NaN        NaT          NaN          NaN        NaN
# 2356  TTini 2017-01-24          NaN         80.0       90.0
# 2357  TTini 2017-03-20          NaN         80.0       70.0
#
# [2358 rows x 36 columns]

# %%
# Clinical_evolution has no missing values. ID_EC is a duplicate of Clinical_evolution, from KPS dataset - let's delete it
df_final_kps.drop("ID_EC", axis = 1, inplace=True)

# %%
# Marc comment: IK = take just one value : 'CHIR_IK_PRE', and if CHIR_IK_PRE is missing, take the average of the two others
df_final_kps['IK'] = df_final_kps['CHIR_IK_PRE']
df_final_kps.loc[(df_final_kps['IK'].isnull()) & (df_final_kps['IK_CLINIQUE'].notnull()) & (df_final_kps['RX_IK_PRE'].notnull()), 'IK'] = (df_final_kps['IK_CLINIQUE'] + df_final_kps['RX_IK_PRE'])/2
df_final_kps.loc[(df_final_kps['IK'].isnull()) & (df_final_kps['IK_CLINIQUE'].isnull()) & (df_final_kps['RX_IK_PRE'].notnull()), 'IK'] = df_final_kps['RX_IK_PRE'] 
df_final_kps.loc[(df_final_kps['IK'].isnull()) & (df_final_kps['IK_CLINIQUE'].notnull()) & (df_final_kps['RX_IK_PRE'].isnull()), 'IK'] = df_final_kps['IK_CLINIQUE']

# %%
# now drop all IK variables except for "IK"
df_final_kps.drop('CHIR_IK_PRE', axis =1, inplace = True)
df_final_kps.drop('IK_CLINIQUE', axis = 1, inplace = True)
df_final_kps.drop('RX_IK_PRE', axis = 1, inplace = True)

# %% [markdown]
# # Looks good so far

# %%
# Code Rx date into either 1 if date is present, or leave it as missing otherwise
df_final_kps['RX'] = np.where(df_final_kps['Rx_date'].notnull(), 1, np.NaN)

# %%
df_final_kps['CHEM'] = np.where(df_final_kps['Chemo_start_date'].notnull(), 1, np.NaN)

# %%
#drop NIP as it's duplicate of ID after the merge
#drop multiple surgeries as it was only needed to remove duplicates
#drop CHIR Date as it comes from KPS dataset after merge and is duplicate of Surgery_date
#drop Rx_date and Chemo_start_date
#Final dataset before imputation
df_final_kps.drop('NIP', axis = 1, inplace=True)
df_final_kps.drop('multiple_surgeries', axis = 1, inplace=True)
df_final_kps.drop('CHIR_DATE', axis = 1, inplace=True)
df_final_kps.drop('Chemo_start_date', axis = 1, inplace=True)
df_final_kps.drop('Rx_date', axis = 1, inplace=True)

# %%
len(df_final_kps.columns)
# Out:
# 29

# %%
#Drop death date
#Drop Dernieres nouvelles
#Drop surgery date
#drop clinical evolution
#drop DoB
df_final_kps.drop('Death_date', axis = 1, inplace=True)
df_final_kps.drop('Surgery_date', axis = 1, inplace=True)
df_final_kps.drop('Dernieres_nouvelles', axis = 1, inplace=True)
df_final_kps.drop('Clinical_evolution', axis = 1, inplace=True)
df_final_kps.drop('DoB', axis = 1, inplace=True)

# %%
len(df_final_kps.columns)
# Out:
# 24

# %%
df_final_kps.head(2)
# Out:
#   Gender   Tumor_type  Tumor_grade Gene_P53 Gene_Mgmt Gene_Egfr Gene_Mdm2  \
# 0      M       gliome          3.0       NC       NaN    NORMAL       NaN
# 1      M  astrocytome          2.0       NC       NaN       NaN       NaN
#
#   Gene_Cdk4 Gene_P16 Gene_Ihc_Atrx Gene_Ch10Q  Gene_Ch9P Tumor_Location  \
# 0       NaN      NaN           NaN      PERTE  NON PERTE              A
# 1       NaN      NaN           NaN        NaN        NaN              N
#
#   Tumor_Position Surgery_type  Age_surgery  life_expectancy     IDH TERT  \
# 0              G    partielle         42.0             30.0  mutant   wt
# 1    non précisé      exérèse         28.0           2069.0      NC  NaN
#
#    IDH_TERT  1p19q_codel  IK   RX  CHEM
# 0       3.0          0.0 NaN  1.0   1.0
# 1       NaN          NaN NaN  1.0   NaN

# %%
#df_final_kps['life_expectancy'] = pd.to_datetime(df_final_kps['life_expectancy'])
df_final_kps['life_expectancy'] = df_final_kps['life_expectancy'].round()

# %% [markdown]
# # Create Imputation dataset

# %%
#df_final_kps.drop(['DoB','Death_date','Surgery_date','Chemo_start_date','Rx_date'],axis=1,inplace=True)
#write_to_pickle(df_final_kps,"preimputation")

# %%
# Drop ID so that MICE imputation works
df_final_kps.drop(['ID'], axis=1,inplace=True)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-144-7646fd0d6985> in <module>()
#       1 # Drop ID so that MICE imputation works
# ----> 2 df_final_kps.drop(['ID'], axis=1,inplace=True)
#
# //anaconda/lib/python3.6/site-packages/pandas/core/generic.py in drop(self, labels, axis, level, inplace, errors)
#    1905                 new_axis = axis.drop(labels, level=level, errors=errors)
#    1906             else:
# -> 1907                 new_axis = axis.drop(labels, errors=errors)
#    1908             dropped = self.reindex(**{axis_name: new_axis})
#    1909             try:
#
# //anaconda/lib/python3.6/site-packages/pandas/indexes/base.py in drop(self, labels, errors)
#    3260             if errors != 'ignore':
#    3261                 raise ValueError('labels %s not contained in axis' %
# -> 3262                                  labels[mask])
#    3263             indexer = indexer[~mask]
#    3264         return self.delete(indexer)
#
# ValueError: labels ['ID'] not contained in axis

# %%
#checking how many observations we have with different numbers of NA data across variables
no_NAN = df_final_kps.dropna(thresh = 35)
len(no_NAN)
# Out:
# 0

# %%
len(df_final_kps.columns)
# Out:
# 34

# %%
df_final_kps.drop("RX", axis = 1, inplace=True)
df_final_kps.drop("CHEM", axis = 1, inplace=True)

# %% [markdown]
# # Add it to a csv ready for imputation. Then read the imputed one for one last manipulation

# %%
#export dataset for imputation
df_final_kps.to_csv('Dropbox/Healthcare work Patric/imputation_dataset_with_censoring_16022018.csv', index=False)

# %% [markdown]
# here we will need to import the imputed dataset, which used life expectancy for the information it contains, and replace
# this variable with the same column from the pre imputation dataset, since we are not interested in the imputed target variable values

# %%
df_imputed = pd.read_csv("Dropbox/Healthcare work Patric/imputed_dataset_with_censoring_16022018")

# %%
df_imputed['life_expectancy'] = df_final_kps['life_expectancy']

# %%
df_imputed['life_expectancy'].isnull().value_counts()
# Out:
# False    2086
# True      272
# Name: life_expectancy, dtype: int64

# %%
df_imputed.to_csv("Dropbox/Healthcare work Patric/imputed_dataset_with_censoring_16022018.csv")

# %%
df_imputed_knn = pd.read_csv("Dropbox/Healthcare work Patric/imputed_dataset_with_censoring_16.02.2018_kNN_before life expectancy reset.csv")

# %%
df_imputed_knn['life_expectancy'] = df_final_kps['life_expectancy']

# %%
df_imputed_knn['life_expectancy'].isnull().value_counts()
# Out:
# False    2086
# True      272
# Name: life_expectancy, dtype: int64

# %%
df_imputed_knn.to_csv("Dropbox/Healthcare work Patric/imputed_dataset_with_censoring_16022018_kNN.csv")
